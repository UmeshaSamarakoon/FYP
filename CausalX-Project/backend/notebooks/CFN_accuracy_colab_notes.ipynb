# %% [markdown]
# # CFN accuracy experiments (Colab)
# Notes and runnable cells to iterate on the Causal Fusion Network (CFN), test detection accuracy, and try improvements safely.

# %% [markdown]
# ## Embedding-aware CFN (TCN + Wav2Vec2)
# - Ensure your CSV includes `tcn_visual_emb` and `wav2vec_audio_emb`.
# - Train with `--use-embeddings` to produce `models/cfn_emb.pth`.
# - Enable inference with: `CFN_USE_EMBEDDINGS=true` and `CFN_EMB_MODEL_PATH=models/cfn_emb.pth`.
# - Optional SCM score: set `CFN_ENABLE_SCM_CHECKS=true`.

# %% [markdown]
# ## Embedding pipeline (wav2vec2 + VisualTCN)
# End-to-end steps to cache checkpoints, build an embedding CSV, train CFN with embeddings, and run inference/eval.

# %% [markdown]
# Setup/Import cell

# %%
# Cache wav2vec2 checkpoint (one-time)
import pathlib, os, subprocess, sys
ckpt_dir = pathlib.Path('~/.cache/torch/hub/checkpoints').expanduser()
ckpt_dir.mkdir(parents=True, exist_ok=True)
ckpt = ckpt_dir/'wav2vec2_fairseq_base_ls960.pth'
if not ckpt.exists():
    # !wget -O "{ckpt}" https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960.pth
print('wav2vec2 cached:', ckpt.exists(), ckpt)
# Out:
# wav2vec2 cached: True /Users/venturit/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960.pth

# %% [markdown]
# Build the embedding CSV

# %%
# Runtime env for embeddings + CPU-only mediapipe (local + Colab)
import os
import sys
from pathlib import Path

_candidates = [
    Path.cwd(),
    Path.cwd().parent,
    Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
    Path('/content/CausalX-Project/backend'),
]
PROJECT_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)
if PROJECT_ROOT is None:
    raise RuntimeError('Could not locate backend root with src/ directory.')

DATA_ROOT = PROJECT_ROOT / 'data'
RAW_ROOT = DATA_ROOT / 'raw' / 'fakeavceleb'
sys.path.insert(0, str(PROJECT_ROOT))

os.environ['CFN_USE_EMBEDDINGS'] = 'true'
os.environ['CFN_W2V2_MODEL'] = 'WAV2VEC2_BASE'
os.environ['MEDIAPIPE_DISABLE_GPU'] = '1'
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

print('PROJECT_ROOT:', PROJECT_ROOT)
print('RAW_ROOT exists:', RAW_ROOT.exists())
# Out:
# PROJECT_ROOT: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend
# RAW_ROOT exists: False

# %%
from pathlib import Path
import sys, os, random
import numpy as np
import pandas as pd
import librosa

if 'PROJECT_ROOT' not in globals() or not (Path(PROJECT_ROOT) / 'src').exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    PROJECT_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)
    if PROJECT_ROOT is None:
        raise RuntimeError('Could not locate backend root with src/ directory.')
else:
    PROJECT_ROOT = Path(PROJECT_ROOT)

DATA_ROOT = PROJECT_ROOT / 'data'
RAW_ROOT = DATA_ROOT / 'raw' / 'fakeavceleb'
sys.path.insert(0, str(PROJECT_ROOT))

os.environ['CFN_USE_EMBEDDINGS'] = 'true'
os.environ['CFN_W2V2_MODEL'] = 'WAV2VEC2_BASE'
os.environ['MEDIAPIPE_DISABLE_GPU'] = '1'
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

from src.utils.dataset_registry import get_fakeavceleb_videos
from src.cvi.feature_extractor import FeatureExtractor
from src.cvi.frame_causal_extractor import extract_frame_level_features

fe = FeatureExtractor()
videos = get_fakeavceleb_videos(RAW_ROOT)
random.shuffle(videos)

rows = []
for v in videos[:400]:
    frames = extract_frame_level_features(v['path'], duration=8.0)
    if not frames:
        continue
    lip = np.array([f['lip_aperture'] for f in frames], np.float32)
    audio_rms = np.array([f['audio_rms'] for f in frames], np.float32)
    wav, sr = librosa.load(v['path'], sr=16000, duration=8.0)
    vis = fe.get_visual_embeddings(lip)
    wav_emb = fe.get_audio_embeddings(wav, sr=sr)
    rows.append({
        'path': v['path'],
        'label': v['label'],
        'lip_variance': float(lip.var()),
        'av_correlation': float(np.corrcoef(lip, audio_rms)[0, 1]) if len(lip) > 1 else 0.0,
        'av_lag_frames': 0.0,
        'jitter_mean': float(np.mean([f.get('jitter', 0.0) for f in frames])),
        'jitter_std': float(np.std([f.get('jitter', 0.0) for f in frames])),
        'tcn_visual_emb': float(np.mean(vis)) if vis.size else 0.0,
        'wav2vec_audio_emb': float(np.mean(wav_emb)) if wav_emb.size else 0.0,
    })

out = DATA_ROOT / 'processed' / 'causal_multimodal_embeddings.csv'
out.parent.mkdir(parents=True, exist_ok=True)
pd.DataFrame(rows).to_csv(out, index=False)
print('wrote', len(rows), 'rows to', out)
# Out:
# wrote 0 rows to /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_embeddings.csv

# %% [markdown]
# Train CFN with embeddings

# %%
# Train CFN with embeddings (local/colab safe)
import subprocess
import sys
from pathlib import Path

if 'PROJECT_ROOT' not in globals() or not (Path(PROJECT_ROOT) / 'src').exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    PROJECT_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)
    if PROJECT_ROOT is None:
        raise RuntimeError('Could not locate backend root with src/ directory.')
else:
    PROJECT_ROOT = Path(PROJECT_ROOT)

py = PROJECT_ROOT / '.venv' / 'bin' / 'python'
python_exe = str(py) if py.exists() else sys.executable
data_csv = PROJECT_ROOT / 'data' / 'processed' / 'causal_multimodal_embeddings.csv'
if not data_csv.exists():
    raise FileNotFoundError(f'Missing CSV: {data_csv}. Run embedding CSV cell first.')

cmd = [
    python_exe, '-m', 'src.training.train_cfn',
    '--data', 'data/processed/causal_multimodal_embeddings.csv',
    '--use-scaler', '--use-embeddings',
    '--epochs', '15', '--patience', '4', '--batch-size', '128',
]
print('Running:', ' '.join(cmd))
subprocess.run(cmd, cwd=PROJECT_ROOT, check=True)
# Out:
# Running: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python -m src.training.train_cfn --data data/processed/causal_multimodal_embeddings.csv --use-scaler --use-embeddings --epochs 15 --patience 4 --batch-size 128
# Using seed: 42
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/src/training/train_cfn.py", line 1264, in <module>
#     main()
#   File "/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/src/training/train_cfn.py", line 821, in main
#     df = pd.read_csv(args.data)
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py", line 873, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import os
from pathlib import Path

data_csv = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_embeddings.csv')
print(f"File size: {os.path.getsize(data_csv)} bytes")
print(f"File exists: {data_csv.exists()}")

# Peek at raw content
with open(data_csv, 'r') as f:
    print(repr(f.read(500)))
# Out:
# File size: 1 bytes
# File exists: True
# '\n'

# %% [markdown]
#  Train VisualTCN

# %%
from src.modules.embeddings import VisualTCN
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from pathlib import Path

if 'videos' not in globals():
    raise RuntimeError("`videos` is not defined. Run the embedding data-prep cell first.")

if 'extract_frame_level_features' not in globals():
    from src.cvi.frame_causal_extractor import extract_frame_level_features

project_root = Path(globals().get('PROJECT_ROOT', Path.cwd()))
if not (project_root / 'src').exists() and (project_root / 'backend' / 'src').exists():
    project_root = project_root / 'backend'

models_dir = project_root / 'models' if (project_root / 'src').exists() else Path('backend/models')
models_dir.mkdir(parents=True, exist_ok=True)
model_path = models_dir / 'visual_tcn.pth'

seqs, labels = [], []
for v in videos[:200]:
    frames = extract_frame_level_features(v['path'], duration=6.0)
    if len(frames) < 20:
        continue
    lip = np.array([f['lip_aperture'] for f in frames], np.float32)
    lip = (lip - lip.mean()) / (lip.std() + 1e-6)
    seqs.append(lip[:256])
    labels.append(v['label'])

if not seqs:
    raise RuntimeError('No usable frame sequences were extracted for VisualTCN training.')

max_len = max(len(s) for s in seqs)
seqs = [np.pad(s, (0, max_len - len(s))) for s in seqs]
X = torch.tensor(seqs, dtype=torch.float32)
y = torch.tensor(labels, dtype=torch.float32)

model = VisualTCN(out_dim=64)
clf = nn.Linear(64, 1)
opt = optim.Adam(list(model.parameters()) + list(clf.parameters()), lr=1e-3)
bce = nn.BCEWithLogitsLoss()

for epoch in range(8):
    opt.zero_grad()
    z = model(X)
    loss = bce(clf(z).squeeze(1), y)
    loss.backward()
    opt.step()
    print('epoch', epoch + 1, 'loss', float(loss))

torch.save(model.state_dict(), model_path)
print(f'saved visual TCN to {model_path}')

# %%
import os

# Raise prob threshold to reduce false positives; raise ratio to require more flagged frames.
os.environ["CFN_PROB_THRESH"] = "0.7"
os.environ["CFN_RATIO_THRESH"] = "0.4"

print("Using CFN_PROB_THRESH", os.environ["CFN_PROB_THRESH"],
      "CFN_RATIO_THRESH", os.environ["CFN_RATIO_THRESH"])

# %% [markdown]
# Inference demo

# %%
from pathlib import Path
from src.cvi.api.inference_service import run_full_cvi_pipeline
from src.utils.dataset_registry import get_fakeavceleb_videos

if 'PROJECT_ROOT' not in globals() or not (Path(PROJECT_ROOT) / 'src').exists():
    raise RuntimeError('Run setup cell first to define PROJECT_ROOT and RAW_ROOT.')

videos = get_fakeavceleb_videos(RAW_ROOT)
if not videos:
    raise RuntimeError(f'No videos found under {RAW_ROOT}')

sample = next((v for v in videos if int(v.get('label', 0)) == 1), videos[0])
video_path = Path(sample['path'])

out = run_full_cvi_pipeline(str(video_path))
print('video_path:', video_path)
print('video_fake:', out['video_fake'], 'confidence:', out['fake_confidence'])
print('highlight_timestamps:', out['highlight_timestamps'][:10])

# %%
from pathlib import Path
import random
import csv
from src.cvi.api.inference_service import run_full_cvi_pipeline
from src.utils.dataset_registry import get_fakeavceleb_videos

if 'PROJECT_ROOT' not in globals() or not (Path(PROJECT_ROOT) / 'src').exists():
    raise RuntimeError('Run setup cell first to define PROJECT_ROOT and RAW_ROOT.')

manifest = PROJECT_ROOT / 'eval_manifest_balanced.tsv'
if not manifest.exists():
    videos = get_fakeavceleb_videos(RAW_ROOT)
    fakes = [v for v in videos if int(v['label']) == 1]
    reals = [v for v in videos if int(v['label']) == 0]
    n = min(len(fakes), len(reals), 100)
    random.shuffle(fakes)
    random.shuffle(reals)
    sample = fakes[:n] + reals[:n]
    random.shuffle(sample)
    with manifest.open('w', newline='') as f:
        w = csv.writer(f, delimiter='	')
        for v in sample:
            w.writerow([v['path'], v['label']])
    print('Created manifest:', manifest, 'rows=', len(sample))


tp = tn = fp = fn = skipped = 0
with manifest.open() as f:
    for line in f:
        path_str, label = line.strip().split('	')
        p = Path(path_str)
        if not p.is_absolute():
            p = PROJECT_ROOT / p

        try:
            r = run_full_cvi_pipeline(str(p))
        except Exception as e:
            skipped += 1
            print(f'Skipping {p} ({e})')
            continue

        pred = r['video_fake']
        label = int(label)
        if pred == 1 and label == 1:
            tp += 1
        elif pred == 0 and label == 0:
            tn += 1
        elif pred == 1 and label == 0:
            fp += 1
        else:
            fn += 1

total = tp + tn + fp + fn
acc = (tp + tn) / total if total else 0
prec = tp / (tp + fp) if (tp + fp) else 0
rec = tp / (tp + fn) if (tp + fn) else 0
f1 = 2 * prec * rec / (prec + rec) if (prec + rec) else 0
print(f'Acc={acc:.3f} Prec={prec:.3f} Rec={rec:.3f} F1={f1:.3f} TP={tp} TN={tn} FP={fp} FN={fn} Skipped={skipped}')

# %% [markdown]
# ## New training workflow helpers
# - Use `backend/scripts/run_training_pipeline.sh` to run feature extraction, optional balancing, and CFN training in one pass.
# - Use `backend/scripts/run_embedding_training.sh` to train the embedding-aware CFN model.
# - Copy `backend/.env.example` to `.env` and set `CFN_PROB_THRESH` / `CFN_RATIO_THRESH` only as a short-term tuning lever (prefer retraining).

# %% [markdown]
# ## 0) Runtime
# - Runtime type: GPU (T4/A100 preferred)
# - Python: 3.9+
# - Enable persistent session if running sweeps

# %% [markdown]
# ## 2) Smoke test on one video

# %%
from pathlib import Path
from src.cvi.cfn_frame_inference import run_cfn_on_video
from src.cvi.api.inference_service import summarize_video
from src.utils.dataset_registry import get_fakeavceleb_videos

if 'PROJECT_ROOT' not in globals() or not (Path(PROJECT_ROOT) / 'src').exists():
    raise RuntimeError('Run setup cell first to define PROJECT_ROOT and RAW_ROOT.')

videos = get_fakeavceleb_videos(RAW_ROOT)
if not videos:
    raise RuntimeError(f'No videos found under {RAW_ROOT}')

video = videos[0]['path']

frames = run_cfn_on_video(
    video,
    threshold=0.6,
    chunk_seconds=10,
    max_seconds=None,
)

video_fake, fake_conf, highlight = summarize_video(
    frames,
    prob_thresh=0.6,
    ratio_thresh=0.3,
)
print(f'video={video}')
print(f'frames={len(frames)}, video_fake={video_fake}, conf={fake_conf:.3f}')
# Out:
# I0000 00:00:1774186712.518990       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 90.5), renderer: Apple M2
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 11
#       9 videos = get_fakeavceleb_videos(RAW_ROOT)
#      10 if not videos:
# ---> 11     raise RuntimeError(f'No videos found under {RAW_ROOT}')
#      13 video = videos[0]['path']
#      15 frames = run_cfn_on_video(
#      16     video,
#      17     threshold=0.6,
#      18     chunk_seconds=10,
#      19     max_seconds=None,
#      20 )
#
# RuntimeError: No videos found under /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/raw/fakeavceleb

# %% [markdown]
# ## 3) Batch evaluation helper

# %%
import glob
from pathlib import Path
from tqdm import tqdm
from src.cvi.api.inference_service import summarize_video
from src.cvi.cfn_frame_inference import run_cfn_on_video

def evaluate_dir(video_dir, prob_thresh=0.6, ratio_thresh=0.3, max_files=30):
    rows = []
    video_dir = Path(video_dir)
    files = sorted(glob.glob(str(video_dir / '**' / '*.mp4'), recursive=True))
    if max_files is not None:
        files = files[:max_files]
    for path in tqdm(files):
        frames = run_cfn_on_video(path, threshold=prob_thresh, chunk_seconds=10)
        label, conf, _ = summarize_video(frames, prob_thresh=prob_thresh, ratio_thresh=ratio_thresh)
        rows.append({'video': path, 'video_fake': label, 'fake_conf': conf})
    return rows

if 'RAW_ROOT' not in globals():
    raise RuntimeError('Run setup cell first to define RAW_ROOT.')

rows = evaluate_dir(RAW_ROOT, max_files=20)
rows[:3]

# %% [markdown]
# ## 4) Techniques to test
# Each section below has a short description and a runnable cell.

# %% [markdown]
# ### 4.1 Threshold sweep (prob_thresh, ratio_thresh)
# Grid-search operating points; compute simple metrics.

# %%
import itertools
import pandas as pd
from pathlib import Path
from sklearn.metrics import precision_recall_fscore_support

# Assumes rows_gt with ground-truth labels, e.g. [{"video":..., "gt":0/1}]
prob_grid = [0.4, 0.5, 0.6, 0.7]
ratio_grid = [0.2, 0.3, 0.4]

if 'RAW_ROOT' not in globals():
    raise RuntimeError('Run setup cell first to define RAW_ROOT.')

EVAL_VIDEO_DIR = Path(RAW_ROOT)

def sweep_thresholds(rows_gt, prob_grid, ratio_grid, video_dir=EVAL_VIDEO_DIR):
    records = []
    for p, r in itertools.product(prob_grid, ratio_grid):
        preds = evaluate_dir(video_dir, prob_thresh=p, ratio_thresh=r, max_files=30)
        merged = pd.DataFrame(rows_gt).merge(pd.DataFrame(preds), on='video')
        prec, rec, f1, _ = precision_recall_fscore_support(
            merged['gt'], merged['video_fake'], average='binary', zero_division=0
        )
        records.append({'prob_thresh': p, 'ratio_thresh': r, 'precision': prec, 'recall': rec, 'f1': f1})
    return pd.DataFrame(records)

# rows_gt = [...]  # build from the same set of videos you evaluate
# sweep_df = sweep_thresholds(rows_gt, prob_grid, ratio_grid)
# sweep_df.sort_values('f1', ascending=False).head()

# %% [markdown]
# ### 4.2 Temporal smoothing
# Apply a moving average over frame-level `fake_prob` to reduce spikes before summarizing.

# %%
import numpy as np
from scipy.ndimage import uniform_filter1d
from src.cvi.api.inference_service import summarize_video

def summarize_with_smoothing(frames, prob_thresh=0.6, ratio_thresh=0.3, window=5):
    probs = np.array([f["fake_prob"] for f in frames])
    smooth = uniform_filter1d(probs, size=window, mode="nearest")
    for f, s in zip(frames, smooth):
        f["fake_prob_smooth"] = float(s)
    return summarize_video(frames, prob_thresh=prob_thresh, ratio_thresh=ratio_thresh)

# Example: video_fake, fake_conf, highlight = summarize_with_smoothing(frames, window=7)

# %% [markdown]
# ### 4.3 Chunk sizing
# Compare `chunk_seconds` (e.g., 5/10/15) for latency vs. stability.

# %%
import time

def benchmark_chunks(video_path, chunk_sizes=(5, 10, 15)):
    results = []
    for cs in chunk_sizes:
        start = time.time()
        frames = run_cfn_on_video(video_path, threshold=0.6, chunk_seconds=cs)
        elapsed = time.time() - start
        results.append({"chunk_seconds": cs, "frames": len(frames), "seconds": elapsed})
    return results

# benchmark_chunks(video)

# %% [markdown]
# ### 4.4 Audio/video lag search
# Evaluate small AV shifts to reduce desync noise.

# %%
import numpy as np

def av_lag_scores(frames, lags_ms=(-120, -60, 0, 60, 120)):
    scores = []
    base_lips = np.array([f["lip_aperture"] for f in frames])
    for lag in lags_ms:
        shifted_audio = np.array([f["audio_rms"] for f in frames])
        # crude shift by rolling; for precise shift re-run feature extraction with offset
        shift_frames = int(lag / 1000 * 30)  # assumes ~30 fps
        shifted_audio = np.roll(shifted_audio, shift_frames)
        corr = np.corrcoef(base_lips, shifted_audio)[0, 1]
        scores.append({"lag_ms": lag, "corr": float(corr)})
    return scores

# av_lag_scores(frames)

# %% [markdown]
# ### 4.5 Feature weighting / model variants
# Hook to rescale features before CFN to prototype weighting; useful if you add more cues.

# %%
def run_with_feature_scale(video_path, av_scale=1.0, phys_scale=1.0):
    frames = run_cfn_on_video(video_path, threshold=0.6)
    for f in frames:
        f["av_mismatch"] *= av_scale
        f["jitter"] = f.get("jitter", 0.0) * phys_scale
    return frames

# frames_scaled = run_with_feature_scale(video, av_scale=1.2, phys_scale=0.8)

# %% [markdown]
# ### 4.6 Augmentations for fine-tuning
# Example: mild audio speed perturbation and landmark jitter to stress-test robustness (use for training, not inference).

# %%
import librosa
import numpy as np

def augment_audio_speed(y, rate=1.02):
    return librosa.effects.time_stretch(y, rate=rate)

def jitter_landmarks(pts, sigma=0.002):
    noise = np.random.normal(scale=sigma, size=pts.shape)
    return pts + noise

# %% [markdown]
# ### 4.7 Bounding-box gating
# Visual check: bboxes only where `fake_prob >= threshold`.

# %%
import cv2

def draw_bboxes(video_path, frames, out_path="annotated.mp4"):
    cap = cv2.VideoCapture(video_path)
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    fps = cap.get(cv2.CAP_PROP_FPS) or 25
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    writer = cv2.VideoWriter(out_path, fourcc, fps, (w, h))

    frame_map = {int(f["timestamp"] * fps): f for f in frames}

    idx = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        info = frame_map.get(idx)
        if info and info.get("bbox"):
            x1, y1, x2, y2 = info["bbox"]
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
        writer.write(frame)
        idx += 1

    cap.release()
    writer.release()

# draw_bboxes(video, frames, out_path="annotated.mp4")

# %% [markdown]
# ## 5) Logging results
# - Keep a CSV of experiment configs and metrics (thresholds, chunk size, smoothing window).
# - Save short snippets of failure cases for qualitative review.

# %% [markdown]
# ## Balanced eval + threshold sweep (updated)
# Creates a balanced manifest, lets you tune thresholds via env vars, and reports specificity/balanced accuracy.

# %%
from pathlib import Path
import sys, os, random, numpy as np, pandas as pd, librosa

_candidates = [
    Path.cwd(),
    Path.cwd().parent,
    Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
    Path('/content/CausalX-Project/backend'),
]
PROJECT_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)
if PROJECT_ROOT is None:
    raise RuntimeError('Could not locate backend root with src/ directory.')

DATA_ROOT = PROJECT_ROOT / 'data'
RAW_ROOT = DATA_ROOT / 'raw' / 'fakeavceleb'

sys.path.insert(0, str(PROJECT_ROOT))
os.environ['CFN_USE_EMBEDDINGS'] = 'true'
os.environ['CFN_W2V2_MODEL'] = 'WAV2VEC2_BASE'
os.environ['MEDIAPIPE_DISABLE_GPU'] = '1'
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

print('PROJECT_ROOT:', PROJECT_ROOT)
print('RAW_ROOT exists:', RAW_ROOT.exists())

# %%
import os
os.environ['CFN_PROB_THRESH'] = '0.7'
os.environ['CFN_RATIO_THRESH'] = '0.4'
print('CFN_PROB_THRESH', os.environ['CFN_PROB_THRESH'], 'CFN_RATIO_THRESH', os.environ['CFN_RATIO_THRESH'])

# %%
from src.utils.dataset_registry import get_fakeavceleb_videos
import csv
videos = get_fakeavceleb_videos(RAW_ROOT)
fakes = [v for v in videos if v['label']==1]
reals = [v for v in videos if v['label']==0]
n = min(len(fakes), len(reals), 200)
random.shuffle(fakes); random.shuffle(reals)
sample = fakes[:n] + reals[:n]
random.shuffle(sample)
manifest = PROJECT_ROOT/'eval_manifest_balanced.tsv'
with manifest.open('w') as f:
    w = csv.writer(f, delimiter='	')
    for v in sample:
        w.writerow([v['path'], v['label']])
print('Wrote', len(sample), 'rows to', manifest)
# Out:
# Wrote 0 rows to /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/eval_manifest_balanced.tsv

# %%
from src.cvi.api.inference_service import run_full_cvi_pipeline
from pathlib import Path
tp=tn=fp=fn=skipped=0
manifest = PROJECT_ROOT/'eval_manifest_balanced.tsv'
for line in manifest.read_text().splitlines():
    path_str, label = line.split('	')
    p = Path(path_str)
    if not p.is_absolute():
        p = PROJECT_ROOT / p
    try:
        r = run_full_cvi_pipeline(str(p))
    except Exception as e:
        skipped += 1
        print('Skip', p, e)
        continue
    pred = r['video_fake']; label=int(label)
    if pred==1 and label==1: tp+=1
    elif pred==0 and label==0: tn+=1
    elif pred==1 and label==0: fp+=1
    else: fn+=1
total = tp+tn+fp+fn
acc = (tp+tn)/total if total else 0
prec = tp/(tp+fp) if (tp+fp) else 0
rec = tp/(tp+fn) if (tp+fn) else 0
spec = tn/(tn+fp) if (tn+fp) else 0
bal_acc = 0.5*(rec+spec)
f1 = 2*prec*rec/(prec+rec) if (prec+rec) else 0
print(f'Acc={acc:.3f} Prec={prec:.3f} Rec={rec:.3f} Spec={spec:.3f} BalAcc={bal_acc:.3f} F1={f1:.3f} TP={tp} TN={tn} FP={fp} FN={fn} Skipped={skipped}')

# %%
from src.cvi.api.inference_service import run_full_cvi_pipeline
video_path = PROJECT_ROOT / 'data/raw/fakeavceleb/FakeVideo-FakeAudio/African/men/id00076/00109_2_id00166_wavtolip.mp4'
r = run_full_cvi_pipeline(str(video_path))
print('video_fake', r['video_fake'], 'confidence', r['fake_confidence'])
print('highlights', r['highlight_timestamps'][:10])

# %% [markdown]
# ## 6) Classification-metric improvement sweeps (trainer-level)
# Use this section to optimize training for classification targets directly from notebook.
# - Uses the updated `src.training.train_cfn` options (`--selection-threshold-mode target`, `--target-*`, `--weight-application`, leakage-safe split).
# - Compares multiple train configs quickly and logs a leaderboard.
# - Saves per-run threshold report (`cfn_threshold_report.json`) for auditability.

# %%
from pathlib import Path
import os, sys, json, shlex, subprocess
import pandas as pd

# Resolve backend root (works for local + Colab)
if 'PROJECT_ROOT' in globals() and (Path(PROJECT_ROOT) / 'src').exists():
    BACKEND_ROOT = Path(PROJECT_ROOT)
else:
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

sys.path.insert(0, str(BACKEND_ROOT))

PYTHON_BIN = BACKEND_ROOT / '.venv/bin/python'
PYTHON_EXE = str(PYTHON_BIN) if PYTHON_BIN.exists() else sys.executable

print('BACKEND_ROOT =', BACKEND_ROOT)
print('PYTHON_EXE  =', PYTHON_EXE)

BASE_ARGS = [
    '-m', 'src.training.train_cfn',
    '--data', 'data/processed/causal_multimodal_dataset_mixed_train.csv',
    '--train-source', 'all',
    '--group-split-col', 'video_id',
    '--use-embeddings', '--use-scaler',
    '--group-balance',
    '--scheduler', 'cosine',
    '--batch-size', '128',
    '--lr', '2e-4',
    '--weight-decay', '1e-4',
    '--seed', '42',
    '--selection-metric', 'hybrid_robust',
    '--selection-threshold-mode', 'target',
    '--target-acc', '0.90',
    '--target-precision', '0.95',
    '--target-recall', '0.88',
    '--target-f1', '0.90',
    '--target-priority', 'f1',
    '--min-domain-spec', '0.05',
    '--min-domain-rec', '0.20',
]

def run_train_experiment(name: str, extra_args: str = '', epochs: int = 20, patience: int = 6):
    out_dir = BACKEND_ROOT / 'models' / f'nb_cls_{name}'
    out_dir.mkdir(parents=True, exist_ok=True)

    cmd = [PYTHON_EXE] + BASE_ARGS + [
        '--epochs', str(epochs),
        '--patience', str(patience),
        '--model-dir', str(out_dir),
    ] + shlex.split(extra_args)

    print('\n' + '=' * 100)
    print('EXPERIMENT:', name)
    print('CMD:', ' '.join(shlex.quote(x) for x in cmd))
    subprocess.run(cmd, cwd=BACKEND_ROOT, check=True)

    rep_path = out_dir / 'cfn_threshold_report.json'
    if not rep_path.exists():
        raise FileNotFoundError(f'Missing report: {rep_path}')
    rep = json.loads(rep_path.read_text())
    chosen = rep['chosen_epoch_report']
    overall = chosen['overall_at_selection_threshold']

    return {
        'name': name,
        'epochs': epochs,
        'selection_mode': rep.get('selection_threshold_mode'),
        'checkpoint_meets_constraints': rep.get('best_checkpoint_met_constraints'),
        'best_epoch': chosen.get('epoch'),
        'auc': chosen.get('val_auc'),
        'pr_auc': chosen.get('pr_auc'),
        'sel_score': chosen.get('selection_score'),
        'thr': chosen.get('selection_threshold'),
        'acc': overall.get('acc'),
        'prec': overall.get('prec'),
        'rec': overall.get('rec'),
        'f1': overall.get('f1'),
        'spec': overall.get('spec'),
        'bal_acc': overall.get('bal_acc'),
        'targets_met': chosen.get('targets_met'),
        'target_gap': chosen.get('target_shortfall'),
        'model_dir': str(out_dir),
        'report_path': str(rep_path),
    }

# %%
import pandas as pd
# Suggested sweep: start with BCE/no causal, then compare weighting + balancing modes.
# Strict promotion gates (tune these for your target quality bar).
MIN_SPEC_FOR_PROMOTION = 0.40
MIN_BAL_ACC_FOR_PROMOTION = 0.65
MIN_AUC_FOR_PROMOTION = 0.60
REQUIRE_TARGETS_MET_FOR_PROMOTION = True

EXPERIMENTS = [
    ('bce_auto', '--loss bce --causal-weight 0.0 --use-weighted-sampler --weight-application auto'),
    ('bce_loss', '--loss bce --causal-weight 0.0 --weight-application loss'),
    ('bce_sampler', '--loss bce --causal-weight 0.0 --use-weighted-sampler --weight-application sampler'),
    ('bce_both', '--loss bce --causal-weight 0.0 --use-weighted-sampler --weight-application both'),
    ('focal_auto', '--loss focal --focal-alpha 0.70 --focal-gamma 1.5 --causal-weight 0.0 --use-weighted-sampler --weight-application auto'),
    ('downsample_bce', '--class-balance-mode downsample --loss bce --causal-weight 0.0 --weight-application loss'),
    ('upsample_bce', '--class-balance-mode upsample --loss bce --causal-weight 0.0 --weight-application loss'),
]

rows = []
for name, extra in EXPERIMENTS:
    try:
        rows.append(run_train_experiment(name, extra_args=extra, epochs=20, patience=6))
    except Exception as e:
        rows.append({'name': name, 'error': str(e)})

leaderboard = pd.DataFrame(rows)
if 'error' in leaderboard.columns:
    display(leaderboard[['name', 'error']].dropna(how='all'))

# Ensure required metric columns exist.
for c in ['spec', 'bal_acc', 'auc', 'targets_met', 'target_gap', 'sel_score', 'f1']:
    if c not in leaderboard.columns:
        leaderboard[c] = pd.NA

if REQUIRE_TARGETS_MET_FOR_PROMOTION:
    targets_mask = leaderboard['targets_met'].fillna(False)
else:
    targets_mask = pd.Series([True] * len(leaderboard), index=leaderboard.index)

leaderboard['strict_pass'] = (
    leaderboard['spec'].fillna(-1).astype(float).ge(MIN_SPEC_FOR_PROMOTION)
    & leaderboard['bal_acc'].fillna(-1).astype(float).ge(MIN_BAL_ACC_FOR_PROMOTION)
    & leaderboard['auc'].fillna(-1).astype(float).ge(MIN_AUC_FOR_PROMOTION)
    & targets_mask.astype(bool)
)

print(
    'Strict gates:',
    {
        'min_spec': MIN_SPEC_FOR_PROMOTION,
        'min_bal_acc': MIN_BAL_ACC_FOR_PROMOTION,
        'min_auc': MIN_AUC_FOR_PROMOTION,
        'require_targets_met': REQUIRE_TARGETS_MET_FOR_PROMOTION,
    }
)
print('Strict-pass experiments:', int(leaderboard['strict_pass'].fillna(False).sum()), '/', len(leaderboard))

ok = leaderboard.dropna(subset=['auc']).copy()
if len(ok):
    ok = ok.sort_values(
        by=['strict_pass', 'targets_met', 'target_gap', 'sel_score', 'auc', 'spec', 'bal_acc', 'f1'],
        ascending=[False, False, True, False, False, False, False, False],
    )
    display(ok)

lb_path = BACKEND_ROOT / 'models' / 'nb_cls_leaderboard.csv'
leaderboard.to_csv(lb_path, index=False)
print('Saved leaderboard to', lb_path)

# %% [markdown]
# ### 6.1 Promote Best Short-Run Config
# **What this step tries:** take the top short-run setting and rerun with longer training to verify the gain is stable and not a short-epoch artifact.
#
# **Readout to check:** whether target metrics hold after the longer schedule (`AUC`, `F1`, `balanced_acc`, `specificity`).

# %%
# Promote the best short-run config to a longer training run.
# If no config passes strict gates, long-run training is blocked by default.
name_to_args = {k: v for k, v in EXPERIMENTS}
ALLOW_RELAXED_FALLBACK_IF_NO_STRICT = False

valid = leaderboard.dropna(subset=['auc']).copy() if 'auc' in leaderboard.columns else pd.DataFrame()
strict = valid[valid['strict_pass'].fillna(False)] if 'strict_pass' in valid.columns else pd.DataFrame()

if len(strict):
    ranked = strict.sort_values(
        by=['targets_met', 'target_gap', 'sel_score', 'auc', 'spec', 'bal_acc', 'f1'],
        ascending=[False, True, False, False, False, False, False],
    )
    best_name = ranked.iloc[0]['name']
    best_args = name_to_args[best_name]
    print('Best strict-pass config:', best_name)
    print('Args:', best_args)
elif len(valid) and ALLOW_RELAXED_FALLBACK_IF_NO_STRICT:
    ranked = valid.sort_values(
        by=['targets_met', 'target_gap', 'sel_score', 'auc', 'spec', 'bal_acc', 'f1'],
        ascending=[False, True, False, False, False, False, False],
    )
    best_name = ranked.iloc[0]['name']
    best_args = name_to_args[best_name]
    print('No strict-pass config found; using relaxed fallback:', best_name)
    print('Args:', best_args)
else:
    best_name, best_args = None, None
    print('No experiment passed strict promotion gates. Long-run training disabled.')

RUN_LONG = False  # Set True after reviewing leaderboard.
if RUN_LONG and best_args is not None:
    long_row = run_train_experiment(f'{best_name}_long', extra_args=best_args, epochs=50, patience=10)
    display(pd.DataFrame([long_row]))
elif RUN_LONG:
    print('RUN_LONG=True but no eligible best config. Relax gates or enable fallback.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 # Promote the best short-run config to a longer training run.
#       2 # If no config passes strict gates, long-run training is blocked by default.
# ----> 3 name_to_args = {k: v for k, v in EXPERIMENTS}
#       4 ALLOW_RELAXED_FALLBACK_IF_NO_STRICT = False
#       6 valid = leaderboard.dropna(subset=['auc']).copy() if 'auc' in leaderboard.columns else pd.DataFrame()
#
# NameError: name 'EXPERIMENTS' is not defined

# %% [markdown]
# ### 6.2 Hard-Negative Mining + Retrain
# **What this step tries:** mine false positives from evaluation and upweight them in retraining to improve real-class specificity.
#
# **Readout to check:** drop in false positives without collapsing fake recall.

# %%
# Optional: mine hard negatives (real videos predicted fake), then retrain with --hard-negative-file.
from src.cvi.api.inference_service import run_full_cvi_pipeline
from pathlib import Path
import csv

def mine_hard_negatives(manifest_tsv, out_tsv, max_rows=300):
    manifest_tsv = Path(manifest_tsv)
    out_tsv = Path(out_tsv)
    rows = []

    lines = manifest_tsv.read_text().splitlines()[:max_rows]
    for line in lines:
        path_str, label_str = line.split('	')
        label = int(label_str)
        if label != 0:
            continue  # mine only from real videos

        p = Path(path_str)
        if not p.is_absolute():
            p = BACKEND_ROOT / p

        try:
            r = run_full_cvi_pipeline(str(p))
        except Exception:
            continue

        pred = int(r.get('video_fake', 0))
        if label == 0 and pred == 1:
            rows.append((str(p), label, pred))

    out_tsv.parent.mkdir(parents=True, exist_ok=True)
    with out_tsv.open('w', newline='') as f:
        w = csv.writer(f, delimiter='	')
        for row in rows:
            w.writerow(row)

    print(f'Hard negatives: {len(rows)} -> {out_tsv}')
    return out_tsv

# Example usage:
# hn_file = mine_hard_negatives(BACKEND_ROOT/'eval_manifest_balanced.tsv', BACKEND_ROOT/'data/processed/hard_negatives_mined.tsv', max_rows=500)
# run_train_experiment('bce_auto_hn', '--loss bce --causal-weight 0.0 --use-weighted-sampler --weight-application auto --hard-negative-file data/processed/hard_negatives_mined.tsv --hard-negative-weight 6.0', epochs=20, patience=6)

# %%
# Plot experiment metrics from leaderboard CSV
import pandas as pd
import matplotlib.pyplot as plt

lb_path = BACKEND_ROOT / 'models' / 'nb_cls_leaderboard.csv'
if not lb_path.exists():
    raise FileNotFoundError(f'Leaderboard not found: {lb_path}. Run the sweep cell first.')

df = pd.read_csv(lb_path)
if 'error' in df.columns:
    df_ok = df[df['error'].isna()].copy()
else:
    df_ok = df.copy()

if df_ok.empty:
    raise RuntimeError('No successful experiments to plot. Check sweep errors first.')

# Keep a stable ranking for plotting.
sort_cols = [c for c in ['strict_pass', 'targets_met', 'target_gap', 'sel_score', 'auc'] if c in df_ok.columns]
if sort_cols:
    ascending = [False if c in {'strict_pass', 'targets_met', 'sel_score', 'auc'} else True for c in sort_cols]
    df_ok = df_ok.sort_values(sort_cols, ascending=ascending)

df_ok = df_ok.reset_index(drop=True)
df_ok['rank'] = df_ok.index + 1

metric_cols = [c for c in ['acc', 'prec', 'rec', 'f1', 'spec', 'bal_acc', 'auc', 'pr_auc', 'sel_score'] if c in df_ok.columns]
if not metric_cols:
    raise RuntimeError('No metric columns found in leaderboard.')

fig, axes = plt.subplots(1, 2, figsize=(16, 5), dpi=120)

# 1) Line plot by rank
for m in [c for c in ['acc', 'prec', 'rec', 'f1', 'spec', 'bal_acc'] if c in metric_cols]:
    axes[0].plot(df_ok['rank'], df_ok[m], marker='o', label=m)
axes[0].set_title('Classification Metrics by Experiment Rank')
axes[0].set_xlabel('Rank (best to worst)')
axes[0].set_ylabel('Score')
axes[0].set_ylim(0, 1.02)
axes[0].grid(alpha=0.25)
axes[0].legend(loc='lower left', ncols=3)

# 2) Bar plot for auc/sel_score style metrics
bar_metrics = [c for c in ['auc', 'pr_auc', 'sel_score'] if c in metric_cols]
if bar_metrics:
    x = range(len(df_ok))
    width = 0.8 / len(bar_metrics)
    for i, m in enumerate(bar_metrics):
        axes[1].bar([v + i * width for v in x], df_ok[m], width=width, label=m)
    axes[1].set_xticks([v + width * (len(bar_metrics)-1) / 2 for v in x])
    axes[1].set_xticklabels(df_ok['name'], rotation=45, ha='right')
    axes[1].set_ylim(0, 1.02)
    axes[1].set_title('AUC / Selection Score by Experiment')
    axes[1].grid(axis='y', alpha=0.25)
    axes[1].legend(loc='lower left')
else:
    axes[1].axis('off')

plt.tight_layout()
plt.show()

# Quick text summary table
show_cols = [c for c in ['name', 'strict_pass', 'targets_met', 'target_gap', 'acc', 'prec', 'rec', 'f1', 'spec', 'bal_acc', 'auc', 'sel_score', 'thr'] if c in df_ok.columns]
display(df_ok[show_cols])

# %% [markdown]
# ## 7) Scripted evidence + classification sweeps
# Use the shell scripts added under `backend/scripts/` so every run is reproducible and auditable.

# %%
from pathlib import Path
import os, subprocess, json
import pandas as pd

if 'BACKEND_ROOT' not in globals() or not (Path(BACKEND_ROOT) / 'src').exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

ARCHIVE_SCRIPT = BACKEND_ROOT / 'scripts' / 'archive_cfn_evidence.sh'
RUNNER_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_cfn_feature_upgrade.sh'
for p in [ARCHIVE_SCRIPT, RUNNER_SCRIPT]:
    if not p.exists():
        raise FileNotFoundError(f'Missing required script: {p}')

def run_cmd(cmd, env=None, cwd=BACKEND_ROOT):
    cmd = [str(x) for x in cmd]
    print('\n$ ' + ' '.join(cmd))
    subprocess.run(cmd, cwd=str(cwd), env=env, check=True)

print('BACKEND_ROOT   =', BACKEND_ROOT)
print('ARCHIVE_SCRIPT =', ARCHIVE_SCRIPT)
print('RUNNER_SCRIPT  =', RUNNER_SCRIPT)

# %% [markdown]
# ### 7.1 Snapshot Baseline Evidence
# **What this step tries:** archive current artifacts (metrics, logs, model pointers) before launching new runs so comparisons remain reproducible.

# %%
# 7.1 Snapshot current state before new sweeps
SNAPSHOT_PRE_TAG = 'pre_cls_sweep_notebook'
run_cmd([ARCHIVE_SCRIPT, SNAPSHOT_PRE_TAG])

# %% [markdown]
# ### 7.2 Optional Feature/Split Refresh
# **What this step tries:** refresh processed features and regenerate split CSVs when upstream extraction logic changed.
#
# **Readout to check:** split sizes and label/domain distributions are as expected.

# %%
# 7.2 (Optional) Regenerate feature CSV, then rebuild mixed train/val/test splits
# Keep this OFF on Mac hosts where MediaPipe FaceMesh may fail to initialize (NSGL issue).
REBUILD_FEATURES = False

if REBUILD_FEATURES:
    proc_csv = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset.csv'
    backup_csv = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_pre_rebuild_backup.csv'
    if proc_csv.exists():
        proc_csv.replace(backup_csv)
        print('Backed up:', backup_csv)

    env = os.environ.copy()
    env.setdefault('PYTHONPATH', '.')
    env.setdefault('MEDIAPIPE_DISABLE_GPU', '1')
    env.setdefault('CUDA_VISIBLE_DEVICES', '-1')
    env.setdefault('MPLCONFIGDIR', '/tmp/mpl')
    run_cmd(['.venv/bin/python', '-m', 'src.preprocessing.batch_feature_extractor'], env=env)

    if not proc_csv.exists() and backup_csv.exists():
        backup_csv.replace(proc_csv)
        raise RuntimeError('Feature rebuild produced no CSV; restored backup.')

env = os.environ.copy()
env.setdefault('PYTHONPATH', '.')
run_cmd([
    '.venv/bin/python', 'scripts/build_mixed_splits.py',
    '--processed-csv', 'data/processed/causal_multimodal_dataset.csv',
], env=env)

# %% [markdown]
# ### 7.3 Scripted Ablation Sweep
# **What this step tries:** run a reproducible set of classification-focused ablations (loss/weighting/sampler variants) and save structured logs.

# %%
# 7.3 Run scripted classification-focused experiments (ablation v2)
from pathlib import Path
import os, subprocess

# Self-heal if setup cell was not executed.
if 'BACKEND_ROOT' not in globals() or not Path(BACKEND_ROOT).exists() or not (Path(BACKEND_ROOT) / 'src').exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

if 'RUNNER_SCRIPT' not in globals() or not Path(RUNNER_SCRIPT).exists():
    RUNNER_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_cfn_feature_upgrade.sh'

if not Path(RUNNER_SCRIPT).exists():
    raise FileNotFoundError(f'Missing run script: {RUNNER_SCRIPT}')

if 'run_cmd' not in globals():
    def run_cmd(cmd, env=None, cwd=BACKEND_ROOT):
        cmd = [str(x) for x in cmd]
        print('\n$ ' + ' '.join(cmd))
        subprocess.run(cmd, cwd=str(cwd), env=env, check=True)


def run_scripted_experiment(run_tag: str, **env_overrides):
    env = os.environ.copy()
    for k, v in env_overrides.items():
        env[k] = str(v)
    env['RUN_TAG'] = run_tag
    run_cmd([RUNNER_SCRIPT], env=env)

COMMON = dict(
    TRAIN_SOURCE='all',
    CLASS_BALANCE_MODE='none',
    WEIGHT_APPLICATION='auto',
    SELECTION_THRESHOLD_MODE='target',
    SELECTION_METRIC='hybrid_robust',
    TARGET_PRECISION='0.70',
    TARGET_RECALL='0.70',
    TARGET_PRIORITY='balanced_acc',
    EPOCHS='50',
    PATIENCE='10',
    MIN_DOMAIN_SPEC='0.05',
    MIN_DOMAIN_REC='0.20',
)

# A) Baseline features (control)
run_scripted_experiment(
    'featup_ablate_baseline_auto_v2_nb',
    FEATURE_PROFILE='baseline',
    HARD_NEG_WEIGHT='1.0',
    **COMMON,
)

# B) Extended features with original hard-negative emphasis
run_scripted_experiment(
    'featup_ablate_extended_auto_v2_nb',
    FEATURE_PROFILE='extended',
    HARD_NEG_WEIGHT='6.0',
    **COMMON,
)

# C) Extended features with reduced hard-negative emphasis
run_scripted_experiment(
    'featup_ablate_extended_auto_hn1_v2_nb',
    FEATURE_PROFILE='extended',
    HARD_NEG_WEIGHT='1.0',
    **COMMON,
)

# %% [markdown]
# ### 7.4 Threshold Report Consolidation
# **What this step tries:** aggregate `cfn_threshold_report.json` outputs into one comparable summary table.
#
# **Readout to check:** operating thresholds and tradeoffs (`precision/recall/specificity`) across runs.

# %%
# 7.4 Summarize threshold reports for selected runs
from pathlib import Path
import json
import pandas as pd

if 'BACKEND_ROOT' not in globals() or not Path(BACKEND_ROOT).exists() or not (Path(BACKEND_ROOT) / 'src').exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

RUN_TAGS = [
    'featup_target_v1_20260308',
    'featup_ablate_baseline_auto_v2_nb',
    'featup_ablate_extended_auto_v2_nb',
    'featup_ablate_extended_auto_hn1_v2_nb',
]

rows = []
for tag in RUN_TAGS:
    rp = BACKEND_ROOT / 'models' / tag / 'cfn_threshold_report.json'
    if not rp.exists():
        rows.append({'run_tag': tag, 'error': f'missing report: {rp}'})
        continue

    rep = json.loads(rp.read_text())
    chosen = rep.get('chosen_epoch_report', {})
    overall = chosen.get('overall_at_selection_threshold', {})
    rows.append({
        'run_tag': tag,
        'checkpoint_meets_constraints': rep.get('best_checkpoint_met_constraints'),
        'targets_met': chosen.get('targets_met'),
        'target_gap': chosen.get('target_shortfall'),
        'auc': chosen.get('val_auc'),
        'pr_auc': chosen.get('pr_auc'),
        'sel_score': chosen.get('selection_score'),
        'acc': overall.get('acc'),
        'prec': overall.get('prec'),
        'rec': overall.get('rec'),
        'spec': overall.get('spec'),
        'bal_acc': overall.get('bal_acc'),
        'f1': overall.get('f1'),
        'worst_spec': chosen.get('worst_spec'),
        'worst_rec': chosen.get('worst_rec'),
        'report_path': str(rp),
    })

summary = pd.DataFrame(rows)
if 'error' not in summary.columns:
    summary = summary.sort_values(
        by=['checkpoint_meets_constraints', 'targets_met', 'target_gap', 'sel_score', 'auc', 'bal_acc', 'f1'],
        ascending=[False, False, True, False, False, False, False],
    )
display(summary)

summary_out = BACKEND_ROOT / 'models' / 'experiment_logs' / 'nb_scripted_target_summary.csv'
summary.to_csv(summary_out, index=False)
print('Saved summary to', summary_out)

# %% [markdown]
# ## 8) Overall classification metrics + visual graphs
#
# Use this section after your scripted runs to view overall Accuracy, Precision, Recall, and F1 (FI).

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Resolve backend root if setup cells were skipped.
if 'BACKEND_ROOT' not in globals() or not Path(BACKEND_ROOT).exists() or not (Path(BACKEND_ROOT) / 'src').exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

# Prefer in-memory summary from previous cell; else load from saved CSV artifacts.
if 'summary' in globals() and isinstance(summary, pd.DataFrame) and not summary.empty:
    metrics_df = summary.copy()
else:
    candidates = [
        BACKEND_ROOT / 'models' / 'experiment_logs' / 'nb_scripted_target_summary.csv',
        BACKEND_ROOT / 'models' / 'nb_cls_leaderboard.csv',
    ]
    src_path = next((p for p in candidates if p.exists()), None)
    if src_path is None:
        raise FileNotFoundError('No summary CSV found. Run the summary/leaderboard cells first.')
    metrics_df = pd.read_csv(src_path)
    print('Loaded metrics from:', src_path)

# Normalize common column names.
rename_map = {
    'name': 'run_tag',
    'accuracy': 'acc',
    'precision': 'prec',
    'recall': 'rec',
    'fi': 'f1',  # support typo/alias
}
metrics_df = metrics_df.rename(columns={k: v for k, v in rename_map.items() if k in metrics_df.columns})

for col in ['acc', 'prec', 'rec', 'f1', 'auc', 'pr_auc', 'sel_score']:
    if col in metrics_df.columns:
        metrics_df[col] = pd.to_numeric(metrics_df[col], errors='coerce')

required = [c for c in ['acc', 'prec', 'rec', 'f1'] if c in metrics_df.columns]
if len(required) < 4:
    raise RuntimeError(f'Missing one or more required metrics columns. Found: {required}')

metrics_df = metrics_df.dropna(subset=['acc', 'prec', 'rec', 'f1'], how='all').copy()
if metrics_df.empty:
    raise RuntimeError('No valid metric rows found to plot.')

if 'run_tag' not in metrics_df.columns:
    metrics_df['run_tag'] = [f'run_{i+1}' for i in range(len(metrics_df))]

sort_cols = [c for c in ['checkpoint_meets_constraints', 'targets_met', 'target_gap', 'f1', 'bal_acc', 'auc'] if c in metrics_df.columns]
if sort_cols:
    asc = [False if c in {'checkpoint_meets_constraints', 'targets_met', 'f1', 'bal_acc', 'auc'} else True for c in sort_cols]
    metrics_df = metrics_df.sort_values(sort_cols, ascending=asc)
else:
    metrics_df = metrics_df.sort_values(['f1', 'acc'], ascending=False)

metrics_df = metrics_df.reset_index(drop=True)
display_cols = [c for c in ['run_tag', 'acc', 'prec', 'rec', 'f1', 'spec', 'bal_acc', 'auc', 'pr_auc', 'sel_score', 'target_gap'] if c in metrics_df.columns]
display(metrics_df[display_cols])

overall_stats = metrics_df[['acc', 'prec', 'rec', 'f1']].agg(['mean', 'max', 'min']).T
overall_stats.columns = ['mean', 'best', 'worst']
print('Overall summary (across runs):')
display(overall_stats)

top_n = min(10, len(metrics_df))
plot_df = metrics_df.head(top_n).copy()

fig, axes = plt.subplots(1, 2, figsize=(18, 6), dpi=120)

# Graph 1: grouped bars for core classification metrics.
x = np.arange(top_n)
core_metrics = ['acc', 'prec', 'rec', 'f1']
width = 0.18
for i, m in enumerate(core_metrics):
    axes[0].bar(x + (i - 1.5) * width, plot_df[m], width=width, label=m.upper())
axes[0].set_title('Overall Classification Metrics by Run')
axes[0].set_ylabel('Score')
axes[0].set_ylim(0, 1.02)
axes[0].set_xticks(x)
axes[0].set_xticklabels(plot_df['run_tag'], rotation=45, ha='right')
axes[0].grid(axis='y', alpha=0.25)
axes[0].legend(loc='lower left')

# Graph 2: trend lines for broader metrics (if present).
line_metrics = [m for m in ['acc', 'prec', 'rec', 'f1', 'spec', 'bal_acc', 'auc'] if m in plot_df.columns]
for m in line_metrics:
    axes[1].plot(plot_df['run_tag'], plot_df[m], marker='o', linewidth=2, label=m)
axes[1].set_title('Metric Trend Across Top Runs')
axes[1].set_ylabel('Score')
axes[1].set_ylim(0, 1.02)
axes[1].grid(alpha=0.25)
axes[1].tick_params(axis='x', rotation=45)
axes[1].legend(loc='lower left', ncols=2)

plt.tight_layout()
plt.show()

best_idx = metrics_df['f1'].idxmax()
best_row = metrics_df.loc[best_idx]
print('Best run by F1 :')
display(best_row[['run_tag', 'acc', 'prec', 'rec', 'f1'] + [c for c in ['spec', 'bal_acc', 'auc', 'sel_score'] if c in metrics_df.columns]])

# %% [markdown]
# ## 9) Auto-Discover Robust Top Runs + Held-Out Evaluation
#
# This section avoids stale hardcoded run tags. It auto-loads recent reports, ranks by robustness, then evaluates top runs on held-out val/test CSVs.

# %%
from pathlib import Path
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

if 'BACKEND_ROOT' not in globals() or not Path(BACKEND_ROOT).exists() or not (Path(BACKEND_ROOT) / 'src').exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

MODELS_DIR = BACKEND_ROOT / 'models'
report_paths = sorted(
    MODELS_DIR.glob('*/cfn_threshold_report.json'),
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)

rows = []
for rp in report_paths:
    run_tag = rp.parent.name
    try:
        rep = json.loads(rp.read_text())
    except Exception as exc:  # noqa: BLE001
        rows.append({'run_tag': run_tag, 'error': f'parse_error: {exc}', 'report_path': str(rp)})
        continue

    chosen = rep.get('chosen_epoch_report', {})
    overall = chosen.get('overall_at_selection_threshold', {})

    row = {
        'run_tag': run_tag,
        'checkpoint_meets_constraints': bool(rep.get('best_checkpoint_met_constraints', False)),
        'targets_met': chosen.get('targets_met'),
        'target_gap': chosen.get('target_shortfall'),
        'epoch': chosen.get('epoch'),
        'thr': chosen.get('selection_threshold'),
        'mode': chosen.get('selection_threshold_mode'),
        'auc': chosen.get('val_auc'),
        'pr_auc': chosen.get('pr_auc'),
        'sel_score': chosen.get('selection_score'),
        'acc': overall.get('acc'),
        'prec': overall.get('prec'),
        'rec': overall.get('rec'),
        'spec': overall.get('spec'),
        'bal_acc': overall.get('bal_acc'),
        'f1': overall.get('f1'),
        'worst_spec': chosen.get('worst_spec'),
        'worst_rec': chosen.get('worst_rec'),
        'report_path': str(rp),
    }
    rows.append(row)

auto_summary = pd.DataFrame(rows)
if auto_summary.empty:
    raise RuntimeError('No threshold reports found under models/*/cfn_threshold_report.json')

num_cols = [
    'target_gap', 'auc', 'pr_auc', 'sel_score', 'acc', 'prec', 'rec', 'spec',
    'bal_acc', 'f1', 'worst_spec', 'worst_rec', 'thr', 'epoch'
]
for col in num_cols:
    if col in auto_summary.columns:
        auto_summary[col] = pd.to_numeric(auto_summary[col], errors='coerce')

for c in ['targets_met', 'checkpoint_meets_constraints']:
    if c in auto_summary.columns:
        auto_summary[c] = auto_summary[c].fillna(False).astype(bool)

auto_summary['robust_score'] = (
    0.40 * auto_summary['bal_acc'].fillna(0) +
    0.30 * auto_summary['worst_spec'].fillna(0) +
    0.30 * auto_summary['worst_rec'].fillna(0)
)

# Keep only rows that have core metrics.
auto_summary = auto_summary.dropna(subset=['acc', 'prec', 'rec', 'f1', 'bal_acc', 'worst_spec', 'worst_rec'], how='any')

auto_summary = auto_summary.sort_values(
    by=['checkpoint_meets_constraints', 'targets_met', 'robust_score', 'sel_score', 'auc', 'f1'],
    ascending=[False, False, False, False, False, False],
)
auto_summary = auto_summary.reset_index(drop=True)

TOP_K = 8
top_runs = auto_summary.head(TOP_K).copy()
display_cols = [
    'run_tag', 'checkpoint_meets_constraints', 'targets_met', 'target_gap',
    'acc', 'prec', 'rec', 'f1', 'spec', 'bal_acc', 'worst_spec', 'worst_rec',
    'auc', 'sel_score', 'thr', 'robust_score'
]
display(top_runs[display_cols])

fig, axes = plt.subplots(1, 2, figsize=(18, 6), dpi=120)

x = np.arange(len(top_runs))
w = 0.18
core = ['acc', 'prec', 'rec', 'f1']
for i, m in enumerate(core):
    axes[0].bar(x + (i - 1.5) * w, top_runs[m], width=w, label=m.upper())
axes[0].set_title('Top Runs: Core Classification Metrics')
axes[0].set_ylim(0, 1.02)
axes[0].set_xticks(x)
axes[0].set_xticklabels(top_runs['run_tag'], rotation=45, ha='right')
axes[0].grid(axis='y', alpha=0.25)
axes[0].legend(loc='lower left')

robust_metrics = ['bal_acc', 'worst_spec', 'worst_rec', 'auc']
for m in robust_metrics:
    axes[1].plot(top_runs['run_tag'], top_runs[m], marker='o', linewidth=2, label=m)
axes[1].set_title('Top Runs: Robustness-Focused Metrics')
axes[1].set_ylim(0, 1.02)
axes[1].grid(alpha=0.25)
axes[1].tick_params(axis='x', rotation=45)
axes[1].legend(loc='lower left')

plt.tight_layout()
plt.show()

TOP_RUN_TAGS = top_runs['run_tag'].tolist()
print('TOP_RUN_TAGS for held-out evaluation:', TOP_RUN_TAGS)

# %%
import pickle
import joblib
import torch
import numpy as np
import pandas as pd

from src.cvi.feature_schema import resolve_feature_columns
from src.training.train_cfn import build_feature_matrix, infer_domain_labels, compute_domain_metrics
from src.modules.causal_fusion import CausalFusionNetworkV2

VAL_CSV_CANDIDATES = [
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_val_plus_dfdc_part2.csv',
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_val_plus_dfdc.csv',
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_val.csv',
]
TEST_CSV_CANDIDATES = [
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_test_plus_dfdc_part2.csv',
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_test_plus_dfdc.csv',
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_test.csv',
]

VAL_CSV = next((p for p in VAL_CSV_CANDIDATES if p.exists()), None)
TEST_CSV = next((p for p in TEST_CSV_CANDIDATES if p.exists()), None)
if VAL_CSV is None or TEST_CSV is None:
    raise FileNotFoundError('Missing val/test split CSVs for held-out evaluation.')

print('Using VAL_CSV :', VAL_CSV)
print('Using TEST_CSV:', TEST_CSV)

def _safe_load_scaler(path):
    if not path.exists():
        return None
    try:
        with open(path, 'rb') as f:
            return pickle.load(f)
    except Exception:
        return joblib.load(path)

def _infer_threshold(report_obj):
    chosen = report_obj.get('chosen_epoch_report', {})
    thr = chosen.get('selection_threshold')
    return float(thr) if thr is not None else 0.5

def _eval_run_on_split(run_tag, split_name, csv_path, threshold_override=None, feature_profile='extended'):
    model_dir = BACKEND_ROOT / 'models' / run_tag
    report_path = model_dir / 'cfn_threshold_report.json'
    model_path = model_dir / 'cfn_emb.pth'
    scaler_path = model_dir / 'cfn_scaler.pkl'

    if not report_path.exists() or not model_path.exists():
        return {'run_tag': run_tag, 'split': split_name, 'error': 'missing model/report artifacts'}

    rep = json.loads(report_path.read_text())
    threshold = float(threshold_override) if threshold_override is not None else _infer_threshold(rep)

    df = pd.read_csv(csv_path)
    av_cols, phys_cols = resolve_feature_columns(df.columns, use_embeddings=True, profile=feature_profile)
    X_av = build_feature_matrix(df, av_cols, name='AV features')
    X_phys = build_feature_matrix(df, phys_cols, name='Physical features')
    y = df['label'].astype(int).to_numpy()
    dom = infer_domain_labels(df)

    scaler = _safe_load_scaler(scaler_path)
    if isinstance(scaler, dict):
        if 'av' in scaler:
            try:
                X_av = scaler['av'].transform(X_av)
            except Exception:
                pass
        if 'phys' in scaler:
            try:
                X_phys = scaler['phys'].transform(X_phys)
            except Exception:
                pass

    state = torch.load(model_path, map_location='cpu')
    av_dim = int(state.get('av_branch.0.weight', torch.empty(0)).shape[1]) if isinstance(state, dict) else X_av.shape[1]
    phys_dim = int(state.get('physical_branch.0.weight', torch.empty(0)).shape[1]) if isinstance(state, dict) else X_phys.shape[1]
    if av_dim <= 0:
        av_dim = X_av.shape[1]
    if phys_dim <= 0:
        phys_dim = X_phys.shape[1]

    model = CausalFusionNetworkV2(av_dim=av_dim, phys_dim=phys_dim)
    model.load_state_dict(state, strict=False)
    model.eval()

    with torch.no_grad():
        probs = model(
            torch.from_numpy(X_av.astype(np.float32)),
            torch.from_numpy(X_phys.astype(np.float32)),
        ).squeeze(1).cpu().numpy()

    met = compute_domain_metrics(y, probs, dom, threshold=threshold)
    o = met['overall']

    return {
        'run_tag': run_tag,
        'split': split_name,
        'thr': threshold,
        'acc': o['acc'],
        'prec': o['prec'],
        'rec': o['rec'],
        'spec': o['spec'],
        'bal_acc': o['bal_acc'],
        'f1': o['f1'],
        'worst_spec': met['worst_spec'],
        'worst_rec': met['worst_rec'],
        'macro_bal_acc': met['macro_bal_acc'],
    }

selected_runs = TOP_RUN_TAGS[:5] if 'TOP_RUN_TAGS' in globals() else []
if not selected_runs:
    raise RuntimeError('TOP_RUN_TAGS is empty. Run the previous cell first.')

eval_rows = []
for run_tag in selected_runs:
    for split_name, split_csv in [('val', VAL_CSV), ('test', TEST_CSV)]:
        try:
            eval_rows.append(_eval_run_on_split(run_tag, split_name, split_csv))
        except Exception as exc:  # noqa: BLE001
            eval_rows.append({'run_tag': run_tag, 'split': split_name, 'error': str(exc)})

heldout_eval = pd.DataFrame(eval_rows)
display(heldout_eval)

ok = heldout_eval[heldout_eval.get('error').isna()] if 'error' in heldout_eval.columns else heldout_eval
if not ok.empty:
    ok = ok.copy()
    ok['robust_score'] = 0.40 * ok['bal_acc'] + 0.30 * ok['worst_spec'] + 0.30 * ok['worst_rec']

    test_ok = ok[ok['split'] == 'test'].sort_values(
        ['robust_score', 'bal_acc', 'worst_spec', 'worst_rec', 'f1'],
        ascending=False
    )
    print('Top test runs by robust_score:')
    display(test_ok[['run_tag', 'thr', 'acc', 'prec', 'rec', 'f1', 'spec', 'bal_acc', 'worst_spec', 'worst_rec', 'robust_score']])

    pivot_metrics = ok.pivot(index='run_tag', columns='split', values='worst_rec')
    print('Worst-domain recall (val vs test):')
    display(pivot_metrics)

    fig, ax = plt.subplots(figsize=(11, 5), dpi=120)
    test_plot = test_ok.reset_index(drop=True)
    x = np.arange(len(test_plot))
    w = 0.25
    ax.bar(x - w, test_plot['worst_rec'], width=w, label='worst_rec')
    ax.bar(x, test_plot['worst_spec'], width=w, label='worst_spec')
    ax.bar(x + w, test_plot['bal_acc'], width=w, label='bal_acc')
    ax.set_title('Held-out Test Robustness Metrics by Run')
    ax.set_xticks(x)
    ax.set_xticklabels(test_plot['run_tag'], rotation=45, ha='right')
    ax.set_ylim(0, 1.02)
    ax.grid(axis='y', alpha=0.25)
    ax.legend(loc='lower left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 10) Full-FaceMesh Threshold Sweep + Deployment Lock
#
# Use this after training `featup_fullfacemesh_v1` to pick a robust deployment threshold under explicit constraints (worst-domain recall/specificity + precision/recall).

# %%
from pathlib import Path
import json
import pickle
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from IPython.display import display

from src.cvi.feature_schema import resolve_feature_columns
from src.training.train_cfn import build_feature_matrix, infer_domain_labels, compute_domain_metrics
from src.modules.causal_fusion import CausalFusionNetworkV2

if 'BACKEND_ROOT' not in globals() or not Path(BACKEND_ROOT).exists() or not (Path(BACKEND_ROOT) / 'src').exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

MODEL_TAG = 'featup_fullfacemesh_v1'
MODEL_DIR = BACKEND_ROOT / 'models' / MODEL_TAG
REPORT_PATH = MODEL_DIR / 'cfn_threshold_report.json'
MODEL_PATH = MODEL_DIR / 'cfn_emb.pth'
SCALER_PATH = MODEL_DIR / 'cfn_scaler.pkl'

TEST_CSV_CANDIDATES = [
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_test_full_facemesh.csv',
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_test_plus_dfdc_part2.csv',
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_test_plus_dfdc.csv',
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_test.csv',
]
TEST_CSV = next((p for p in TEST_CSV_CANDIDATES if p.exists()), None)

if not MODEL_PATH.exists() or not REPORT_PATH.exists():
    raise FileNotFoundError(f'Missing model/report artifacts under {MODEL_DIR}')
if TEST_CSV is None:
    raise FileNotFoundError('No suitable test CSV found for threshold sweep.')

# ---- Constraints (edit if needed) ----
MIN_WORST_SPEC = 0.45
MIN_WORST_REC = 0.45
MIN_PREC = 0.97
MIN_REC = 0.75

print('MODEL_DIR:', MODEL_DIR)
print('TEST_CSV :', TEST_CSV)

def _safe_load_scaler(path: Path):
    if not path.exists():
        return None
    try:
        with open(path, 'rb') as f:
            return pickle.load(f)
    except Exception:
        return joblib.load(path)

def _match_dim(arr: np.ndarray, dim: int) -> np.ndarray:
    if arr.shape[1] == dim:
        return arr
    if arr.shape[1] > dim:
        return arr[:, :dim]
    pad = np.zeros((arr.shape[0], dim - arr.shape[1]), dtype=arr.dtype)
    return np.concatenate([arr, pad], axis=1)

# 1) Load dataset + features
df = pd.read_csv(TEST_CSV)
av_cols, phys_cols = resolve_feature_columns(df.columns, use_embeddings=True, profile='extended')
X_av = build_feature_matrix(df, av_cols, name='AV features')
X_phys = build_feature_matrix(df, phys_cols, name='Physical features')
y = df['label'].astype(int).to_numpy()
domains = infer_domain_labels(df)

# 2) Apply scaler if available
scaler = _safe_load_scaler(SCALER_PATH)
if isinstance(scaler, dict):
    if 'av' in scaler:
        try:
            X_av = scaler['av'].transform(X_av)
        except Exception:
            pass
    if 'phys' in scaler:
        try:
            X_phys = scaler['phys'].transform(X_phys)
        except Exception:
            pass

# 3) Load model and predict probabilities
state = torch.load(MODEL_PATH, map_location='cpu')
av_dim = int(state.get('av_branch.0.weight', torch.empty(0)).shape[1]) if isinstance(state, dict) else X_av.shape[1]
phys_dim = int(state.get('physical_branch.0.weight', torch.empty(0)).shape[1]) if isinstance(state, dict) else X_phys.shape[1]
if av_dim <= 0:
    av_dim = X_av.shape[1]
if phys_dim <= 0:
    phys_dim = X_phys.shape[1]

X_av = _match_dim(X_av, av_dim)
X_phys = _match_dim(X_phys, phys_dim)

model = CausalFusionNetworkV2(av_dim=av_dim, phys_dim=phys_dim)
model.load_state_dict(state, strict=False)
model.eval()
with torch.no_grad():
    probs = model(
        torch.from_numpy(X_av.astype(np.float32)),
        torch.from_numpy(X_phys.astype(np.float32)),
    ).squeeze(1).cpu().numpy()

rep = json.loads(REPORT_PATH.read_text())
default_thr = float(rep.get('chosen_epoch_report', {}).get('selection_threshold', 0.5))

# 4) Sweep thresholds
grid = np.unique(np.concatenate([
    np.linspace(max(0.0, float(np.min(probs))), min(1.0, float(np.max(probs))), 401),
    np.quantile(probs, np.linspace(0, 1, 201)),
    np.array([default_thr], dtype=float),
]))
grid = np.clip(grid, 0.0, 1.0)

rows = []
for t in grid:
    met = compute_domain_metrics(y, probs, domains, threshold=float(t))
    o = met['overall']
    rows.append({
        'thr': float(t),
        'acc': o['acc'],
        'prec': o['prec'],
        'rec': o['rec'],
        'spec': o['spec'],
        'bal_acc': o['bal_acc'],
        'f1': o['f1'],
        'worst_spec': met['worst_spec'],
        'worst_rec': met['worst_rec'],
        'macro_bal_acc': met['macro_bal_acc'],
    })

sweep_df = pd.DataFrame(rows).sort_values('thr').reset_index(drop=True)
sweep_df['feasible'] = (
    (sweep_df['worst_spec'] >= MIN_WORST_SPEC) &
    (sweep_df['worst_rec'] >= MIN_WORST_REC) &
    (sweep_df['prec'] >= MIN_PREC) &
    (sweep_df['rec'] >= MIN_REC)
)
sweep_df['robust_score'] = (
    0.40 * sweep_df['bal_acc'] +
    0.30 * sweep_df['worst_spec'] +
    0.30 * sweep_df['worst_rec']
)

feasible_df = sweep_df[sweep_df['feasible']].copy()
if feasible_df.empty:
    print('No thresholds satisfy all constraints; using best robust_score overall.')
    pick_df = sweep_df.copy()
else:
    pick_df = feasible_df.copy()

pick_df = pick_df.sort_values(
    by=['robust_score', 'bal_acc', 'worst_spec', 'worst_rec', 'f1'],
    ascending=False
)
best = pick_df.iloc[0]
best_thr = float(best['thr'])

print('Default threshold from report:', round(default_thr, 6))
print('Feasible threshold count    :', int(feasible_df.shape[0]))
print('Recommended threshold       :', round(best_thr, 6))
display_cols = ['thr', 'feasible', 'acc', 'prec', 'rec', 'spec', 'bal_acc', 'f1', 'worst_spec', 'worst_rec', 'robust_score']
display(pick_df.head(15)[display_cols])

# Plot curves across thresholds + selected threshold
fig, axes = plt.subplots(1, 2, figsize=(18, 6), dpi=120)
axes[0].plot(sweep_df['thr'], sweep_df['worst_rec'], label='worst_rec', linewidth=2)
axes[0].plot(sweep_df['thr'], sweep_df['worst_spec'], label='worst_spec', linewidth=2)
axes[0].plot(sweep_df['thr'], sweep_df['bal_acc'], label='bal_acc', linewidth=2)
axes[0].axhline(MIN_WORST_REC, color='tab:blue', linestyle='--', alpha=0.5, label='min_worst_rec')
axes[0].axhline(MIN_WORST_SPEC, color='tab:orange', linestyle='--', alpha=0.5, label='min_worst_spec')
axes[0].axvline(best_thr, color='black', linestyle='--', alpha=0.8, label=f'selected={best_thr:.4f}')
axes[0].set_title('Robustness Metrics vs Threshold')
axes[0].set_xlabel('Threshold')
axes[0].set_ylabel('Score')
axes[0].set_ylim(0, 1.02)
axes[0].grid(alpha=0.25)
axes[0].legend(loc='lower left')

axes[1].plot(sweep_df['thr'], sweep_df['prec'], label='precision', linewidth=2)
axes[1].plot(sweep_df['thr'], sweep_df['rec'], label='recall', linewidth=2)
axes[1].plot(sweep_df['thr'], sweep_df['f1'], label='f1', linewidth=2)
axes[1].axhline(MIN_PREC, color='tab:green', linestyle='--', alpha=0.5, label='min_precision')
axes[1].axhline(MIN_REC, color='tab:red', linestyle='--', alpha=0.5, label='min_recall')
axes[1].axvline(best_thr, color='black', linestyle='--', alpha=0.8, label=f'selected={best_thr:.4f}')
axes[1].set_title('Classification Metrics vs Threshold')
axes[1].set_xlabel('Threshold')
axes[1].set_ylabel('Score')
axes[1].set_ylim(0, 1.02)
axes[1].grid(alpha=0.25)
axes[1].legend(loc='lower left')

plt.tight_layout()
plt.show()

print('\nRecommended deployment env:')
print(f'CFN_USE_EMBEDDINGS=true')
print(f'CFN_EMB_MODEL_PATH=models/{MODEL_TAG}/cfn_emb.pth')
print(f'CFN_SCALER_PATH=models/{MODEL_TAG}/cfn_scaler.pkl')
print(f'CFN_PROB_THRESH={best_thr:.6f}')
# Out:
# MODEL_DIR: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/featup_fullfacemesh_v1
# TEST_CSV : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_dataset_mixed_test_full_facemesh.csv
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# Physical features: zero-filled 5 missing columns: ['video_motion_noise_ratio', 'video_shape_noise_ratio', 'video_temporal_instability', 'video_detection_dropout', 'video_compression_proxy']
# No thresholds satisfy all constraints; using best robust_score overall.
# Default threshold from report: 0.295384
# Feasible threshold count    : 0
# Recommended threshold       : 0.974717
#           thr  feasible       acc      prec       rec  spec   bal_acc  \
# 593  0.974717     False  0.031564  1.000000  0.000888   1.0  0.500444
# 594  0.976453     False  0.031564  1.000000  0.000888   1.0  0.500444
# ...

# %% [markdown]
# ## 11) Thesis Target Audit (Strict Pass/Fail)
#
# Audits current runs against the thesis thresholds from `CausalX_Metric_Thresholds.docx`.
#
# Targets enforced:
# - FakeAVCeleb: `acc>=0.90`, `prec>=0.87`, `rec>=0.88`, `f1>=0.88`, `auc>=0.91`
# - Optional cross-dataset guard (disabled by default below): `dfdc_auc>=0.75` and `auc_drop(fake_auc - dfdc_auc)<=0.12`

# %%
from pathlib import Path
import json
import pickle
import joblib
import numpy as np
import pandas as pd
import torch
from sklearn.metrics import roc_auc_score, average_precision_score
from IPython.display import display

from src.cvi.feature_schema import resolve_feature_columns
from src.training.train_cfn import build_feature_matrix, infer_domain_labels, compute_domain_metrics
from src.modules.causal_fusion import CausalFusionNetworkV2

# Resolve backend root if setup cells were skipped.
if 'BACKEND_ROOT' not in globals() or not Path(BACKEND_ROOT).exists() or not (Path(BACKEND_ROOT) / 'src').exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

TARGETS = {
    'fake_acc': 0.90,
    'fake_prec': 0.87,
    'fake_rec': 0.88,
    'fake_f1': 0.88,
    'fake_auc': 0.91,
    'dfdc_auc': 0.75,
    'max_auc_drop': 0.12,
    'enforce_cross_dataset': False,
}


def _safe_load_scaler(path: Path):
    if not path.exists():
        return None
    try:
        with open(path, 'rb') as f:
            return pickle.load(f)
    except Exception:
        return joblib.load(path)


def _match_dim(arr: np.ndarray, dim: int) -> np.ndarray:
    if arr.shape[1] == dim:
        return arr
    if arr.shape[1] > dim:
        return arr[:, :dim]
    pad = np.zeros((arr.shape[0], dim - arr.shape[1]), dtype=arr.dtype)
    return np.concatenate([arr, pad], axis=1)


def _norm_domains(domains):
    return np.array([str(d).strip().lower() for d in domains])


def _domain_masks(domains_norm):
    fake_mask = np.array(['fake' in d for d in domains_norm])
    dfdc_mask = np.array(['dfdc' in d for d in domains_norm])
    return fake_mask, dfdc_mask


def _safe_auc(y_true: np.ndarray, y_prob: np.ndarray):
    if y_true.size == 0:
        return np.nan
    if np.unique(y_true).size < 2:
        return np.nan
    return float(roc_auc_score(y_true, y_prob))


def _safe_pr_auc(y_true: np.ndarray, y_prob: np.ndarray):
    if y_true.size == 0:
        return np.nan
    if np.unique(y_true).size < 2:
        return np.nan
    return float(average_precision_score(y_true, y_prob))


def _pick_eval_csv(run_tag: str):
    run_lower = run_tag.lower()
    base = BACKEND_ROOT / 'data' / 'processed'
    if 'fullfacemesh' in run_lower:
        candidates = [
            base / 'causal_multimodal_dataset_mixed_test_full_facemesh.csv',
            base / 'causal_multimodal_dataset_mixed_test_plus_dfdc_part2.csv',
            base / 'causal_multimodal_dataset_mixed_test_plus_dfdc.csv',
            base / 'causal_multimodal_dataset_mixed_test.csv',
        ]
    else:
        candidates = [
            base / 'causal_multimodal_dataset_mixed_test_plus_dfdc_part2.csv',
            base / 'causal_multimodal_dataset_mixed_test_plus_dfdc.csv',
            base / 'causal_multimodal_dataset_mixed_test.csv',
            base / 'causal_multimodal_dataset_mixed_test_full_facemesh.csv',
        ]
    return next((p for p in candidates if p.exists()), None)


def _infer_threshold(report_obj: dict) -> float:
    chosen = report_obj.get('chosen_epoch_report', {})
    thr = chosen.get('selection_threshold')
    return float(thr) if thr is not None else 0.5


def _eval_run(run_tag: str):
    model_dir = BACKEND_ROOT / 'models' / run_tag
    model_path = model_dir / 'cfn_emb.pth'
    scaler_path = model_dir / 'cfn_scaler.pkl'
    report_path = model_dir / 'cfn_threshold_report.json'
    eval_csv = _pick_eval_csv(run_tag)

    if eval_csv is None:
        return {'run_tag': run_tag, 'error': 'no evaluation CSV found'}
    if not model_path.exists() or not report_path.exists():
        return {'run_tag': run_tag, 'eval_csv': str(eval_csv), 'error': 'missing model/report artifacts'}

    rep = json.loads(report_path.read_text())
    thr = _infer_threshold(rep)

    df = pd.read_csv(eval_csv)
    av_cols, phys_cols = resolve_feature_columns(df.columns, use_embeddings=True, profile='auto')
    X_av = build_feature_matrix(df, av_cols, name='AV features')
    X_phys = build_feature_matrix(df, phys_cols, name='Physical features')
    y = df['label'].astype(int).to_numpy()
    domains = _norm_domains(infer_domain_labels(df))

    scaler = _safe_load_scaler(scaler_path)
    if isinstance(scaler, dict):
        if 'av' in scaler:
            try:
                X_av = scaler['av'].transform(X_av)
            except Exception:
                pass
        if 'phys' in scaler:
            try:
                X_phys = scaler['phys'].transform(X_phys)
            except Exception:
                pass

    state = torch.load(model_path, map_location='cpu')
    av_dim = int(state.get('av_branch.0.weight', torch.empty(0)).shape[1]) if isinstance(state, dict) else X_av.shape[1]
    phys_dim = int(state.get('physical_branch.0.weight', torch.empty(0)).shape[1]) if isinstance(state, dict) else X_phys.shape[1]
    if av_dim <= 0:
        av_dim = X_av.shape[1]
    if phys_dim <= 0:
        phys_dim = X_phys.shape[1]

    X_av = _match_dim(X_av, av_dim)
    X_phys = _match_dim(X_phys, phys_dim)

    model = CausalFusionNetworkV2(av_dim=av_dim, phys_dim=phys_dim)
    model.load_state_dict(state, strict=False)
    model.eval()
    with torch.no_grad():
        probs = model(
            torch.from_numpy(X_av.astype(np.float32)),
            torch.from_numpy(X_phys.astype(np.float32)),
        ).squeeze(1).cpu().numpy()

    fake_mask, dfdc_mask = _domain_masks(domains)
    if fake_mask.sum() == 0 or dfdc_mask.sum() == 0:
        return {
            'run_tag': run_tag,
            'eval_csv': str(eval_csv),
            'thr': thr,
            'n': int(len(y)),
            'n_fake_domain': int(fake_mask.sum()),
            'n_dfdc_domain': int(dfdc_mask.sum()),
            'error': 'missing FakeAVCeleb or DFDC samples in eval set',
        }

    y_fake = y[fake_mask]
    p_fake = probs[fake_mask]
    y_dfdc = y[dfdc_mask]
    p_dfdc = probs[dfdc_mask]

    fake_overall = compute_domain_metrics(y_fake, p_fake, ['fakeavceleb'] * len(y_fake), threshold=thr)['overall']
    dfdc_overall = compute_domain_metrics(y_dfdc, p_dfdc, ['dfdc'] * len(y_dfdc), threshold=thr)['overall']

    fake_auc = _safe_auc(y_fake, p_fake)
    fake_pr_auc = _safe_pr_auc(y_fake, p_fake)
    dfdc_auc = _safe_auc(y_dfdc, p_dfdc)
    dfdc_pr_auc = _safe_pr_auc(y_dfdc, p_dfdc)
    auc_drop = (fake_auc - dfdc_auc) if (not np.isnan(fake_auc) and not np.isnan(dfdc_auc)) else np.nan

    return {
        'run_tag': run_tag,
        'eval_csv': str(eval_csv),
        'thr': float(thr),
        'n': int(len(y)),
        'n_fake_domain': int(len(y_fake)),
        'n_dfdc_domain': int(len(y_dfdc)),
        'fake_acc': float(fake_overall['acc']),
        'fake_prec': float(fake_overall['prec']),
        'fake_rec': float(fake_overall['rec']),
        'fake_f1': float(fake_overall['f1']),
        'fake_spec': float(fake_overall['spec']),
        'fake_bal_acc': float(fake_overall['bal_acc']),
        'fake_auc': float(fake_auc) if not np.isnan(fake_auc) else np.nan,
        'fake_pr_auc': float(fake_pr_auc) if not np.isnan(fake_pr_auc) else np.nan,
        'dfdc_acc': float(dfdc_overall['acc']),
        'dfdc_prec': float(dfdc_overall['prec']),
        'dfdc_rec': float(dfdc_overall['rec']),
        'dfdc_f1': float(dfdc_overall['f1']),
        'dfdc_spec': float(dfdc_overall['spec']),
        'dfdc_bal_acc': float(dfdc_overall['bal_acc']),
        'dfdc_auc': float(dfdc_auc) if not np.isnan(dfdc_auc) else np.nan,
        'dfdc_pr_auc': float(dfdc_pr_auc) if not np.isnan(dfdc_pr_auc) else np.nan,
        'auc_drop_fake_minus_dfdc': float(auc_drop) if not np.isnan(auc_drop) else np.nan,
    }


# Run selection priority: explicit best globals -> TOP_RUN_TAGS -> recent reports on disk.
run_tags = []
if 'CURRENT_BEST_MODEL_TAG' in globals() and CURRENT_BEST_MODEL_TAG:
    run_tags.append(str(CURRENT_BEST_MODEL_TAG))
if 'MODEL_TAG' in globals() and MODEL_TAG:
    run_tags.append(str(MODEL_TAG))
if 'TOP_RUN_TAGS' in globals() and isinstance(TOP_RUN_TAGS, list):
    run_tags.extend([str(x) for x in TOP_RUN_TAGS[:8]])

if not run_tags:
    recent_reports = sorted(
        (BACKEND_ROOT / 'models').glob('*/cfn_threshold_report.json'),
        key=lambda p: p.stat().st_mtime,
        reverse=True,
    )
    run_tags = [p.parent.name for p in recent_reports[:8]]

RUN_TAGS_TO_AUDIT = list(dict.fromkeys([r for r in run_tags if isinstance(r, str) and r]))
print('RUN_TAGS_TO_AUDIT:', RUN_TAGS_TO_AUDIT)

rows = []
for run_tag in RUN_TAGS_TO_AUDIT:
    try:
        rows.append(_eval_run(run_tag))
    except Exception as exc:  # noqa: BLE001
        rows.append({'run_tag': run_tag, 'error': str(exc)})

TARGET_AUDIT_DF = pd.DataFrame(rows)

if TARGET_AUDIT_DF.empty:
    raise RuntimeError('No runs audited.')

if 'error' in TARGET_AUDIT_DF.columns:
    err_df = TARGET_AUDIT_DF[TARGET_AUDIT_DF['error'].notna()].copy()
    if not err_df.empty:
        print('Runs with evaluation errors:')
        display(err_df[['run_tag', 'error']])

ok = TARGET_AUDIT_DF[TARGET_AUDIT_DF.get('error').isna()].copy() if 'error' in TARGET_AUDIT_DF.columns else TARGET_AUDIT_DF.copy()
if ok.empty:
    raise RuntimeError('All audited runs failed to evaluate.')

# Strict pass/fail columns against thesis thresholds.
ok['pass_fake_acc'] = ok['fake_acc'] >= TARGETS['fake_acc']
ok['pass_fake_prec'] = ok['fake_prec'] >= TARGETS['fake_prec']
ok['pass_fake_rec'] = ok['fake_rec'] >= TARGETS['fake_rec']
ok['pass_fake_f1'] = ok['fake_f1'] >= TARGETS['fake_f1']
ok['pass_fake_auc'] = ok['fake_auc'] >= TARGETS['fake_auc']
ok['pass_dfdc_auc'] = ok['dfdc_auc'] >= TARGETS['dfdc_auc']
ok['pass_auc_drop'] = ok['auc_drop_fake_minus_dfdc'] <= TARGETS['max_auc_drop']

pass_cols = [
    'pass_fake_acc',
    'pass_fake_prec',
    'pass_fake_rec',
    'pass_fake_f1',
    'pass_fake_auc',
]
if TARGETS.get('enforce_cross_dataset', False):
    pass_cols.extend(['pass_dfdc_auc', 'pass_auc_drop'])
ok['all_targets_met'] = ok[pass_cols].all(axis=1)

# Positive-only gap accumulation for ranking.
ok['gap_fake_acc'] = np.maximum(0.0, TARGETS['fake_acc'] - ok['fake_acc'])
ok['gap_fake_prec'] = np.maximum(0.0, TARGETS['fake_prec'] - ok['fake_prec'])
ok['gap_fake_rec'] = np.maximum(0.0, TARGETS['fake_rec'] - ok['fake_rec'])
ok['gap_fake_f1'] = np.maximum(0.0, TARGETS['fake_f1'] - ok['fake_f1'])
ok['gap_fake_auc'] = np.maximum(0.0, TARGETS['fake_auc'] - ok['fake_auc'])
ok['gap_dfdc_auc'] = np.maximum(0.0, TARGETS['dfdc_auc'] - ok['dfdc_auc'])
ok['gap_auc_drop'] = np.maximum(0.0, ok['auc_drop_fake_minus_dfdc'] - TARGETS['max_auc_drop'])
gap_terms = [
    'gap_fake_acc',
    'gap_fake_prec',
    'gap_fake_rec',
    'gap_fake_f1',
    'gap_fake_auc',
]
if TARGETS.get('enforce_cross_dataset', False):
    gap_terms.extend(['gap_dfdc_auc', 'gap_auc_drop'])
ok['target_gap_total'] = ok[gap_terms].sum(axis=1)

ok = ok.sort_values(
    by=['all_targets_met', 'target_gap_total', 'fake_f1', 'fake_acc', 'dfdc_auc'],
    ascending=[False, True, False, False, False],
).reset_index(drop=True)

TARGET_AUDIT_DF = ok

show_cols = [
    'run_tag', 'eval_csv', 'thr', 'all_targets_met', 'target_gap_total',
    'fake_acc', 'fake_prec', 'fake_rec', 'fake_f1', 'fake_auc',
    'dfdc_auc', 'auc_drop_fake_minus_dfdc',
    'pass_fake_acc', 'pass_fake_prec', 'pass_fake_rec', 'pass_fake_f1',
    'pass_fake_auc', 'pass_dfdc_auc', 'pass_auc_drop',
]
display(TARGET_AUDIT_DF[show_cols])

best_row = TARGET_AUDIT_DF.iloc[0]
print('\nBest audited run:', best_row['run_tag'])
print('All strict targets met:', bool(best_row['all_targets_met']))
print('Total target gap:', round(float(best_row['target_gap_total']), 6))

BEST_TARGET_AUDIT_ROW = best_row.to_dict()
BEST_TARGET_AUDIT_RUN_TAG = str(best_row['run_tag'])
BEST_TARGET_AUDIT_ALL_MET = bool(best_row['all_targets_met'])

out_dir = BACKEND_ROOT / 'models' / 'experiment_logs'
out_dir.mkdir(parents=True, exist_ok=True)
out_csv = out_dir / 'nb_thesis_target_audit.csv'
TARGET_AUDIT_DF.to_csv(out_csv, index=False)
print('Saved strict target audit to:', out_csv)
# Out:
# RUN_TAGS_TO_AUDIT: ['featup_fullfacemesh_v1']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
#                   run_tag                                           eval_csv  \
# 0  featup_fullfacemesh_v1  /Users/venturit/Documents/GitHub/FYP/CausalX-P...
#
#         thr  all_targets_met  target_gap_total  fake_acc  fake_prec  fake_rec  \
# 0  0.295384            False          0.376101  0.917982   0.976591   0.93853
#
#     fake_f1  fake_auc  dfdc_auc  auc_drop_fake_minus_dfdc  pass_fake_acc  \
# 0  0.957182  0.533899  0.442286                  0.091613           True
#
#    pass_fake_prec  pass_fake_rec  pass_fake_f1  pass_fake_auc  pass_dfdc_auc  \
# 0            True           True          True          False          False
#
#    pass_auc_drop
# 0           True
# Best audited run: featup_fullfacemesh_v1
# All strict targets met: False
# Total target gap: 0.376101
# ...

# %% [markdown]
# ## 12) Automated Gap-Closing Loop (Audit -> Retrain Grid -> Re-Audit)
#
# This section automates steps 1-3:
# 1. Audit many recent runs with strict thesis targets.
# 2. Launch a retrain grid (optional, toggle `RUN_GRID=True`).
# 3. Re-audit only the new grid runs and compare against current best.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from IPython.display import display

if 'BACKEND_ROOT' not in globals() or BACKEND_ROOT is None:
    raise RuntimeError('BACKEND_ROOT is missing. Run setup cells first.')
if '_eval_run' not in globals() or 'TARGETS' not in globals():
    raise RuntimeError('Run Section 11 first so strict-audit helpers are available.')


def _apply_strict_thresholds(df: pd.DataFrame, targets: dict) -> pd.DataFrame:
    out = df.copy()

    out['pass_fake_acc'] = out['fake_acc'] >= targets['fake_acc']
    out['pass_fake_prec'] = out['fake_prec'] >= targets['fake_prec']
    out['pass_fake_rec'] = out['fake_rec'] >= targets['fake_rec']
    out['pass_fake_f1'] = out['fake_f1'] >= targets['fake_f1']
    out['pass_fake_auc'] = out['fake_auc'] >= targets['fake_auc']
    out['pass_dfdc_auc'] = out['dfdc_auc'] >= targets['dfdc_auc']
    out['pass_auc_drop'] = out['auc_drop_fake_minus_dfdc'] <= targets['max_auc_drop']

    pass_cols = [
        'pass_fake_acc',
        'pass_fake_prec',
        'pass_fake_rec',
        'pass_fake_f1',
        'pass_fake_auc',
    ]
    if targets.get('enforce_cross_dataset', False):
        pass_cols.extend(['pass_dfdc_auc', 'pass_auc_drop'])
    out['all_targets_met'] = out[pass_cols].all(axis=1)

    out['gap_fake_acc'] = np.maximum(0.0, targets['fake_acc'] - out['fake_acc'])
    out['gap_fake_prec'] = np.maximum(0.0, targets['fake_prec'] - out['fake_prec'])
    out['gap_fake_rec'] = np.maximum(0.0, targets['fake_rec'] - out['fake_rec'])
    out['gap_fake_f1'] = np.maximum(0.0, targets['fake_f1'] - out['fake_f1'])
    out['gap_fake_auc'] = np.maximum(0.0, targets['fake_auc'] - out['fake_auc'])
    out['gap_dfdc_auc'] = np.maximum(0.0, targets['dfdc_auc'] - out['dfdc_auc'])
    out['gap_auc_drop'] = np.maximum(0.0, out['auc_drop_fake_minus_dfdc'] - targets['max_auc_drop'])

    gap_terms = [
        'gap_fake_acc',
        'gap_fake_prec',
        'gap_fake_rec',
        'gap_fake_f1',
        'gap_fake_auc',
    ]
    if targets.get('enforce_cross_dataset', False):
        gap_terms.extend(['gap_dfdc_auc', 'gap_auc_drop'])
    out['target_gap_total'] = out[gap_terms].sum(axis=1)

    out = out.sort_values(
        by=['all_targets_met', 'target_gap_total', 'fake_f1', 'fake_acc', 'dfdc_auc'],
        ascending=[False, True, False, False, False],
    ).reset_index(drop=True)
    return out


def run_strict_audit(run_tags):
    run_tags = [str(x) for x in run_tags if isinstance(x, str) and str(x).strip()]
    run_tags = list(dict.fromkeys(run_tags))
    rows = []
    for run_tag in run_tags:
        try:
            rows.append(_eval_run(run_tag))
        except Exception as exc:  # noqa: BLE001
            rows.append({'run_tag': run_tag, 'error': str(exc)})

    raw_df = pd.DataFrame(rows)
    if raw_df.empty:
        return raw_df, raw_df, raw_df

    if 'error' in raw_df.columns:
        err_df = raw_df[raw_df['error'].notna()].copy()
        ok_df = raw_df[raw_df['error'].isna()].copy()
    else:
        err_df = pd.DataFrame(columns=['run_tag', 'error'])
        ok_df = raw_df.copy()

    if ok_df.empty:
        return raw_df, err_df, ok_df

    scored_df = _apply_strict_thresholds(ok_df, TARGETS)
    return raw_df, err_df, scored_df


# ---- Audit recent runs automatically ----
MODELS_DIR = BACKEND_ROOT / 'models'
MAX_RECENT_RUNS = 30
recent_reports = sorted(
    MODELS_DIR.glob('*/cfn_threshold_report.json'),
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)
RECENT_RUN_TAGS = [p.parent.name for p in recent_reports[:MAX_RECENT_RUNS]]
print('Auditing recent runs:', len(RECENT_RUN_TAGS))

AUTO_AUDIT_RAW_DF, AUTO_AUDIT_ERR_DF, AUTO_AUDIT_DF = run_strict_audit(RECENT_RUN_TAGS)

if not AUTO_AUDIT_ERR_DF.empty:
    print('Runs with errors during audit:')
    display(AUTO_AUDIT_ERR_DF[['run_tag', 'error']])

if AUTO_AUDIT_DF.empty:
    raise RuntimeError('No valid runs were audited.')

show_cols = [
    'run_tag', 'thr', 'all_targets_met', 'target_gap_total',
    'fake_acc', 'fake_prec', 'fake_rec', 'fake_f1', 'fake_auc',
    'dfdc_auc', 'auc_drop_fake_minus_dfdc',
    'pass_fake_acc', 'pass_fake_prec', 'pass_fake_rec', 'pass_fake_f1',
    'pass_fake_auc', 'pass_dfdc_auc', 'pass_auc_drop',
]
display(AUTO_AUDIT_DF[show_cols].head(20))

AUTO_AUDIT_BEST_ROW = AUTO_AUDIT_DF.iloc[0].to_dict()
AUTO_AUDIT_BEST_RUN_TAG = str(AUTO_AUDIT_DF.iloc[0]['run_tag'])
print('Best audited run:', AUTO_AUDIT_BEST_RUN_TAG)
print('Best target gap :', round(float(AUTO_AUDIT_DF.iloc[0]['target_gap_total']), 6))
print('All targets met :', bool(AUTO_AUDIT_DF.iloc[0]['all_targets_met']))

out_dir = BACKEND_ROOT / 'models' / 'experiment_logs'
out_dir.mkdir(parents=True, exist_ok=True)
out_csv = out_dir / 'nb_thesis_target_audit_all_recent.csv'
AUTO_AUDIT_DF.to_csv(out_csv, index=False)
print('Saved recent strict-audit leaderboard to:', out_csv)
# Out:
# Auditing recent runs: 30
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# ...

# %%
import os
import subprocess
import time
import pandas as pd
from IPython.display import display

if 'BACKEND_ROOT' not in globals() or BACKEND_ROOT is None:
    raise RuntimeError('BACKEND_ROOT is missing. Run setup cells first.')

# Toggle to actually start training grid.
RUN_GRID = True

train_candidates = [
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_train_plus_dfdc_part2.csv',
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_train_plus_dfdc.csv',
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_train.csv',
]
fullmesh_train_candidates = [
    BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_mixed_train_full_facemesh.csv',
]
hard_neg_candidates = [
    BACKEND_ROOT / 'data/processed/hard_negatives_mixed_v4.tsv',
    BACKEND_ROOT / 'data/processed/hard_negatives_mixed.tsv',
]

train_data = next((p for p in train_candidates if p.exists()), None)
fullmesh_train_data = next((p for p in fullmesh_train_candidates if p.exists()), train_data)
hard_neg_file = next((p for p in hard_neg_candidates if p.exists()), None)

if train_data is None:
    raise FileNotFoundError('No train CSV found for grid runs.')

# Small, focused grid to improve ranking/generalization first.
RETRAIN_GRID = [
    {
        'RUN_TAG': 'thesis_grid_ext_part2_bal_v1_nb',
        'DATA_PATH': str(train_data),
        'FEATURE_PROFILE': 'extended',
        'CLASS_BALANCE_MODE': 'downsample',
        'WEIGHT_APPLICATION': 'loss',
        'HARD_NEG_WEIGHT': '3.0',
        'CAUSAL_WEIGHT': '0.10',
    },
    {
        'RUN_TAG': 'thesis_grid_ext_part2_bal_v2_nb',
        'DATA_PATH': str(train_data),
        'FEATURE_PROFILE': 'extended',
        'CLASS_BALANCE_MODE': 'downsample',
        'WEIGHT_APPLICATION': 'loss',
        'HARD_NEG_WEIGHT': '5.0',
        'CAUSAL_WEIGHT': '0.15',
    },
    {
        'RUN_TAG': 'thesis_grid_fullmesh_bal_v1_nb',
        'DATA_PATH': str(fullmesh_train_data),
        'FEATURE_PROFILE': 'extended',
        'CLASS_BALANCE_MODE': 'downsample',
        'WEIGHT_APPLICATION': 'loss',
        'HARD_NEG_WEIGHT': '4.0',
        'CAUSAL_WEIGHT': '0.10',
    },
]

COMMON_ENV = {
    'TRAIN_SOURCE': 'all',
    'SELECTION_METRIC': 'hybrid_robust',
    'SELECTION_THRESHOLD_MODE': 'target',
    'TARGET_ACC': '0.90',
    'TARGET_PRECISION': '0.88',
    'TARGET_RECALL': '0.88',
    'TARGET_F1': '0.90',
    'TARGET_PRIORITY': 'f1',
    'MIN_DOMAIN_SPEC': '0.20',
    'MIN_DOMAIN_REC': '0.45',
    'EPOCHS': '50',
    'PATIENCE': '12',
    'BATCH_SIZE': '128',
    'LR': '2e-4',
    'WEIGHT_DECAY': '1e-4',
    'SEED': '42',
}
if hard_neg_file is not None:
    COMMON_ENV['HARD_NEG_FILE'] = str(hard_neg_file)

print('Planned retrain grid:')
display(pd.DataFrame(RETRAIN_GRID))
print('RUN_GRID =', RUN_GRID)

GRID_RUN_LOG_DF = pd.DataFrame()
if RUN_GRID:
    logs = []
    script_path = BACKEND_ROOT / 'scripts' / 'run_cfn_feature_upgrade.sh'
    for cfg in RETRAIN_GRID:
        env = os.environ.copy()
        env.update(COMMON_ENV)
        env.update({k: str(v) for k, v in cfg.items()})

        cmd = ['bash', str(script_path)]
        t0 = time.time()
        print('\nRunning grid item:', cfg['RUN_TAG'])
        proc = subprocess.run(
            cmd,
            cwd=BACKEND_ROOT,
            env=env,
            text=True,
            capture_output=True,
        )
        dt = time.time() - t0

        log_tail = '\n'.join((proc.stdout or '').splitlines()[-15:])
        logs.append({
            'run_tag': cfg['RUN_TAG'],
            'returncode': proc.returncode,
            'duration_sec': round(dt, 1),
            'log_tail': log_tail,
        })
        print('Return code:', proc.returncode, '| Duration (s):', round(dt, 1))
        if proc.returncode != 0:
            print('Last stdout lines:\n', log_tail)
            err_tail = '\n'.join((proc.stderr or '').splitlines()[-10:])
            if err_tail:
                print('Last stderr lines:\n', err_tail)

    GRID_RUN_LOG_DF = pd.DataFrame(logs)
    display(GRID_RUN_LOG_DF[['run_tag', 'returncode', 'duration_sec']])
    out_dir = BACKEND_ROOT / 'models' / 'experiment_logs'
    out_dir.mkdir(parents=True, exist_ok=True)
    out_csv = out_dir / 'nb_thesis_retrain_grid_log.csv'
    GRID_RUN_LOG_DF.to_csv(out_csv, index=False)
    print('Saved grid run log to:', out_csv)
else:
    print('Grid not executed. Set RUN_GRID=True and rerun this cell to start training jobs.')
# Out:
# Planned retrain grid:
#                            RUN_TAG  \
# 0  thesis_grid_ext_part2_bal_v1_nb
# 1  thesis_grid_ext_part2_bal_v2_nb
# 2   thesis_grid_fullmesh_bal_v1_nb
#
#                                            DATA_PATH FEATURE_PROFILE  \
# 0  /Users/venturit/Documents/GitHub/FYP/CausalX-P...        extended
# 1  /Users/venturit/Documents/GitHub/FYP/CausalX-P...        extended
# 2  /Users/venturit/Documents/GitHub/FYP/CausalX-P...        extended
#
#   CLASS_BALANCE_MODE WEIGHT_APPLICATION HARD_NEG_WEIGHT CAUSAL_WEIGHT
# 0         downsample               loss             3.0          0.10
# 1         downsample               loss             5.0          0.15
# 2         downsample               loss             4.0          0.10
# RUN_GRID = True
#
# Running grid item: thesis_grid_ext_part2_bal_v1_nb
# Return code: 0 | Duration (s): 3.9
#
# Running grid item: thesis_grid_ext_part2_bal_v2_nb
# Return code: 0 | Duration (s): 2.4
#
# ...

# %%
import pandas as pd
from IPython.display import display

if 'run_strict_audit' not in globals():
    raise RuntimeError('run_strict_audit helper missing. Run the first Section 12 cell first.')

if 'RETRAIN_GRID' not in globals() or not RETRAIN_GRID:
    raise RuntimeError('RETRAIN_GRID is missing. Run the grid-definition cell first.')

new_run_tags = [str(cfg['RUN_TAG']) for cfg in RETRAIN_GRID]
compare_tags = list(new_run_tags)
if 'AUTO_AUDIT_BEST_RUN_TAG' in globals() and AUTO_AUDIT_BEST_RUN_TAG:
    compare_tags.append(str(AUTO_AUDIT_BEST_RUN_TAG))

GRID_AUDIT_RAW_DF, GRID_AUDIT_ERR_DF, GRID_AUDIT_DF = run_strict_audit(compare_tags)

if not GRID_AUDIT_ERR_DF.empty:
    print('Grid runs with errors (likely not trained yet):')
    display(GRID_AUDIT_ERR_DF[['run_tag', 'error']])

if GRID_AUDIT_DF.empty:
    raise RuntimeError('No grid runs could be audited. If RUN_GRID=False, train first.')

show_cols = [
    'run_tag', 'thr', 'all_targets_met', 'target_gap_total',
    'fake_acc', 'fake_prec', 'fake_rec', 'fake_f1', 'fake_auc',
    'dfdc_auc', 'auc_drop_fake_minus_dfdc',
]
display(GRID_AUDIT_DF[show_cols])

best = GRID_AUDIT_DF.iloc[0]
print('Best after grid audit:', best['run_tag'])
print('All strict targets met:', bool(best['all_targets_met']))
print('Total target gap:', round(float(best['target_gap_total']), 6))

GRID_AUDIT_BEST_RUN_TAG = str(best['run_tag'])
GRID_AUDIT_BEST_ROW = best.to_dict()

out_dir = BACKEND_ROOT / 'models' / 'experiment_logs'
out_dir.mkdir(parents=True, exist_ok=True)
out_csv = out_dir / 'nb_thesis_grid_audit.csv'
GRID_AUDIT_DF.to_csv(out_csv, index=False)
print('Saved grid strict-audit results to:', out_csv)
# Out:
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
#                                              run_tag       thr  \
# 0  fakeav_auc_sweep_v2_obj_20260319_043619_p1_r06...  0.479418
# 1                    thesis_grid_ext_part2_bal_v1_nb  0.417339
# 2                     thesis_grid_fullmesh_bal_v1_nb  0.417321
# 3                    thesis_grid_ext_part2_bal_v2_nb  0.417150
#
#    all_targets_met  target_gap_total  fake_acc  fake_prec  fake_rec   fake_f1  \
# 0            False          0.314705  0.968441   0.977195  0.990814  0.983957
# ...

# %% [markdown]
# ## 16) FakeAVCeleb Target Pipeline (Balanced Splits + AUC Sweep)
#
# This section operationalizes the three-step pipeline for FakeAVCeleb target pursuit:
# 1. Build balanced FakeAVCeleb train/val/test splits.
# 2. Run AUC-focused CFN hyperparameter sweep.
# 3. Produce target-audit leaderboard (`acc>=0.90`, `prec>=0.87`, `rec>=0.88`, `f1>=0.88`, `auc>=0.91`).

# %% [markdown]
# ### Dataset Imbalance Handling Used In This Notebook
# FakeAVCeleb here is strongly skewed toward fake samples, so the notebook uses a layered mitigation strategy:
#
# - **Balanced split builders** for controlled runs (`random_label_balanced`, `scenario_balanced_label`, `four_way_balanced`).
# - **Balanced holdout evaluation** (val/test real=fake) while optionally keeping an imbalanced full-train pool for realism.
# - **Training-time weighting** via `--use-weighted-sampler`, `--weight-application`, and optional `--class-balanced-loss`.
# - **Pair-aware sampling and hard-example phases** (`--paired-rf-sampling`, phase2 hard negatives/positives) to protect real-class specificity.
# - **Scenario-aware balancing** so positives are not dominated by one manipulation type.
#
# When comparing runs, prioritize `balanced_acc`, `specificity`, `F1_real`, and per-scenario metrics in addition to overall `AUC`.

# %%
from pathlib import Path
import json
import subprocess
import pandas as pd

if 'BACKEND_ROOT' not in globals() or BACKEND_ROOT is None:
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

PYTHON = BACKEND_ROOT / '.venv' / 'bin' / 'python'
if not PYTHON.exists():
    PYTHON = Path('python3')

TARGETS_FAKEAV = {
    'acc': 0.90,
    'prec': 0.87,
    'rec': 0.88,
    'f1': 0.88,
    'auc': 0.91,
}

BAL_TRAIN = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_bal_train.csv'
BAL_VAL = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_bal_val.csv'
BAL_TEST = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_bal_test.csv'
BAL_META = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_bal_meta.json'

print('BACKEND_ROOT :', BACKEND_ROOT)
print('PYTHON       :', PYTHON)
print('TARGETS      :', TARGETS_FAKEAV)
# Out:
# BACKEND_ROOT : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend
# PYTHON       : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python
# TARGETS      : {'acc': 0.9, 'prec': 0.87, 'rec': 0.88, 'f1': 0.88, 'auc': 0.91}

# %% [markdown]
# ### 16.1 Build Balanced FakeAV Splits
# **What this step tries:** construct leakage-safe FakeAV-only train/val/test CSVs with explicit class balancing for controlled baseline training.
#
# **Readout to check:** split metadata (`label_counts`, `scenario_counts`) and any sampling constraints.

# %%
# Step 1: Build balanced FakeAVCeleb splits
cmd = [
    str(PYTHON), 'scripts/build_fakeav_balanced_splits.py',
    '--processed-csv', 'data/processed/causal_multimodal_dataset.csv',
    '--test-size', '0.15',
    '--val-size', '0.15',
    '--seed', '42',
    '--out-train-csv', str(BAL_TRAIN.relative_to(BACKEND_ROOT)),
    '--out-val-csv', str(BAL_VAL.relative_to(BACKEND_ROOT)),
    '--out-test-csv', str(BAL_TEST.relative_to(BACKEND_ROOT)),
    '--out-meta-json', str(BAL_META.relative_to(BACKEND_ROOT)),
]
print('CMD:', ' '.join(cmd))
res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
print(res.stdout)
if res.returncode != 0:
    print(res.stderr)
    raise RuntimeError(f'build_fakeav_balanced_splits.py failed: code={res.returncode}')

meta = json.loads(BAL_META.read_text())
print('Balanced split meta:')
print(json.dumps(meta['splits'], indent=2))
# Out:
# CMD: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python scripts/build_fakeav_balanced_splits.py --processed-csv data/processed/causal_multimodal_dataset.csv --test-size 0.15 --val-size 0.15 --seed 42 --out-train-csv data/processed/causal_multimodal_dataset_fakeav_bal_train.csv --out-val-csv data/processed/causal_multimodal_dataset_fakeav_bal_val.csv --out-test-csv data/processed/causal_multimodal_dataset_fakeav_bal_test.csv --out-meta-json data/processed/causal_multimodal_dataset_fakeav_bal_meta.json
# Balanced FakeAVCeleb split build complete.
# balanced: rows=998 labels={0: 499, 1: 499} scenarios={'0:0': 499, '0:1': 10, '1:0': 238, '1:1': 251}
# train: rows=698 labels={0: 349, 1: 349} scenarios={'0:0': 349, '0:1': 7, '1:0': 169, '1:1': 173}
# val: rows=150 labels={0: 75, 1: 75} scenarios={'0:0': 75, '0:1': 2, '1:0': 33, '1:1': 40}
# test: rows=150 labels={0: 75, 1: 75} scenarios={'0:0': 75, '0:1': 1, '1:0': 36, '1:1': 38}
# outputs:
# ...

# %% [markdown]
# ### 16.2 AUC Sweep + Target Leaderboard
# **What this step tries:** run a hyperparameter sweep oriented toward ranking quality (`AUC`) and then audit against thesis targets.
#
# **Readout to check:** top runs by AUC and which target constraints are feasible simultaneously.

# %%
# Step 2 + 3: Run AUC-focused sweep and build target leaderboard
RUN_SWEEP = False  # Set True to execute full sweep from notebook
SWEEP_PREFIX = 'fakeav_auc_sweep_bal'

if RUN_SWEEP:
    cmd = [
        str(PYTHON), 'scripts/sweep_fakeav_auc.py',
        '--train-csv', str(BAL_TRAIN.relative_to(BACKEND_ROOT)),
        '--val-csv', str(BAL_VAL.relative_to(BACKEND_ROOT)),
        '--test-csv', str(BAL_TEST.relative_to(BACKEND_ROOT)),
        '--feature-profile', 'extended',
        '--epochs', '35',
        '--patience', '8',
        '--max-runs', '10',
        '--eval-threshold-source', 'val_target',
    '--eval-threshold-priority', 'balanced_acc',
    '--run-prefix', SWEEP_PREFIX,
    ]
    print('CMD:', ' '.join(cmd))
    res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
    print(res.stdout)
    if res.returncode != 0:
        print(res.stderr)
        raise RuntimeError(f'sweep_fakeav_auc.py failed: code={res.returncode}')
else:
    print('RUN_SWEEP=False (skipping sweep execution).')
    print('Set RUN_SWEEP=True to run Step 2/3 from notebook.')
# Out:
# RUN_SWEEP=False (skipping sweep execution).
# Set RUN_SWEEP=True to run Step 2/3 from notebook.

# %% [markdown]
# ### 16.3 Reachability Report
# **What this step tries:** load the latest sweep artifacts and report whether strict target combinations are reachable on this data regime.

# %%
# Load latest sweep artifacts and report reachability
logs_root = BACKEND_ROOT / 'models/experiment_logs'
candidates = sorted(
    [p for p in logs_root.glob('fakeav_auc_sweep_bal*') if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)
if not candidates:
    raise RuntimeError('No fakeav_auc_sweep_bal* experiment log directories found.')

latest = candidates[0]
leaderboard = latest / 'leaderboard_sorted.csv'
summary = latest / 'reachability_summary.json'

print('Using sweep dir:', latest)
if not leaderboard.exists():
    raise RuntimeError(f'Missing leaderboard: {leaderboard}')

lb = pd.read_csv(leaderboard)
display_cols = [
    'run_tag', 'all_targets_met', 'target_gap_total',
    'test_auc', 'test_acc', 'test_prec', 'test_rec', 'test_f1', 'val_auc'
]
display(lb[[c for c in display_cols if c in lb.columns]].head(15))

print('Runs meeting AUC>=0.91:', int((lb['test_auc'] >= 0.91).sum()), '/', len(lb))
print('Runs meeting all targets:', int(lb['all_targets_met'].sum()), '/', len(lb))
print('Best test AUC:', float(lb['test_auc'].max()))

if summary.exists():
    print('reachability_summary.json:')
    print(summary.read_text())
# Out:
# Using sweep dir: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/experiment_logs/fakeav_auc_sweep_bal_20260310_20260310_165459
#                                              run_tag  all_targets_met  \
# 0  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
# 1  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
# 2  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
# 3  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
# 4  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
# 5  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
# 6  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
# 7  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
# 8  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
# 9  fakeav_auc_sweep_bal_20260310_20260310_165459_...            False
#
# ...

# %% [markdown]
# ## 17) Protocol-V2 Sweep (Scenario-Balanced + Hard Negatives)
#
# Protocol-v2 adds two changes over Section 16:
# 1. **Scenario-balanced positive sampling** (`0:1`, `1:0`, `1:1`) with label balance.
# 2. **Hard-negative phase**: mine val-set false positives from top baseline runs, then retrain with `--hard-negative-file` and `--hard-negative-weight`.

# %%
from pathlib import Path
import json
import subprocess
import pandas as pd

if 'BACKEND_ROOT' not in globals() or BACKEND_ROOT is None:
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

PYTHON = BACKEND_ROOT / '.venv' / 'bin' / 'python'
if not PYTHON.exists():
    PYTHON = Path('python3')

V2_TRAIN = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_v2_train.csv'
V2_VAL = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_v2_val.csv'
V2_TEST = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_v2_test.csv'
V2_META = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_v2_meta.json'

print('BACKEND_ROOT:', BACKEND_ROOT)
print('PYTHON     :', PYTHON)
# Out:
# BACKEND_ROOT: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend
# PYTHON     : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python

# %% [markdown]
# ### 17.1 Protocol-V2 Split Builder
# **What this step tries:** rebalance positive manipulations across `0:1`, `1:0`, `1:1` while maintaining label balance.
#
# **Readout to check:** per-scenario counts in train/val/test to confirm scenario coverage.

# %%
# Build protocol-v2 splits (scenario-balanced label strategy)
cmd = [
    str(PYTHON), 'scripts/build_fakeav_balanced_splits.py',
    '--processed-csv', 'data/processed/causal_multimodal_dataset.csv',
    '--strategy', 'scenario_balanced_label',
    '--seed', '42',
    '--out-train-csv', str(V2_TRAIN.relative_to(BACKEND_ROOT)),
    '--out-val-csv', str(V2_VAL.relative_to(BACKEND_ROOT)),
    '--out-test-csv', str(V2_TEST.relative_to(BACKEND_ROOT)),
    '--out-meta-json', str(V2_META.relative_to(BACKEND_ROOT)),
]
print('CMD:', ' '.join(cmd))
res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
print(res.stdout)
if res.returncode != 0:
    print(res.stderr)
    raise RuntimeError(f'build_fakeav_balanced_splits.py (v2) failed: code={res.returncode}')

meta = json.loads(V2_META.read_text())
print('V2 split summary:')
print(json.dumps(meta['splits'], indent=2))
# Out:
# CMD: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python scripts/build_fakeav_balanced_splits.py --processed-csv data/processed/causal_multimodal_dataset.csv --strategy scenario_balanced_label --seed 42 --out-train-csv data/processed/causal_multimodal_dataset_fakeav_v2_train.csv --out-val-csv data/processed/causal_multimodal_dataset_fakeav_v2_val.csv --out-test-csv data/processed/causal_multimodal_dataset_fakeav_v2_test.csv --out-meta-json data/processed/causal_multimodal_dataset_fakeav_v2_meta.json
# Balanced FakeAVCeleb split build complete.
# balanced: rows=998 labels={0: 499, 1: 499} scenarios={'0:0': 499, '0:1': 167, '1:0': 166, '1:1': 166}
# train: rows=698 labels={0: 349, 1: 349} scenarios={'0:0': 349, '0:1': 118, '1:0': 119, '1:1': 112}
# val: rows=150 labels={0: 75, 1: 75} scenarios={'0:0': 75, '0:1': 24, '1:0': 22, '1:1': 29}
# test: rows=150 labels={0: 75, 1: 75} scenarios={'0:0': 75, '0:1': 25, '1:0': 25, '1:1': 25}
# outputs:
# ...

# %% [markdown]
# ### 17.2 Protocol-V2 Training Sweep
# **What this step tries:** run baseline phase-1 training, then phase-2 hard-example retraining to recover specificity and improve robustness.
#
# **Readout to check:** phase-by-phase changes in `AUC`, `balanced_acc`, `F1_real`, `F1_fake`.

# %%
# Run protocol-v2 sweep (phase1 baseline + phase2 hard-negative retraining)
RUN_V2_SWEEP = False  # Set True to execute from notebook
V2_PREFIX = 'fakeav_auc_sweep_v2'

if RUN_V2_SWEEP:
    cmd = [
        str(PYTHON), 'scripts/sweep_fakeav_auc_protocol_v2.py',
        '--train-csv', str(V2_TRAIN.relative_to(BACKEND_ROOT)),
        '--val-csv', str(V2_VAL.relative_to(BACKEND_ROOT)),
        '--test-csv', str(V2_TEST.relative_to(BACKEND_ROOT)),
        '--feature-profile', 'extended',
        '--epochs', '35',
        '--patience', '8',
        '--phase1-runs', '8',
        '--topk-hardneg', '3',
        '--hardneg-weights', '2.0,3.0',
        '--eval-threshold-source', 'val_target',
    '--eval-threshold-priority', 'balanced_acc',
    '--run-prefix', V2_PREFIX,
    ]
    print('CMD:', ' '.join(cmd))
    res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
    print(res.stdout)
    if res.returncode != 0:
        print(res.stderr)
        raise RuntimeError(f'sweep_fakeav_auc_protocol_v2.py failed: code={res.returncode}')
else:
    print('RUN_V2_SWEEP=False (skipping execution).')
    print('Set RUN_V2_SWEEP=True to execute protocol-v2 sweep in notebook.')
# Out:
# RUN_V2_SWEEP=False (skipping execution).
# Set RUN_V2_SWEEP=True to execute protocol-v2 sweep in notebook.

# %% [markdown]
# ### 17.3 Protocol-V2 Audit
# **What this step tries:** summarize the latest protocol-v2 leaderboard and assess target reachability after hard-negative curriculum.

# %%
# Load latest protocol-v2 leaderboard and reachability report
logs_root = BACKEND_ROOT / 'models/experiment_logs'
v2_dirs = sorted(
    [p for p in logs_root.glob('fakeav_auc_sweep_v2*') if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)
if not v2_dirs:
    raise RuntimeError('No fakeav_auc_sweep_v2* directories found.')

latest = v2_dirs[0]
lb_path = latest / 'leaderboard_sorted.csv'
reach_path = latest / 'reachability_summary.json'
if not lb_path.exists():
    raise RuntimeError(f'Missing leaderboard: {lb_path}')

print('Using v2 sweep:', latest)
lb = pd.read_csv(lb_path)
cols = [
    'phase', 'run_tag', 'parent_run', 'hard_negative_weight', 'hard_negative_rows',
    'all_targets_met', 'target_gap_total', 'test_auc', 'test_acc', 'test_prec', 'test_rec', 'test_f1', 'val_auc'
]
display(lb[[c for c in cols if c in lb.columns]].head(20))

print('Runs meeting AUC>=0.91:', int((lb['test_auc'] >= 0.91).sum()), '/', len(lb))
print('Runs meeting all targets:', int(lb['all_targets_met'].sum()), '/', len(lb))
print('Best test AUC:', float(lb['test_auc'].max()))

if reach_path.exists():
    print('reachability_summary.json:')
    print(reach_path.read_text())
# Out:
# Using v2 sweep: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/experiment_logs/fakeav_auc_sweep_v2_obj_20260319_043619
#               phase                                            run_tag  \
# 0   phase1_baseline  fakeav_auc_sweep_v2_obj_20260319_043619_p1_r03...
# 1   phase1_baseline  fakeav_auc_sweep_v2_obj_20260319_043619_p1_r04...
# 2    phase2_hardneg  fakeav_auc_sweep_v2_obj_20260319_043619_p2_r01...
# 3    phase2_hardneg  fakeav_auc_sweep_v2_obj_20260319_043619_p2_r05...
# 4   phase1_baseline  fakeav_auc_sweep_v2_obj_20260319_043619_p1_r07...
# 5    phase2_hardneg  fakeav_auc_sweep_v2_obj_20260319_043619_p2_r03...
# 6   phase1_baseline  fakeav_auc_sweep_v2_obj_20260319_043619_p1_r02...
# 7    phase2_hardneg  fakeav_auc_sweep_v2_obj_20260319_043619_p2_r02...
# 8   phase1_baseline  fakeav_auc_sweep_v2_obj_20260319_043619_p1_r08...
# 9    phase2_hardneg  fakeav_auc_sweep_v2_obj_20260319_043619_p2_r04...
# ...

# %% [markdown]
# ## 18) Objective Upgrade Sweep (Multi-Task + Ranking Loss)
#
# Use protocol-v2 data with the new training objective terms added to `train_cfn.py`:
# 1. Auxiliary multi-task heads (`video_fake`, `audio_fake`).
# 2. Pairwise ranking loss to directly improve score ordering (AUC-oriented).
# 3. Existing hard-negative phase for false-positive suppression.

# %% [markdown]
# ### 18.1 Objective Upgrade Run
# **What this step tries:** add multi-task supervision and ranking loss on top of protocol-v2 to improve ordering and class-specific behavior.
#
# **Readout to check:** uplift in AUC and whether real-class metrics remain stable.

# %%
# Run protocol-v2 sweep with multitask + ranking objectives
RUN_V2_OBJECTIVE_SWEEP = True  # Set True to execute
OBJ_PREFIX = 'fakeav_auc_sweep_v2_obj'

if 'BACKEND_ROOT' not in globals() or BACKEND_ROOT is None:
    from pathlib import Path
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

if 'PYTHON' not in globals() or PYTHON is None:
    PYTHON = BACKEND_ROOT / '.venv' / 'bin' / 'python'
    if not PYTHON.exists():
        PYTHON = Path('python3')

if 'V2_TRAIN' not in globals():
    V2_TRAIN = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_v2_train.csv'
if 'V2_VAL' not in globals():
    V2_VAL = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_v2_val.csv'
if 'V2_TEST' not in globals():
    V2_TEST = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_v2_test.csv'

cmd = [
    str(PYTHON), 'scripts/sweep_fakeav_auc_protocol_v2.py',
    '--train-csv', str(V2_TRAIN.relative_to(BACKEND_ROOT)),
    '--val-csv', str(V2_VAL.relative_to(BACKEND_ROOT)),
    '--test-csv', str(V2_TEST.relative_to(BACKEND_ROOT)),
    '--feature-profile', 'extended',
    '--epochs', '35',
    '--patience', '8',
    '--phase1-runs', '8',
    '--topk-hardneg', '3',
    '--hardneg-weights', '2.0,3.0',
    '--hardneg-source', 'train',
    '--enable-multitask',
    '--multitask-weight', '0.20',
    '--ranking-loss-weight', '0.10',
    '--ranking-margin', '0.20',
    '--ranking-max-pairs', '1024',
    '--eval-threshold-source', 'val_target',
    '--eval-threshold-priority', 'balanced_acc',
    '--run-prefix', OBJ_PREFIX,
]
print('CMD:', ' '.join(cmd))
if RUN_V2_OBJECTIVE_SWEEP:
    res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
    print(res.stdout)
    if res.returncode != 0:
        print(res.stderr)
        raise RuntimeError(f'objective protocol-v2 sweep failed: code={res.returncode}')
else:
    print('RUN_V2_OBJECTIVE_SWEEP=False (skipping execution).')
    print('Set RUN_V2_OBJECTIVE_SWEEP=True to run this section.')
# Out:
# CMD: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python scripts/sweep_fakeav_auc_protocol_v2.py --train-csv data/processed/causal_multimodal_dataset_fakeav_v2_train.csv --val-csv data/processed/causal_multimodal_dataset_fakeav_v2_val.csv --test-csv data/processed/causal_multimodal_dataset_fakeav_v2_test.csv --feature-profile extended --epochs 35 --patience 8 --phase1-runs 8 --topk-hardneg 3 --hardneg-weights 2.0,3.0 --hardneg-source train --enable-multitask --multitask-weight 0.20 --ranking-loss-weight 0.10 --ranking-margin 0.20 --ranking-max-pairs 1024 --eval-threshold-source val_target --eval-threshold-priority balanced_acc --run-prefix fakeav_auc_sweep_v2_obj
#
# Traceback (most recent call last):
#   File "/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/scripts/sweep_fakeav_auc_protocol_v2.py", line 36, in <module>
#     from src.training.train_cfn import (
# ...

# %% [markdown]
# ### 18.2 Objective Upgrade Review
# **What this step tries:** inspect objective-upgrade results and compare against baseline protocol-v2 settings.

# %%
# Inspect latest objective-upgrade sweep leaderboard
logs_root = BACKEND_ROOT / 'models/experiment_logs'
obj_dirs = sorted(
    [p for p in logs_root.glob('fakeav_auc_sweep_v2_obj*') if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)
if not obj_dirs:
    raise RuntimeError('No fakeav_auc_sweep_v2_obj* directories found. Run the previous cell first.')

latest_obj = obj_dirs[0]
lb_path = latest_obj / 'leaderboard_sorted.csv'
reach_path = latest_obj / 'reachability_summary.json'
if not lb_path.exists():
    raise RuntimeError(f'Missing leaderboard: {lb_path}')

print('Using objective sweep:', latest_obj)
lb = pd.read_csv(lb_path)
show_cols = [
    'phase', 'run_tag', 'all_targets_met', 'target_gap_total',
    'test_auc', 'test_acc', 'test_prec', 'test_rec', 'test_f1',
    'enable_multitask', 'multitask_weight', 'ranking_loss_weight',
    'hard_negative_weight', 'hard_negative_rows', 'val_auc'
]
display(lb[[c for c in show_cols if c in lb.columns]].head(20))

if 'TARGETS_FAKEAV' not in globals():
    TARGETS_FAKEAV = {'acc': 0.90, 'prec': 0.87, 'rec': 0.88, 'f1': 0.88, 'auc': 0.91}

print('Runs meeting all targets:', int(lb['all_targets_met'].sum()), '/', len(lb))
for k, t in TARGETS_FAKEAV.items():
    col = f'test_{k}'
    if col in lb.columns:
        print(f"Runs meeting {col}>={t:.2f}:", int((lb[col] >= t).sum()), '/', len(lb))

if reach_path.exists():
    print('reachability_summary.json:')
    print(reach_path.read_text())

# %% [markdown]
# ## 19) Full-Train + Balanced Holdout Pipeline (Next Step)
#
# This pipeline keeps **balanced val/test** for fair target auditing, while using a **maximal FakeAVCeleb train pool** (all remaining rows).
#
# Use this when balanced-train sweeps plateau around low AUC/precision.

# %%
from pathlib import Path
import json
import subprocess
import pandas as pd

if 'BACKEND_ROOT' not in globals() or BACKEND_ROOT is None:
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

PYTHON = BACKEND_ROOT / '.venv' / 'bin' / 'python'
if not PYTHON.exists():
    PYTHON = Path('python3')

FULL_TRAIN = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_fulltrain_train.csv'
FULL_VAL = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_fulltrain_val.csv'
FULL_TEST = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_fulltrain_test.csv'
FULL_META = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_fulltrain_meta.json'

cmd = [
    str(PYTHON), 'scripts/build_fakeav_holdout_balanced_splits.py',
    '--processed-csv', 'data/processed/causal_multimodal_dataset.csv',
    '--seed', '42',
    '--val-size', '0.15',
    '--test-size', '0.15',
    '--holdout-fake-strategy', 'scenario_balanced',
    '--out-train-csv', str(FULL_TRAIN.relative_to(BACKEND_ROOT)),
    '--out-val-csv', str(FULL_VAL.relative_to(BACKEND_ROOT)),
    '--out-test-csv', str(FULL_TEST.relative_to(BACKEND_ROOT)),
    '--out-meta-json', str(FULL_META.relative_to(BACKEND_ROOT)),
]
print('CMD:', ' '.join(cmd))
res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
print(res.stdout)
if res.returncode != 0:
    print(res.stderr)
    raise RuntimeError(f'build_fakeav_holdout_balanced_splits.py failed: code={res.returncode}')

meta = json.loads(FULL_META.read_text())
print('full-train split summary:')
print(json.dumps(meta['splits'], indent=2))
# Out:
# CMD: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python scripts/build_fakeav_holdout_balanced_splits.py --processed-csv data/processed/causal_multimodal_dataset.csv --seed 42 --val-size 0.15 --test-size 0.15 --holdout-fake-strategy scenario_balanced --out-train-csv data/processed/causal_multimodal_dataset_fakeav_fulltrain_train.csv --out-val-csv data/processed/causal_multimodal_dataset_fakeav_fulltrain_val.csv --out-test-csv data/processed/causal_multimodal_dataset_fakeav_fulltrain_test.csv --out-meta-json data/processed/causal_multimodal_dataset_fakeav_fulltrain_meta.json
# FakeAVCeleb full-train holdout split build complete.
# train: rows=21241 labels={0: 349, 1: 20892} scenarios={'0:0': 349, '0:1': 449, '1:0': 9658, '1:1': 10785}
# val: rows=150 labels={0: 75, 1: 75} scenarios={'0:0': 75, '0:1': 25, '1:0': 25, '1:1': 25}
# test: rows=150 labels={0: 75, 1: 75} scenarios={'0:0': 75, '0:1': 25, '1:0': 25, '1:1': 25}
# outputs:
# ...

# %% [markdown]
# ### 19.1 Full-Train Sweep
# **What this step tries:** train on maximal FakeAV pool (imbalanced) while preserving balanced holdout evaluation.
#
# **Readout to check:** whether larger train pool improves AUC/generalization without unacceptable specificity loss.

# %%
# Run sweep on full-train split with weighted sampler + objective terms
RUN_FULLTRAIN_SWEEP = True  # Set True to execute
FULL_PREFIX = 'fakeav_auc_sweep_fulltrain'

cmd = [
    str(PYTHON), 'scripts/sweep_fakeav_auc.py',
    '--train-csv', str(FULL_TRAIN.relative_to(BACKEND_ROOT)),
    '--val-csv', str(FULL_VAL.relative_to(BACKEND_ROOT)),
    '--test-csv', str(FULL_TEST.relative_to(BACKEND_ROOT)),
    '--feature-profile', 'extended',
    '--epochs', '35',
    '--patience', '8',
    '--max-runs', '10',
    '--train-source', 'fakeavceleb',
    '--train-use-weighted-sampler',
    '--train-weight-application', 'auto',
    '--enable-multitask',
    '--multitask-weight', '0.20',
    '--ranking-loss-weight', '0.10',
    '--ranking-margin', '0.20',
    '--ranking-max-pairs', '1024',
    '--eval-threshold-source', 'val_target',
    '--eval-threshold-priority', 'balanced_acc',
    '--run-prefix', FULL_PREFIX,
]
print('CMD:', ' '.join(cmd))
if RUN_FULLTRAIN_SWEEP:
    res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
    print(res.stdout)
    if res.returncode != 0:
        print(res.stderr)
        raise RuntimeError(f'full-train sweep failed: code={res.returncode}')
else:
    print('RUN_FULLTRAIN_SWEEP=False (skipping execution).')
    print('Set RUN_FULLTRAIN_SWEEP=True to execute this section.')
# Out:
# CMD: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python scripts/sweep_fakeav_auc.py --train-csv data/processed/causal_multimodal_dataset_fakeav_fulltrain_train.csv --val-csv data/processed/causal_multimodal_dataset_fakeav_fulltrain_val.csv --test-csv data/processed/causal_multimodal_dataset_fakeav_fulltrain_test.csv --feature-profile extended --epochs 35 --patience 8 --max-runs 10 --train-source fakeavceleb --train-use-weighted-sampler --train-weight-application auto --enable-multitask --multitask-weight 0.20 --ranking-loss-weight 0.10 --ranking-margin 0.20 --ranking-max-pairs 1024 --eval-threshold-source val_target --eval-threshold-priority balanced_acc --run-prefix fakeav_auc_sweep_fulltrain
#
# Traceback (most recent call last):
#   File "/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/scripts/sweep_fakeav_auc.py", line 38, in <module>
#     from src.training.train_cfn import (
# ...

# %% [markdown]
# ### 19.2 Full-Train Audit
# **What this step tries:** summarize full-train experiments and report target feasibility under holdout-balanced evaluation.

# %%
# Inspect latest full-train sweep and target reachability
logs_root = BACKEND_ROOT / 'models/experiment_logs'
full_dirs = sorted(
    [p for p in logs_root.glob('fakeav_auc_sweep_fulltrain*') if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)
if not full_dirs:
    raise RuntimeError('No fakeav_auc_sweep_fulltrain* directories found.')

latest_full = full_dirs[0]
lb_path = latest_full / 'leaderboard_sorted.csv'
reach_path = latest_full / 'reachability_summary.json'
if not lb_path.exists():
    raise RuntimeError(f'Missing leaderboard: {lb_path}')

print('Using full-train sweep:', latest_full)
lb = pd.read_csv(lb_path)
cols = [
    'run_tag', 'all_targets_met', 'target_gap_total',
    'test_auc', 'test_acc', 'test_prec', 'test_rec', 'test_f1', 'val_auc',
    'train_use_weighted_sampler', 'enable_multitask', 'multitask_weight', 'ranking_loss_weight'
]
display(lb[[c for c in cols if c in lb.columns]].head(20))

if 'TARGETS_FAKEAV' not in globals():
    TARGETS_FAKEAV = {'acc': 0.90, 'prec': 0.87, 'rec': 0.88, 'f1': 0.88, 'auc': 0.91}

print('Runs meeting all targets:', int(lb['all_targets_met'].sum()), '/', len(lb))
for k, t in TARGETS_FAKEAV.items():
    col = f'test_{k}'
    if col in lb.columns:
        print(f'Runs meeting {col}>={t:.2f}:', int((lb[col] >= t).sum()), '/', len(lb))

if reach_path.exists():
    print('reachability_summary.json:')
    print(reach_path.read_text())

# %% [markdown]
# ## 20) Preprocessing -> Full Pipeline (Audio Trim + Feature Refresh + Sweeps)
#
# Use this section when you want to rerun the pipeline from preprocessing onward, in one place:
# 1. Trim first 100ms of FakeAVCeleb audio (bias mitigation).
# 2. Re-extract features into `data/processed/causal_multimodal_dataset.csv`.
# 3. Rebuild full-train + balanced holdout splits.
# 4. Run baseline and/or objective sweeps.
#
# All heavy steps are toggle-gated (`False` by default).

# %%
from pathlib import Path
import json
import subprocess
import pandas as pd

# ---- root / python resolution ----
if 'BACKEND_ROOT' not in globals() or BACKEND_ROOT is None:
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

PYTHON = BACKEND_ROOT / '.venv' / 'bin' / 'python'
if not PYTHON.exists():
    PYTHON = Path('python3')

# ---- key paths ----
FAKEAV_ROOT = BACKEND_ROOT / 'data/raw/fakeavceleb'
PROCESSED_CSV = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset.csv'
TRIM_MANIFEST = BACKEND_ROOT / 'data/processed/fakeav_audio_trim_manifest.csv'

FULL_TRAIN = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_fulltrain_train.csv'
FULL_VAL = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_fulltrain_val.csv'
FULL_TEST = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_fulltrain_test.csv'
FULL_META = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_fakeav_fulltrain_meta.json'

# ---- toggles ----
RUN_AUDIO_TRIM = False
RUN_FEATURE_EXTRACTION = False
RUN_BUILD_FULLTRAIN_SPLITS = False
RUN_FULLTRAIN_BASE_SWEEP = False
RUN_FULLTRAIN_OBJECTIVE_SWEEP = False

# ---- params ----
TRIM_SECONDS = 0.10
FULLTRAIN_BASE_PREFIX = 'fakeav_auc_sweep_fulltrain_base_thrcal'
FULLTRAIN_OBJ_PREFIX = 'fakeav_auc_sweep_fulltrain_obj_thrcal'

print('BACKEND_ROOT:', BACKEND_ROOT)
print('PYTHON:', PYTHON)
print('Toggles:', {
    'RUN_AUDIO_TRIM': RUN_AUDIO_TRIM,
    'RUN_FEATURE_EXTRACTION': RUN_FEATURE_EXTRACTION,
    'RUN_BUILD_FULLTRAIN_SPLITS': RUN_BUILD_FULLTRAIN_SPLITS,
    'RUN_FULLTRAIN_BASE_SWEEP': RUN_FULLTRAIN_BASE_SWEEP,
    'RUN_FULLTRAIN_OBJECTIVE_SWEEP': RUN_FULLTRAIN_OBJECTIVE_SWEEP,
})
# Out:
# BACKEND_ROOT: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend
# PYTHON: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python
# Toggles: {'RUN_AUDIO_TRIM': False, 'RUN_FEATURE_EXTRACTION': False, 'RUN_BUILD_FULLTRAIN_SPLITS': False, 'RUN_FULLTRAIN_BASE_SWEEP': False, 'RUN_FULLTRAIN_OBJECTIVE_SWEEP': False}

# %% [markdown]
# ### 20.1 Audio-Bias Mitigation
# **What this step tries:** trim initial FakeAV audio segments to reduce shortcut cues from leading artifacts.

# %%
# Step 1: FakeAVCeleb audio-bias mitigation (trim first 100ms)
if RUN_AUDIO_TRIM:
    cmd = [
        str(PYTHON), 'scripts/trim_fakeav_audio_head.py',
        '--input-root', str(FAKEAV_ROOT.relative_to(BACKEND_ROOT)),
        '--in-place',
        '--trim-seconds', f'{TRIM_SECONDS:.2f}',
        '--manifest-csv', str(TRIM_MANIFEST.relative_to(BACKEND_ROOT)),
    ]
    print('CMD:', ' '.join(cmd))
    res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
    print(res.stdout)
    if res.returncode != 0:
        print(res.stderr)
        raise RuntimeError(f'trim_fakeav_audio_head.py failed: code={res.returncode}')
else:
    print('RUN_AUDIO_TRIM=False (skipping audio trim).')

if TRIM_MANIFEST.exists():
    man = pd.read_csv(TRIM_MANIFEST)
    print('Latest trim status counts:')
    print(man['status'].value_counts(dropna=False).to_string())
    print('Manifest:', TRIM_MANIFEST)
# Out:
# RUN_AUDIO_TRIM=False (skipping audio trim).
# Latest trim status counts:
# status
# trimmed_in_place    21544
# Manifest: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/fakeav_audio_trim_manifest.csv

# %% [markdown]
# ### 20.2 Feature Refresh
# **What this step tries:** regenerate processed features after preprocessing updates so downstream training uses consistent inputs.

# %%
# Step 2: Feature extraction refresh
if RUN_FEATURE_EXTRACTION:
    cmd = [str(PYTHON), '-m', 'src.preprocessing.batch_feature_extractor']
    print('CMD:', ' '.join(cmd))
    res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
    print(res.stdout)
    if res.returncode != 0:
        print(res.stderr)
        raise RuntimeError(f'batch_feature_extractor failed: code={res.returncode}')
else:
    print('RUN_FEATURE_EXTRACTION=False (skipping extraction).')

if PROCESSED_CSV.exists():
    df = pd.read_csv(PROCESSED_CSV)
    print('Processed CSV:', PROCESSED_CSV)
    print('Rows:', len(df), 'Columns:', len(df.columns))
    if 'dataset' in df.columns and 'label' in df.columns:
        print('Dataset counts:')
        print(df['dataset'].astype(str).str.lower().value_counts().to_string())
        print('Label counts:')
        print(df['label'].astype(int).value_counts().sort_index().to_string())
# Out:
# RUN_FEATURE_EXTRACTION=False (skipping extraction).
# Processed CSV: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_dataset.csv
# Rows: 23737 Columns: 39
# Dataset counts:
# dataset
# fakeavceleb    21541
# dfdc            2196
# Label counts:
# label
# 0      795
# 1    22942

# %% [markdown]
# ### 20.3 Split Rebuild (Full-Train + Balanced Holdout)
# **What this step tries:** rebuild split CSVs with realistic imbalanced training and balanced val/test auditing.

# %%
# Step 3: Build full-train + balanced holdout splits
if RUN_BUILD_FULLTRAIN_SPLITS:
    cmd = [
        str(PYTHON), 'scripts/build_fakeav_holdout_balanced_splits.py',
        '--processed-csv', str(PROCESSED_CSV.relative_to(BACKEND_ROOT)),
        '--seed', '42',
        '--val-size', '0.15',
        '--test-size', '0.15',
        '--holdout-fake-strategy', 'scenario_balanced',
        '--out-train-csv', str(FULL_TRAIN.relative_to(BACKEND_ROOT)),
        '--out-val-csv', str(FULL_VAL.relative_to(BACKEND_ROOT)),
        '--out-test-csv', str(FULL_TEST.relative_to(BACKEND_ROOT)),
        '--out-meta-json', str(FULL_META.relative_to(BACKEND_ROOT)),
    ]
    print('CMD:', ' '.join(cmd))
    res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
    print(res.stdout)
    if res.returncode != 0:
        print(res.stderr)
        raise RuntimeError(f'build_fakeav_holdout_balanced_splits.py failed: code={res.returncode}')
else:
    print('RUN_BUILD_FULLTRAIN_SPLITS=False (skipping split build).')

if FULL_META.exists():
    meta = json.loads(FULL_META.read_text())
    print('Split summary:')
    print(json.dumps(meta.get('splits', {}), indent=2))
# Out:
# RUN_BUILD_FULLTRAIN_SPLITS=False (skipping split build).
# Split summary:
# {
#   "train": {
#     "rows": 21241,
#     "label_counts": {
#       "0": 349,
#       "1": 20892
#     },
#     "scenario_counts": {
#       "0:0": 349,
#       "0:1": 449,
#       "1:0": 9658,
#       "1:1": 10785
#     }
#   },
#   "val": {
#     "rows": 150,
#     "label_counts": {
#       "0": 75,
#       "1": 75
#     },
#     "scenario_counts": {
#       "0:0": 75,
#       "0:1": 25,
#       "1:0": 25,
#       "1:1": 25
#     }
#   },
#   "test": {
#     "rows": 150,
#     "label_counts": {
#       "0": 75,
#       "1": 75
#     },
#     "scenario_counts": {
#       "0:0": 75,
#       "0:1": 25,
#       "1:0": 25,
#       "1:1": 25
#     }
#   }
# }

# %% [markdown]
# ### 20.4A Baseline Full-Train Sweep
# **What this step tries:** run a controlled baseline objective on rebuilt splits before adding advanced losses.

# %%
# Step 4A: Full-train baseline sweep (no multitask/ranking)
if RUN_FULLTRAIN_BASE_SWEEP:
    cmd = [
        str(PYTHON), 'scripts/sweep_fakeav_auc.py',
        '--train-csv', str(FULL_TRAIN.relative_to(BACKEND_ROOT)),
        '--val-csv', str(FULL_VAL.relative_to(BACKEND_ROOT)),
        '--test-csv', str(FULL_TEST.relative_to(BACKEND_ROOT)),
        '--feature-profile', 'extended',
        '--epochs', '35',
        '--patience', '8',
        '--max-runs', '10',
        '--train-source', 'fakeavceleb',
        '--train-use-weighted-sampler',
        '--train-weight-application', 'auto',
        '--eval-threshold-source', 'val_target',
        '--eval-threshold-priority', 'balanced_acc',
        '--run-prefix', FULLTRAIN_BASE_PREFIX,
    ]
    print('CMD:', ' '.join(cmd))
    res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
    print(res.stdout)
    if res.returncode != 0:
        print(res.stderr)
        raise RuntimeError(f'fulltrain baseline sweep failed: code={res.returncode}')
else:
    print('RUN_FULLTRAIN_BASE_SWEEP=False (skipping baseline sweep).')
# Out:
# RUN_FULLTRAIN_BASE_SWEEP=False (skipping baseline sweep).

# %% [markdown]
# ### 20.4B Objective Full-Train Sweep
# **What this step tries:** add multi-task/ranking terms to the same split regime and compare directly against 20.4A.

# %%
# Step 4B: Full-train objective sweep (multitask + ranking)
if RUN_FULLTRAIN_OBJECTIVE_SWEEP:
    cmd = [
        str(PYTHON), 'scripts/sweep_fakeav_auc.py',
        '--train-csv', str(FULL_TRAIN.relative_to(BACKEND_ROOT)),
        '--val-csv', str(FULL_VAL.relative_to(BACKEND_ROOT)),
        '--test-csv', str(FULL_TEST.relative_to(BACKEND_ROOT)),
        '--feature-profile', 'extended',
        '--epochs', '35',
        '--patience', '8',
        '--max-runs', '10',
        '--train-source', 'fakeavceleb',
        '--train-use-weighted-sampler',
        '--train-weight-application', 'auto',
        '--enable-multitask',
        '--multitask-weight', '0.20',
        '--ranking-loss-weight', '0.10',
        '--ranking-margin', '0.20',
        '--ranking-max-pairs', '1024',
        '--eval-threshold-source', 'val_target',
        '--eval-threshold-priority', 'balanced_acc',
        '--run-prefix', FULLTRAIN_OBJ_PREFIX,
    ]
    print('CMD:', ' '.join(cmd))
    res = subprocess.run(cmd, cwd=BACKEND_ROOT, text=True, capture_output=True)
    print(res.stdout)
    if res.returncode != 0:
        print(res.stderr)
        raise RuntimeError(f'fulltrain objective sweep failed: code={res.returncode}')
else:
    print('RUN_FULLTRAIN_OBJECTIVE_SWEEP=False (skipping objective sweep).')

# %% [markdown]
# ### 20.5 Quick Leaderboard Check
# **What this step tries:** quickly verify whether the latest full-train candidates improved both ranking quality and guard metrics.

# %%
# Step 5: Quick leaderboard check (latest fulltrain sweeps)
logs_root = BACKEND_ROOT / 'models/experiment_logs'
patterns = ['fakeav_auc_sweep_fulltrain_base_thrcal*', 'fakeav_auc_sweep_fulltrain_obj_thrcal*']

for pat in patterns:
    dirs = sorted([p for p in logs_root.glob(pat) if p.is_dir()], key=lambda p: p.stat().st_mtime, reverse=True)
    if not dirs:
        print(f'No directories for pattern: {pat}')
        continue
    latest = dirs[0]
    lb = latest / 'leaderboard_sorted.csv'
    print('Pattern:', pat)
    print('Latest :', latest)
    if lb.exists():
        df = pd.read_csv(lb)
        if len(df):
            cols = ['run_tag', 'target_gap_total', 'test_auc', 'test_acc', 'test_prec', 'test_rec', 'test_f1', 'test_thr']
            cols = [c for c in cols if c in df.columns]
            display(df[cols].head(5))
        else:
            print('Leaderboard exists but empty.')
    else:
        print('Missing leaderboard_sorted.csv')

# %% [markdown]
# ## Step 6: Latest Step37 Multiseed Metrics Refresh (2026-03-15)
#
# Loads the newest strict-clean FakeAVCeleb multiseed/ensemble artifacts and compares:
# - Ensemble baseline (val-target thresholding in-run)
# - Post-hoc temperature-aware constrained sweep
# - Fold-wise seed-weight-optimized ensemble (val AUC optimized)
#
# Targets checked: `Accuracy>=0.95`, `AUC>=0.970`, `F1>=0.94`, `Precision>=0.93`, `Recall>=0.94`.

# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

RUN_DIR = BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step39_rankreal_multiseed_multiseed_20260315_201400'

ensemble_summary = json.loads((RUN_DIR / 'ensemble_summary.json').read_text())
posthoc = json.loads((RUN_DIR / 'posthoc_threshold_sweep_temperatureaware.json').read_text())
foldwise_opt = json.loads((RUN_DIR / 'posthoc_foldwise_seed_weight_optimized_temperatureaware_step0p005.json').read_text())

targets = {'acc': 0.95, 'auc': 0.970, 'f1': 0.94, 'prec': 0.93, 'rec': 0.94}

rows = []

cv = ensemble_summary['cv_metrics']
rows.append({
    'variant': 'ensemble_baseline_cv_mean',
    'acc': float(cv['test_acc']['mean']),
    'auc': float(cv['test_auc']['mean']),
    'f1': float(cv['test_f1']['mean']),
    'prec': float(cv['test_prec']['mean']),
    'rec': float(cv['test_rec']['mean']),
})

rows.append({
    'variant': 'posthoc_tempaware_protocol_pooled_test',
    'acc': float(posthoc['protocol']['pooled_test_metrics']['acc']),
    'auc': float(posthoc['protocol']['pooled_test_metrics']['auc']),
    'f1': float(posthoc['protocol']['pooled_test_metrics']['f1']),
    'prec': float(posthoc['protocol']['pooled_test_metrics']['prec']),
    'rec': float(posthoc['protocol']['pooled_test_metrics']['rec']),
})

rows.append({
    'variant': 'posthoc_tempaware_user_target_pooled_test',
    'acc': float(posthoc['user_stretch']['pooled_test_metrics']['acc']),
    'auc': float(posthoc['user_stretch']['pooled_test_metrics']['auc']),
    'f1': float(posthoc['user_stretch']['pooled_test_metrics']['f1']),
    'prec': float(posthoc['user_stretch']['pooled_test_metrics']['prec']),
    'rec': float(posthoc['user_stretch']['pooled_test_metrics']['rec']),
})

rows.append({
    'variant': 'foldwise_seed_weight_opt_cv_mean',
    'acc': float(foldwise_opt['cv_mean']['test_acc']),
    'auc': float(foldwise_opt['cv_mean']['test_auc']),
    'f1': float(foldwise_opt['cv_mean']['test_f1']),
    'prec': float(foldwise_opt['cv_mean']['test_prec']),
    'rec': float(foldwise_opt['cv_mean']['test_rec']),
})

df = pd.DataFrame(rows)
for m, t in targets.items():
    df[f'{m}_target'] = t
    df[f'{m}_pass'] = df[m] >= t

display(df)

print('Artifacts:')
print(' -', RUN_DIR / 'ensemble_summary.json')
print(' -', RUN_DIR / 'posthoc_threshold_sweep_temperatureaware.json')
print(' -', RUN_DIR / 'posthoc_foldwise_seed_weight_optimized_temperatureaware_step0p005.json')

print()
print('Clear Metrics Summary (Step39 refresh):')
for _, r in df.iterrows():
    pass_flags = [
        'Y' if bool(r['acc_pass']) else 'N',
        'Y' if bool(r['auc_pass']) else 'N',
        'Y' if bool(r['f1_pass']) else 'N',
        'Y' if bool(r['prec_pass']) else 'N',
        'Y' if bool(r['rec_pass']) else 'N',
    ]
    print(
        f"{r['variant']}: "
        f"ACC={r['acc']:.4f} AUC={r['auc']:.4f} F1={r['f1']:.4f} PREC={r['prec']:.4f} REC={r['rec']:.4f} "
        f"PASS[AUC/ACC/F1/P/R]={pass_flags[1]}/{pass_flags[0]}/{pass_flags[2]}/{pass_flags[3]}/{pass_flags[4]}"
    )

# Confusion matrices (graphical)
def _plot_cm(ax, counts, title):
    tp = float(counts.get('tp', 0.0))
    tn = float(counts.get('tn', 0.0))
    fp = float(counts.get('fp', 0.0))
    fn = float(counts.get('fn', 0.0))
    mat = np.array([[tn, fp], [fn, tp]], dtype=float)
    im = ax.imshow(mat, cmap='Blues')
    ax.set_xticks([0, 1], labels=['Pred Real', 'Pred Fake'])
    ax.set_yticks([0, 1], labels=['True Real', 'True Fake'])
    ax.set_title(title)
    for i in range(2):
        for j in range(2):
            ax.text(j, i, f"{int(round(mat[i,j]))}", ha='center', va='center', color='black')
    return im

ens_fold = pd.read_csv(RUN_DIR / 'ensemble_fold_metrics.csv')
conf_ensemble = {
    'tp': float(ens_fold['test_tp'].sum()),
    'tn': float(ens_fold['test_tn'].sum()),
    'fp': float(ens_fold['test_fp'].sum()),
    'fn': float(ens_fold['test_fn'].sum()),
}
conf_protocol = {
    'tp': float(posthoc['protocol']['pooled_test_metrics']['tp']),
    'tn': float(posthoc['protocol']['pooled_test_metrics']['tn']),
    'fp': float(posthoc['protocol']['pooled_test_metrics']['fp']),
    'fn': float(posthoc['protocol']['pooled_test_metrics']['fn']),
}
conf_user = {
    'tp': float(posthoc['user_stretch']['pooled_test_metrics']['tp']),
    'tn': float(posthoc['user_stretch']['pooled_test_metrics']['tn']),
    'fp': float(posthoc['user_stretch']['pooled_test_metrics']['fp']),
    'fn': float(posthoc['user_stretch']['pooled_test_metrics']['fn']),
}
fold_rows = foldwise_opt.get('fold_rows', [])
conf_foldwise = {
    'tp': float(sum(float(r.get('test_tp', 0.0)) for r in fold_rows)),
    'tn': float(sum(float(r.get('test_tn', 0.0)) for r in fold_rows)),
    'fp': float(sum(float(r.get('test_fp', 0.0)) for r in fold_rows)),
    'fn': float(sum(float(r.get('test_fn', 0.0)) for r in fold_rows)),
}

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
_plot_cm(axes[0, 0], conf_ensemble, 'Ensemble Baseline')
_plot_cm(axes[0, 1], conf_protocol, 'Posthoc Protocol')
_plot_cm(axes[1, 0], conf_user, 'Posthoc User Target')
_plot_cm(axes[1, 1], conf_foldwise, 'Foldwise Weight Opt')
plt.tight_layout()
plt.show()
# Out:
#                                      variant       acc       auc        f1  \
# 0                  ensemble_baseline_cv_mean  0.872383  0.841685  0.930910
# 1     posthoc_tempaware_protocol_pooled_test  0.895502  0.842104  0.944259
# 2  posthoc_tempaware_user_target_pooled_test  0.948424  0.842104  0.973348
# 3           foldwise_seed_weight_opt_cv_mean  0.897544  0.840025  0.945394
#
#        prec       rec  acc_target  acc_pass  auc_target  auc_pass  f1_target  \
# 0  0.987114  0.880858        0.95     False        0.97     False       0.94
# 1  0.985782  0.906093        0.95     False        0.97     False       0.94
# 2  0.982754  0.964119        0.95     False        0.97     False       0.94
# 3  0.985863  0.908137        0.95     False        0.97     False       0.94
#
#    f1_pass  prec_target  prec_pass  rec_target  rec_pass
# 0    False         0.93       True        0.94     False
# 1     True         0.93       True        0.94     False
# ...

# %% [markdown]
# ## Step 7: Step38-Step44 Complete Changelog + Runnable Metrics (2026-03-16)
#
# This section captures the remaining steps we tried (Step36 -> Step44), with:
# - what changed in each step,
# - exact artifact locations,
# - quick loaders to inspect ensemble/post-hoc metrics,
# - rerun commands for Step43/Step44.
#
# Comparability note:
# - `step44_realvis_multiseed` uses `causal_multimodal_dataset_effnet_w2v2_physfix_realvis.csv`.
# - It is the strongest accuracy run, but it is a different data regime from the nextgen-fullvis runs (`step38/39/41/42/43`).

# %%
from pathlib import Path
import json
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

try:
    BACKEND_ROOT
except NameError:
    BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')

STEP_RUNS = [
    {
        'step': 'step36_newtech',
        'run_dir': BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step36_newtech_multiseed_multiseed_20260314_220222',
        'change': 'Initial new-tech stack: GenD-style adapt + paired RF + Stage0 + class-balanced + AUC/ranking emphasis.',
    },
    {
        'step': 'step37_cleanstrict',
        'run_dir': BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step37_cleanstrict_multiseed_multiseed_20260315_010923',
        'change': 'Switched to fullvis_proxy processed CSV; removed Stage0/CB; cleaner strict setup.',
    },
    {
        'step': 'step38_nextgen',
        'run_dir': BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step38_nextgen_multiseed_multiseed_20260315_171231',
        'change': 'Moved to nextgen processed CSV/features (extended discrepancy/distortion regime).',
    },
    {
        'step': 'step39_rankreal',
        'run_dir': BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step39_rankreal_multiseed_multiseed_20260315_201400',
        'change': 'Higher ranking/AUC pressure + Stage0 + class-balanced re-enabled.',
    },
    {
        'step': 'step41_pairfix_valingest',
        'run_dir': BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step41_pairfix_valingest_multiseed_multiseed_20260315_222101',
        'change': 'Pair-source + validation ingestion fixes; stronger baseline before guards.',
    },
    {
        'step': 'step41_tempaware_variant',
        'run_dir': BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step41_pairfix_valingest_multiseed_tempaware_multiseed_20260315_222645',
        'change': 'Temperature-aware variant in a different processed-CSV branch (regressed).',
    },
    {
        'step': 'step42_nextgen_guard',
        'run_dir': BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step42_nextgen_guard_multiseed_tempaware_multiseed_20260315_234715',
        'change': 'Nextgen fail-fast guard + improved auto-selection; best comparable nextgen baseline.',
    },
    {
        'step': 'step43_stage0_allsrc_cb_auc',
        'run_dir': BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step43_stage0_allsrc_cb_auc_multiseed_20260316_041619',
        'change': 'Aggressive stack: train_source=all + Stage0 + CB + focal/BCE mix + higher rank weight (regressed).',
    },
    {
        'step': 'step44_realvis_multiseed',
        'run_dir': BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step44_realvis_multiseed_multiseed_20260316_043357',
        'change': 'Realvis data regime, focal loss, lower ranking pressure; highest metrics run.',
    },
]


def _read_json(path: Path):
    if not path.exists():
        return None
    return json.loads(path.read_text())


def _safe_get(d, *keys, default=None):
    cur = d
    for k in keys:
        if cur is None or k not in cur:
            return default
        cur = cur[k]
    return cur


def _round(x):
    try:
        return round(float(x), 6)
    except Exception:
        return None

rows = []
cm_rows = []
for item in STEP_RUNS:
    run_dir = item['run_dir']
    ms = _read_json(run_dir / 'multiseed_summary.json')
    ens = _read_json(run_dir / 'ensemble_summary.json')
    post = _read_json(run_dir / 'posthoc_threshold_sweep_temperatureaware.json')

    if ms is None or ens is None:
        rows.append({'step': item['step'], 'status': 'missing artifacts', 'run_dir': str(run_dir), 'change': item['change']})
        continue

    seed0 = ms.get('seed_runs', [{}])[0]
    cv0 = _read_json(Path(seed0.get('summary_path', '')))
    split_meta = _read_json(Path(seed0.get('split_meta_path', '')))

    cv = ens.get('cv_metrics', {})
    row = {
        'step': item['step'],
        'run_dir': str(run_dir),
        'processed_csv': str(_safe_get(split_meta, 'processed_csv', default='')),
        'split_mode': _safe_get(cv0, 'protocol', 'split_mode'),
        'train_source': _safe_get(cv0, 'protocol', 'train_source'),
        'loss': _safe_get(cv0, 'protocol', 'loss'),
        'ranking_w': _safe_get(cv0, 'protocol', 'ranking_loss_weight'),
        'stage0': _safe_get(cv0, 'protocol', 'stage0_avc_pretrain'),
        'class_balanced': _safe_get(cv0, 'protocol', 'class_balanced_loss'),
        'focal_bce_mix': _safe_get(cv0, 'protocol', 'focal_bce_mix'),
        'phase2_rounds': _safe_get(cv0, 'protocol', 'phase2_rounds'),
        'ensemble_acc': _round(_safe_get(cv, 'test_acc', 'mean')),
        'ensemble_auc': _round(_safe_get(cv, 'test_auc', 'mean')),
        'ensemble_f1': _round(_safe_get(cv, 'test_f1', 'mean')),
        'ensemble_prec': _round(_safe_get(cv, 'test_prec', 'mean')),
        'ensemble_rec': _round(_safe_get(cv, 'test_rec', 'mean')),
        'posthoc_user_acc': _round(_safe_get(post, 'user_stretch', 'pooled_test_metrics', 'acc')),
        'posthoc_user_auc': _round(_safe_get(post, 'user_stretch', 'pooled_test_metrics', 'auc')),
        'posthoc_user_f1': _round(_safe_get(post, 'user_stretch', 'pooled_test_metrics', 'f1')),
        'posthoc_user_prec': _round(_safe_get(post, 'user_stretch', 'pooled_test_metrics', 'prec')),
        'posthoc_user_rec': _round(_safe_get(post, 'user_stretch', 'pooled_test_metrics', 'rec')),
        'change': item['change'],
    }
    rows.append(row)

    ef = run_dir / 'ensemble_fold_metrics.csv'
    if ef.exists():
        df_ef = pd.read_csv(ef)
        cm_rows.append({
            'step': item['step'],
            'tp': float(df_ef['test_tp'].sum()),
            'tn': float(df_ef['test_tn'].sum()),
            'fp': float(df_ef['test_fp'].sum()),
            'fn': float(df_ef['test_fn'].sum()),
        })

step_df = pd.DataFrame(rows)
with pd.option_context('display.max_colwidth', 100):
    display(step_df)


def _fmt(v):
    try:
        if pd.isna(v):
            return 'NA'
        return f"{float(v):.4f}"
    except Exception:
        return 'NA'

print()
print('Clear Metrics Summary (Step36 -> Step44):')
for _, r in step_df.iterrows():
    print(
        f"{r.get('step','NA')}: "
        f"ens[ACC={_fmt(r.get('ensemble_acc'))}, AUC={_fmt(r.get('ensemble_auc'))}, "
        f"F1={_fmt(r.get('ensemble_f1'))}, P={_fmt(r.get('ensemble_prec'))}, R={_fmt(r.get('ensemble_rec'))}] "
        f"posthoc_user[ACC={_fmt(r.get('posthoc_user_acc'))}, AUC={_fmt(r.get('posthoc_user_auc'))}, "
        f"F1={_fmt(r.get('posthoc_user_f1'))}, P={_fmt(r.get('posthoc_user_prec'))}, R={_fmt(r.get('posthoc_user_rec'))}]"
    )

# Graphical confusion matrices (ensemble baseline per step)
def _plot_cm(ax, counts, title):
    tp = float(counts.get('tp', 0.0))
    tn = float(counts.get('tn', 0.0))
    fp = float(counts.get('fp', 0.0))
    fn = float(counts.get('fn', 0.0))
    mat = np.array([[tn, fp], [fn, tp]], dtype=float)
    ax.imshow(mat, cmap='Blues')
    ax.set_xticks([0, 1], labels=['Pred Real', 'Pred Fake'])
    ax.set_yticks([0, 1], labels=['True Real', 'True Fake'])
    ax.set_title(title)
    for i in range(2):
        for j in range(2):
            ax.text(j, i, f"{int(round(mat[i,j]))}", ha='center', va='center', color='black')

if cm_rows:
    n = len(cm_rows)
    ncols = 3
    nrows = int(math.ceil(n / ncols))
    fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4 * nrows))
    axes = np.array(axes).reshape(-1)
    for i, r in enumerate(cm_rows):
        _plot_cm(axes[i], r, r['step'])
    for j in range(len(cm_rows), len(axes)):
        axes[j].axis('off')
    plt.tight_layout()
    plt.show()
# Out:
#                           step  \
# 0               step36_newtech
# 1           step37_cleanstrict
# 2               step38_nextgen
# 3              step39_rankreal
# 4     step41_pairfix_valingest
# 5     step41_tempaware_variant
# 6         step42_nextgen_guard
# 7  step43_stage0_allsrc_cb_auc
# 8     step44_realvis_multiseed
#
#                                                                                                run_dir  \
# 0  /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/experiment_logs/fakeav_mrdf5...
# 1  /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/experiment_logs/fakeav_mrdf5...
# 2  /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/experiment_logs/fakeav_mrdf5...
# 3  /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/experiment_logs/fakeav_mrdf5...
# 4  /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/experiment_logs/fakeav_mrdf5...
# ...

# %% [markdown]
# ### Step44 Normal Holdout Test (Single Split)
#
# This cell reports the single fixed normal test-set run (not 5-fold averaged):
# - `fakeav_mrdf5cv_step44_normaltest_single_s42_20260316_154454`

# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

NORMAL_RUN_DIR = BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step44_normaltest_single_s42_20260316_154454'
cv_summary_path = NORMAL_RUN_DIR / 'cv_summary.json'
fold_csv_path = NORMAL_RUN_DIR / 'fold_metrics.csv'

if not cv_summary_path.exists():
    raise RuntimeError(f'Missing {cv_summary_path}')
if not fold_csv_path.exists():
    raise RuntimeError(f'Missing {fold_csv_path}')

cv_summary = json.loads(cv_summary_path.read_text())
cv = cv_summary['cv_metrics']
fold_df = pd.read_csv(fold_csv_path)

metrics_row = {
    'variant': 'step44_normal_holdout_test',
    'acc': float(cv['test_acc']['mean']),
    'auc': float(cv['test_auc']['mean']),
    'f1': float(cv['test_f1']['mean']),
    'prec': float(cv['test_prec']['mean']),
    'rec': float(cv['test_rec']['mean']),
    'bal_acc': float(cv['test_bal_acc']['mean']),
    'tp': float(fold_df['test_tp'].sum()),
    'tn': float(fold_df['test_tn'].sum()),
    'fp': float(fold_df['test_fp'].sum()),
    'fn': float(fold_df['test_fn'].sum()),
}

normal_df = pd.DataFrame([metrics_row])
display(normal_df)

print('Clear Metrics Summary (Step44 normal test split):')
print(
    f"ACC={metrics_row['acc']:.4f} AUC={metrics_row['auc']:.4f} F1={metrics_row['f1']:.4f} "
    f"PREC={metrics_row['prec']:.4f} REC={metrics_row['rec']:.4f} BAL_ACC={metrics_row['bal_acc']:.4f} "
    f"| TP={int(metrics_row['tp'])} TN={int(metrics_row['tn'])} FP={int(metrics_row['fp'])} FN={int(metrics_row['fn'])}"
)

# Graphical confusion matrix
cm = np.array([[metrics_row['tn'], metrics_row['fp']], [metrics_row['fn'], metrics_row['tp']]], dtype=float)
fig, ax = plt.subplots(figsize=(5, 4))
ax.imshow(cm, cmap='Blues')
ax.set_xticks([0, 1], labels=['Pred Real', 'Pred Fake'])
ax.set_yticks([0, 1], labels=['True Real', 'True Fake'])
ax.set_title('Step44 Normal Test Confusion Matrix')
for i in range(2):
    for j in range(2):
        ax.text(j, i, f"{int(round(cm[i,j]))}", ha='center', va='center', color='black')
plt.tight_layout()
plt.show()
# Out:
#                       variant      acc       auc        f1     prec       rec  \
# 0  step44_normal_holdout_test  0.99884  0.999665  0.999406  0.99905  0.999762
#
#     bal_acc      tp    tn   fp   fn
# 0  0.979881  4208.0  96.0  4.0  1.0
# Clear Metrics Summary (Step44 normal test split):
# ACC=0.9988 AUC=0.9997 F1=0.9994 PREC=0.9991 REC=0.9998 BAL_ACC=0.9799 | TP=4208 TN=96 FP=4 FN=1

# %% [markdown]
# ### Step40 single-seed pilot checks (clip-fix ablations)
#
# These were intermediate single-seed probes before multiseed consolidation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

PILOT_SUMMARIES = [
    BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step40_clipfix_pilot_s42_20260315_211711/cv_summary.json',
    BACKEND_ROOT / 'models/experiment_logs/fakeav_mrdf5cv_step40b_clipfix_baseline_pilot_s42_20260315_211817/cv_summary.json',
]

pilot_rows = []
for p in PILOT_SUMMARIES:
    obj = _read_json(p)
    if obj is None:
        continue
    m = obj.get('cv_metrics', {})
    run_dir = p.parent
    fold_csv = run_dir / 'fold_metrics.csv'
    tp = tn = fp = fn = float('nan')
    if fold_csv.exists():
        df_fold = pd.read_csv(fold_csv)
        tp = float(df_fold['test_tp'].sum())
        tn = float(df_fold['test_tn'].sum())
        fp = float(df_fold['test_fp'].sum())
        fn = float(df_fold['test_fn'].sum())
    pilot_rows.append({
        'run_tag': obj.get('run_tag'),
        'loss': _safe_get(obj, 'protocol', 'loss'),
        'ranking_w': _safe_get(obj, 'protocol', 'ranking_loss_weight'),
        'stage0': _safe_get(obj, 'protocol', 'stage0_avc_pretrain'),
        'acc': _round(_safe_get(m, 'test_acc', 'mean')),
        'auc': _round(_safe_get(m, 'test_auc', 'mean')),
        'f1': _round(_safe_get(m, 'test_f1', 'mean')),
        'prec': _round(_safe_get(m, 'test_prec', 'mean')),
        'rec': _round(_safe_get(m, 'test_rec', 'mean')),
        'tp': tp,
        'tn': tn,
        'fp': fp,
        'fn': fn,
    })

pilot_df = pd.DataFrame(pilot_rows)
display(pilot_df)

print()
print('Clear Metrics Summary (Step40 pilots):')
if len(pilot_rows) == 0:
    print('No pilot metrics found.')
else:
    for _, r in pilot_df.iterrows():
        print(
            f"{r.get('run_tag','NA')}: "
            f"ACC={float(r.get('acc', float('nan'))):.4f} "
            f"AUC={float(r.get('auc', float('nan'))):.4f} "
            f"F1={float(r.get('f1', float('nan'))):.4f} "
            f"PREC={float(r.get('prec', float('nan'))):.4f} "
            f"REC={float(r.get('rec', float('nan'))):.4f} "
            f"| TP={int(r.get('tp',0)) if pd.notna(r.get('tp')) else 'NA'} "
            f"TN={int(r.get('tn',0)) if pd.notna(r.get('tn')) else 'NA'} "
            f"FP={int(r.get('fp',0)) if pd.notna(r.get('fp')) else 'NA'} "
            f"FN={int(r.get('fn',0)) if pd.notna(r.get('fn')) else 'NA'}"
        )

# Graphical confusion matrices
def _plot_cm(ax, r):
    if pd.isna(r.get('tp')) or pd.isna(r.get('tn')) or pd.isna(r.get('fp')) or pd.isna(r.get('fn')):
        ax.axis('off')
        ax.set_title(str(r.get('run_tag', 'NA')))
        return
    mat = np.array([[float(r['tn']), float(r['fp'])], [float(r['fn']), float(r['tp'])]], dtype=float)
    ax.imshow(mat, cmap='Blues')
    ax.set_xticks([0, 1], labels=['Pred Real', 'Pred Fake'])
    ax.set_yticks([0, 1], labels=['True Real', 'True Fake'])
    ax.set_title(str(r.get('run_tag', 'NA')).split('_s42_')[0][-28:])
    for i in range(2):
        for j in range(2):
            ax.text(j, i, f"{int(round(mat[i,j]))}", ha='center', va='center', color='black')

if len(pilot_df):
    fig, axes = plt.subplots(1, len(pilot_df), figsize=(6 * len(pilot_df), 5))
    if len(pilot_df) == 1:
        axes = [axes]
    for ax, (_, r) in zip(axes, pilot_df.iterrows()):
        _plot_cm(ax, r)
    plt.tight_layout()
    plt.show()
# Out:
#                                              run_tag loss  ranking_w  stage0  \
# 0  fakeav_mrdf5cv_step40_clipfix_pilot_s42_202603...  bce        0.3   False
# 1  fakeav_mrdf5cv_step40b_clipfix_baseline_pilot_...  bce        0.2   False
#
#         acc       auc        f1      prec       rec      tp    tn    fp     fn
# 0  0.911812  0.837441  0.953454  0.984071  0.924685  3892.0  37.0  63.0  317.0
# 1  0.909492  0.837270  0.952135  0.984768  0.921597  3879.0  40.0  60.0  330.0
# Clear Metrics Summary (Step40 pilots):
# fakeav_mrdf5cv_step40_clipfix_pilot_s42_20260315_211711: ACC=0.9118 AUC=0.8374 F1=0.9535 PREC=0.9841 REC=0.9247 | TP=3892 TN=37 FP=63 FN=317
# fakeav_mrdf5cv_step40b_clipfix_baseline_pilot_s42_20260315_211817: ACC=0.9095 AUC=0.8373 F1=0.9521 PREC=0.9848 REC=0.9216 | TP=3879 TN=40 FP=60 FN=330

# %% [markdown]
# ### Re-run commands used for latest steps
#
# Run from `backend/`.
# - `step43` reproduces the aggressive all-source/stage0/class-balanced run.
# - `step44` reproduces the latest highest-metric run.
# - post-hoc command loads temperature-aware constrained threshold metrics.

# %%
REPRO_CMDS = {
    'step43_train_multiseed': r'''python scripts/run_fakeav_mrdf_5fold_cv.py \
  --run-prefix fakeav_mrdf5cv_step43_stage0_allsrc_cb_auc \
  --feature-profile nextgen \
  --processed-csv data/processed/causal_multimodal_dataset_effnet_w2v2_physfix_fullvis_proxy_nextgen.csv \
  --split-mode full \
  --seed-list 42,1337,2026 \
  --split-seed 42 \
  --train-source all \
  --class-balanced-loss --class-balance-beta 0.9999 \
  --focal-bce-mix 0.25 \
  --stage0-avc-pretrain --stage0-epochs 8 --stage0-patience 3 --stage0-lr 1e-4 \
  --ranking-loss-weight 0.35 --ranking-margin 0.2 --ranking-max-pairs 4096 \
  --phase2-enable --phase2-rounds 4 --phase2-hardneg-source val \
  --phase2-use-hard-positives --phase2-hardpos-source val \
  --hard-negative-weight 4.0 --hard-positive-weight 2.0 \
  --target-acc 0.90 --target-precision 0.90 --target-recall 0.90 --target-f1 0.90 \
  --target-spec 0.55 --min-domain-spec 0.40 \
  --eval-threshold-source val_target --eval-threshold-priority balanced_acc \
  --ensemble-enable --ensemble-rank-metric val_bal_acc --ensemble-weighting uniform
'''.strip(),

    'step43_posthoc_tempaware': r'''python scripts/posthoc_multiseed_threshold_sweep.py \
  --multiseed-summary models/experiment_logs/fakeav_mrdf5cv_step43_stage0_allsrc_cb_auc_multiseed_20260316_041619/multiseed_summary.json \
  --feature-profile nextgen \
  --ensemble-rank-metric val_auc \
  --ensemble-weighting rank_metric \
  --threshold-priority balanced_acc
'''.strip(),

    'step44_train_multiseed': r'''python scripts/run_fakeav_mrdf_5fold_cv.py \
  --processed-csv data/processed/causal_multimodal_dataset_effnet_w2v2_physfix_realvis.csv \
  --run-prefix fakeav_mrdf5cv_step44_realvis_multiseed \
  --seed-list 42,1337,2026 --split-seed 42 --split-mode full \
  --feature-profile extended --missing-feature-policy error \
  --train-source fakeavceleb \
  --loss focal \
  --phase2-enable --phase2-rounds 3 --phase2-hardneg-source val \
  --phase2-use-hard-positives --phase2-hardpos-source val \
  --hard-negative-weight 6.0 --hard-positive-weight 3.0 --hardpos-scenario none \
  --phase2-scenario-focus audio_only_fake --phase2-scenario-focus-weight 1.75 \
  --eval-threshold-source val_target --eval-threshold-priority balanced_acc \
  --train-target-priority balanced_acc \
  --target-acc 0.90 --target-precision 0.87 --target-recall 0.88 --target-f1 0.88 --target-spec 0.35 \
  --min-domain-spec 0.25 --min-domain-rec 0.82 \
  --ensemble-enable --ensemble-rank-metric val_auc --ensemble-weighting rank_metric
'''.strip(),

    'step44_posthoc_tempaware_accuracy': r'''python scripts/posthoc_multiseed_threshold_sweep.py \
  --multiseed-summary models/experiment_logs/fakeav_mrdf5cv_step44_realvis_multiseed_multiseed_20260316_043357/multiseed_summary.json \
  --feature-profile extended \
  --ensemble-rank-metric val_auc \
  --ensemble-weighting rank_metric \
  --threshold-priority accuracy \
  --user-target-acc 0.98 --user-target-prec 0.90 --user-target-rec 0.90 --user-target-f1 0.90
'''.strip(),
}

for name, cmd in REPRO_CMDS.items():
    print(f'[{name}]')
    print(cmd)
    print('-' * 80)
# Out:
# [step43_train_multiseed]
# python scripts/run_fakeav_mrdf_5fold_cv.py \
#   --run-prefix fakeav_mrdf5cv_step43_stage0_allsrc_cb_auc \
#   --feature-profile nextgen \
#   --processed-csv data/processed/causal_multimodal_dataset_effnet_w2v2_physfix_fullvis_proxy_nextgen.csv \
#   --split-mode full \
#   --seed-list 42,1337,2026 \
#   --split-seed 42 \
#   --train-source all \
#   --class-balanced-loss --class-balance-beta 0.9999 \
#   --focal-bce-mix 0.25 \
#   --stage0-avc-pretrain --stage0-epochs 8 --stage0-patience 3 --stage0-lr 1e-4 \
#   --ranking-loss-weight 0.35 --ranking-margin 0.2 --ranking-max-pairs 4096 \
#   --phase2-enable --phase2-rounds 4 --phase2-hardneg-source val \
#   --phase2-use-hard-positives --phase2-hardpos-source val \
#   --hard-negative-weight 4.0 --hard-positive-weight 2.0 \
#   --target-acc 0.90 --target-precision 0.90 --target-recall 0.90 --target-f1 0.90 \
#   --target-spec 0.55 --min-domain-spec 0.40 \
# ...

# %% [markdown]
# ### DFDC-Only Evaluation (FakeAV-trained model)
# Run this cell to evaluate on **DFDC rows only** (filtered from mixed val/test CSVs).
# It auto-loads the latest **Step46 selected model** from robust-selection JSON when available,
# ensures physical proxy columns exist (auto-generates them if missing),
# prints ACC/AUC/F1/PREC/REC/SPEC/BAL_ACC, and plots confusion matrices.

# %%
# DFDC-only evaluation (report + val-tuned threshold)
from pathlib import Path
import importlib.util
import json
import subprocess
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# Resolve backend root robustly (works in repo root or backend folder)
PROJECT_ROOT = Path.cwd().resolve()
if (PROJECT_ROOT / 'backend' / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT / 'backend'
elif not (PROJECT_ROOT / 'src').exists() and (PROJECT_ROOT.parent / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

run_script = PROJECT_ROOT / 'scripts' / 'run_fakeav_mrdf_5fold_cv.py'
spec = importlib.util.spec_from_file_location('mrdf_run_module', run_script)
mod = importlib.util.module_from_spec(spec)
assert spec is not None and spec.loader is not None
spec.loader.exec_module(mod)

# -------- Config --------
FEATURE_PROFILE = 'extended'
MANUAL_MODEL_DIR = None  # e.g. Path('/abs/path/to/model_dir') to override auto-selection

# Auto-selection priority:
# 1) MANUAL_MODEL_DIR (if set)
# 2) Latest Step47 run best fold model (by val_auc)
# 3) Step46 robust-selection best model
# 4) Step44 fallback
STEP47_RUN_PREFIX = 'step47_fakeav_only_dfdc_push'
ROBUST_SELECTION_JSON = PROJECT_ROOT / 'models' / 'experiment_logs' / 'step46_fakeav_robust_constrained_robust_selection.json'
FALLBACK_MODEL_DIR = PROJECT_ROOT / 'models' / 'fakeav_mrdf5cv_step44_normaltest_single_s42_20260316_154454_fold_01_p1_focal_lr0p0003'

VAL_CANDIDATES = [
    PROJECT_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val_dfdc_augfix3_physfix.csv',
    PROJECT_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val_dfdc_augfix3.csv',
    PROJECT_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val.csv',
]
TEST_CANDIDATES = [
    PROJECT_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test_dfdc_augfix3_physfix.csv',
    PROJECT_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test_dfdc_augfix3.csv',
    PROJECT_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test.csv',
]

PHYS_COLS = [
    'video_motion_noise_ratio',
    'video_shape_noise_ratio',
    'video_temporal_instability',
    'video_detection_dropout',
    'video_compression_proxy',
]


def _best_model_from_latest_run_prefix(prefix: str):
    logs_root = PROJECT_ROOT / 'models' / 'experiment_logs'
    run_dirs = sorted(
        [p for p in logs_root.glob(f'{prefix}_s*_20*') if p.is_dir()],
        key=lambda p: p.stat().st_mtime,
        reverse=True,
    )
    for run_dir in run_dirs:
        fold_csv = run_dir / 'fold_metrics.csv'
        if not fold_csv.exists():
            continue
        try:
            df = pd.read_csv(fold_csv)
        except Exception:
            continue
        if 'error' in df.columns:
            df = df[df['error'].isna()].copy()
        if df.empty:
            continue

        rank_cols = [c for c in ['val_auc', 'val_bal_acc', 'val_f1', 'test_auc'] if c in df.columns]
        if not rank_cols:
            continue
        rank_col = rank_cols[0]
        row = df.sort_values(by=rank_col, ascending=False).iloc[0]
        mdir = Path(str(row.get('model_dir', '')))
        if mdir.exists() and (mdir / 'cfn_emb.pth').exists():
            return {
                'model_dir': mdir,
                'run_dir': run_dir,
                'rank_col': rank_col,
                'rank_value': float(row.get(rank_col, float('nan'))),
            }
    return None


def _resolve_model_dir() -> Path:
    if MANUAL_MODEL_DIR is not None:
        return Path(MANUAL_MODEL_DIR)

    step47 = _best_model_from_latest_run_prefix(STEP47_RUN_PREFIX)
    if step47 is not None:
        print(
            f"Using Step47 best model from {step47['run_dir'].name}: "
            f"{step47['model_dir']} ({step47['rank_col']}={step47['rank_value']:.4f})"
        )
        return step47['model_dir']

    if ROBUST_SELECTION_JSON.exists():
        try:
            obj = json.loads(ROBUST_SELECTION_JSON.read_text())
            mdir = Path(obj.get('best_model', {}).get('model_dir', ''))
            if mdir.exists() and (mdir / 'cfn_emb.pth').exists():
                print(f'Using Step46 robust-selection model: {mdir}')
                return mdir
        except Exception:
            pass

    if FALLBACK_MODEL_DIR.exists() and (FALLBACK_MODEL_DIR / 'cfn_emb.pth').exists():
        print(f'Using fallback model: {FALLBACK_MODEL_DIR}')
        return FALLBACK_MODEL_DIR

    raise RuntimeError('Could not resolve MODEL_DIR from Step47/Step46/fallback')


def _resolve_csv(candidates):
    for p in candidates:
        if p.exists():
            return p
    raise RuntimeError(f'No candidate CSV exists: {candidates}')


def _ensure_physfix(csv_path: Path, suffix: str) -> Path:
    probe = pd.read_csv(csv_path, nrows=1)
    if all(c in probe.columns for c in PHYS_COLS):
        return csv_path

    aug_script = PROJECT_ROOT / 'scripts' / 'augment_processed_with_artifact_proxies.py'
    if not aug_script.exists():
        raise RuntimeError(f'Physical-proxy script not found: {aug_script}')

    out_csv = PROJECT_ROOT / 'models' / 'experiment_logs' / f'tmp_{csv_path.stem}_{suffix}_physfix.csv'
    out_csv.parent.mkdir(parents=True, exist_ok=True)

    subprocess.run(
        [
            sys.executable,
            str(aug_script),
            '--input-csv', str(csv_path),
            '--output-csv', str(out_csv),
        ],
        check=True,
    )
    return out_csv


def _dfdc_only_csv(src_csv: Path, suffix: str):
    df = pd.read_csv(src_csv)
    if 'dataset' not in df.columns:
        raise RuntimeError(f"Missing 'dataset' column in {src_csv}")
    dfdc = df[df['dataset'].astype(str).str.lower().eq('dfdc')].copy()
    if dfdc.empty:
        raise RuntimeError(f'No DFDC rows found in {src_csv}')
    out_csv = PROJECT_ROOT / 'models' / 'experiment_logs' / f'tmp_dfdc_only_{suffix}.csv'
    out_csv.parent.mkdir(parents=True, exist_ok=True)
    dfdc.to_csv(out_csv, index=False)
    return out_csv, dfdc


def _best_balacc_threshold(y_true: np.ndarray, probs: np.ndarray) -> float:
    grid = np.linspace(0.0, 1.0, 1001, dtype=float)
    best_t, best_bal, best_f1 = 0.5, -1.0, -1.0
    y = np.asarray(y_true).astype(int)
    p = np.asarray(probs, dtype=float)
    for t in grid:
        pred = (p >= float(t)).astype(int)
        tp = int(np.sum((pred == 1) & (y == 1)))
        tn = int(np.sum((pred == 0) & (y == 0)))
        fp = int(np.sum((pred == 1) & (y == 0)))
        fn = int(np.sum((pred == 0) & (y == 1)))
        rec = tp / (tp + fn + 1e-8)
        spec = tn / (tn + fp + 1e-8)
        bal = 0.5 * (rec + spec)
        prec = tp / (tp + fp + 1e-8)
        f1 = 2 * prec * rec / (prec + rec + 1e-8)
        if bal > best_bal or (abs(bal - best_bal) <= 1e-12 and f1 > best_f1):
            best_t, best_bal, best_f1 = float(t), float(bal), float(f1)
    return best_t


def _metrics_at(y_true: np.ndarray, probs: np.ndarray, threshold: float):
    y = np.asarray(y_true).astype(int)
    p = np.asarray(probs, dtype=float)
    pred = (p >= float(threshold)).astype(int)
    tp = int(np.sum((pred == 1) & (y == 1)))
    tn = int(np.sum((pred == 0) & (y == 0)))
    fp = int(np.sum((pred == 1) & (y == 0)))
    fn = int(np.sum((pred == 0) & (y == 1)))

    acc = (tp + tn) / max(tp + tn + fp + fn, 1)
    prec = tp / (tp + fp + 1e-8)
    rec = tp / (tp + fn + 1e-8)
    f1 = 2 * prec * rec / (prec + rec + 1e-8)
    spec = tn / (tn + fp + 1e-8)
    bal_acc = 0.5 * (rec + spec)
    auc = float(roc_auc_score(y, p)) if len(np.unique(y)) > 1 else float('nan')

    return {
        'threshold': float(threshold),
        'acc': float(acc),
        'auc': float(auc),
        'f1': float(f1),
        'prec': float(prec),
        'rec': float(rec),
        'spec': float(spec),
        'bal_acc': float(bal_acc),
        'tp': tp,
        'tn': tn,
        'fp': fp,
        'fn': fn,
    }, confusion_matrix(y, pred, labels=[0, 1])


MODEL_DIR = _resolve_model_dir()
VAL_CSV = _ensure_physfix(_resolve_csv(VAL_CANDIDATES), 'val_auto')
TEST_CSV = _ensure_physfix(_resolve_csv(TEST_CANDIDATES), 'test_auto')

val_dfdc_csv, val_dfdc_df = _dfdc_only_csv(VAL_CSV, 'val_from_notebook')
test_dfdc_csv, test_dfdc_df = _dfdc_only_csv(TEST_CSV, 'test_from_notebook')

_, y_val, _, p_val, report_thr = mod._predict_probs(
    model_dir=MODEL_DIR,
    csv_path=val_dfdc_csv,
    feature_profile=FEATURE_PROFILE,
)
_, y_test, _, p_test, _ = mod._predict_probs(
    model_dir=MODEL_DIR,
    csv_path=test_dfdc_csv,
    feature_profile=FEATURE_PROFILE,
)

y_val = np.asarray(y_val, dtype=int)
y_test = np.asarray(y_test, dtype=int)
p_val = np.asarray(p_val, dtype=float)
p_test = np.asarray(p_test, dtype=float)

val_best_bal_thr = _best_balacc_threshold(y_val, p_val)

m_report, cm_report = _metrics_at(y_test, p_test, float(report_thr))
m_tuned, cm_tuned = _metrics_at(y_test, p_test, float(val_best_bal_thr))

print('DFDC-only Evaluation')
print(f'Model: {MODEL_DIR}')
print(f'Val CSV source: {VAL_CSV}')
print(f'Test CSV source: {TEST_CSV}')
print(f'DFDC rows: val={len(val_dfdc_df)}, test={len(test_dfdc_df)}')
print('')

for tag, m in [('report_threshold', m_report), ('val_tuned_bal_acc_threshold', m_tuned)]:
    print(f'[{tag}]')
    print(
        f"thr={m['threshold']:.6f} | "
        f"ACC={m['acc']:.4f} AUC={m['auc']:.4f} F1={m['f1']:.4f} "
        f"PREC={m['prec']:.4f} REC={m['rec']:.4f} SPEC={m['spec']:.4f} BAL_ACC={m['bal_acc']:.4f}"
    )
    print(f"TP={m['tp']} TN={m['tn']} FP={m['fp']} FN={m['fn']}")
    print('')

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
ConfusionMatrixDisplay(cm_report, display_labels=['Real(0)', 'Fake(1)']).plot(ax=axes[0], values_format='d', colorbar=False)
axes[0].set_title(f"DFDC Test CM @ report thr={m_report['threshold']:.3f}")
ConfusionMatrixDisplay(cm_tuned, display_labels=['Real(0)', 'Fake(1)']).plot(ax=axes[1], values_format='d', colorbar=False)
axes[1].set_title(f"DFDC Test CM @ val-tuned thr={m_tuned['threshold']:.3f}")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[65], line 26
#      24 mod = importlib.util.module_from_spec(spec)
#      25 assert spec is not None and spec.loader is not None
# ---> 26 spec.loader.exec_module(mod)
#      28 # -------- Config --------
#      29 FEATURE_PROFILE = 'extended'
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Documents/GitHub/FYP/CausalX-Project/backend/scripts/run_fakeav_mrdf_5fold_cv.py:43
#      41 from src.cvi.feature_schema import NEXTGEN_AV_FEATURES, NEXTGEN_PHYS_FEATURES, resolve_feature_columns
#      42 from src.modules.causal_fusion import CausalFusionNetworkV2
# ---> 43 from src.training.train_cfn import (
#      44     apply_temperature_scaling,
#      45     build_feature_matrix,
# ...

# %% [markdown]
# ### Step46: FakeAV Robust Constrained Training + Selection
# Runs the new Step46 pipeline (multiseed training, post-hoc temperature-aware sweep, and constrained robustness selection against FakeAV stress splits).
# Set `RUN_STEP46 = True` in the next cell to execute.

# %%
# Step46 robust constrained run (multiseed + posthoc + constrained selection)
from pathlib import Path
import os
import shlex
import subprocess

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
RUN_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_step46_fakeav_robust_constrained.sh'

RUN_PREFIX = 'step46_fakeav_robust_constrained'
TEACHER_MODEL_DIR = BACKEND_ROOT / 'models/fakeav_mrdf5cv_step44_normaltest_single_s42_20260316_154454_fold_01_p1_focal_lr0p0003'

RUN_STEP46 = False  # Set True to execute

cmd = ['bash', str(RUN_SCRIPT), str(RUN_PREFIX), str(TEACHER_MODEL_DIR)]
print('Step46 command:')
print(' '.join(shlex.quote(x) for x in cmd))

if RUN_STEP46:
    env = dict(os.environ)
    env.setdefault('TORCH_HOME', str(BACKEND_ROOT / '.torch_cache'))
    # Run from repo root so relative paths inside scripts stay consistent.
    subprocess.run(cmd, cwd=str(BACKEND_ROOT.parent), env=env, check=True)
else:
    print('RUN_STEP46=False. Set to True when you want to launch training.')

# %% [markdown]
# ### Step46: Constrained Robustness Selection Report
# Loads the constrained selector output and highlights the best feasible model (no clean FakeAV metric drop beyond epsilon).

# %%
# Step46 constrained robustness selection report
from pathlib import Path
import json
import pandas as pd
import matplotlib.pyplot as plt

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
RUN_PREFIX = 'step46_fakeav_robust_constrained'

sel_json = BACKEND_ROOT / 'models' / 'experiment_logs' / f'{RUN_PREFIX}_robust_selection.json'
sel_csv = BACKEND_ROOT / 'models' / 'experiment_logs' / f'{RUN_PREFIX}_robust_selection.csv'

print('Selection JSON:', sel_json)
print('Selection CSV :', sel_csv)

if not sel_json.exists() or not sel_csv.exists():
    print('Step46 outputs not found yet. Run the previous cell with RUN_STEP46=True first.')
else:
    obj = json.loads(sel_json.read_text())
    df = pd.read_csv(sel_csv)

    print('Selection mode:', obj.get('metadata', {}).get('selection_mode'))
    print('Candidates:', obj.get('metadata', {}).get('num_candidates'))
    print('Clean constraints:', obj.get('constraints', {}))

    best = obj.get('best_model') or {}
    if best:
        print('Selected model:')
        print(best.get('model_dir'))
        print(
            f"clean_acc={float(best.get('clean_acc', float('nan'))):.4f} "
            f"clean_f1={float(best.get('clean_f1', float('nan'))):.4f} "
            f"clean_auc={float(best.get('clean_auc', float('nan'))):.4f} "
            f"stress_auc_mean={float(best.get('stress_auc_mean', float('nan'))):.4f} "
            f"stress_f1_mean={float(best.get('stress_f1_mean', float('nan'))):.4f} "
            f"stress_bal_min={float(best.get('stress_bal_acc_min', float('nan'))):.4f} "
            f"robust_score={float(best.get('robust_score', float('nan'))):.4f}"
        )

    view_cols = [
        'model_dir', 'meets_clean_constraints',
        'clean_acc', 'clean_f1', 'clean_auc',
        'stress_auc_mean', 'stress_f1_mean', 'stress_bal_acc_min', 'robust_score'
    ]
    view_cols = [c for c in view_cols if c in df.columns]

    ranked = df.sort_values(
        by=['meets_clean_constraints', 'robust_score', 'stress_auc_mean', 'stress_f1_mean'],
        ascending=False,
    )

    print('Top candidates:')
    display(ranked[view_cols].head(10))

    plot_df = ranked.head(10).copy()
    plt.figure(figsize=(10, 4))
    plt.bar(range(len(plot_df)), plot_df['robust_score'])
    plt.xticks(range(len(plot_df)), [Path(x).name for x in plot_df['model_dir']], rotation=45, ha='right')
    plt.ylabel('robust_score')
    plt.title('Step46 Top-10 Robust Scores (constrained ranking)')
    plt.tight_layout()
    plt.show()
# Out:
# Selection JSON: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/experiment_logs/step46_fakeav_robust_constrained_robust_selection.json
# Selection CSV : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/experiment_logs/step46_fakeav_robust_constrained_robust_selection.csv
# Selection mode: feasible_only
# Candidates: 15
# Clean constraints: {'floor_acc': 0.9836666666666667, 'floor_f1': 0.9838421001341762, 'floor_auc': 0.9978222222222223, 'teacher_model_dir': '/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/fakeav_mrdf5cv_step44_normaltest_single_s42_20260316_154454_fold_01_p1_focal_lr0p0003', 'teacher_metrics': {'tp': 75.0, 'tn': 73.0, 'fp': 2.0, 'fn': 0.0, 'acc': 0.9866666666666667, 'prec': 0.9740259738994772, 'rec': 0.9999999998666668, 'f1': 0.9868421001341762, 'spec': 0.9733333332035556, 'bal_acc': 0.9866666665351111, 'auc': 0.9998222222222223}, 'eps': {'acc': 0.003, 'f1': 0.003, 'auc': 0.002}}
# Selected model:
# ...

# %% [markdown]
# ### Step47: FakeAV-Only Training for Better DFDC Generalization\n
# Runs the recommended nextgen regime while keeping **training source = FakeAVCeleb only**.\n
# Includes: Stage0 AV pretrain, paired real/fake sampling, GenD adaptation, LN-only tuning,\n
# joint CE + AUC margin, hyperspherical regularization, artifact-based auxiliary losses, and stricter specificity constraints.\n
# Set `RUN_STEP47 = True` to execute.\n

# %%
# Step47 run (FakeAV-only, DFDC-generalization push)
from pathlib import Path
import os
import shlex
import subprocess

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
PYTHON = BACKEND_ROOT / '.venv' / 'bin' / 'python'
RUN_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_fakeav_mrdf_5fold_cv.py'

RUN_PREFIX = 'step47_fakeav_only_dfdc_push'

# Prefer nextgen feature table; create fallback if missing.
NEXTGEN_CSV = BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_effnet_w2v2_physfix_fullvis_proxy_nextgen.csv'
FALLBACK_BASE = BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_effnet_w2v2_physfix_fullvis_proxy.csv'

if not NEXTGEN_CSV.exists() and FALLBACK_BASE.exists():
    print('Generating missing nextgen CSV from physfix_fullvis_proxy...')
    subprocess.run(
        [
            str(PYTHON),
            str(BACKEND_ROOT / 'scripts' / 'augment_processed_with_nextgen_regime.py'),
            '--input-csv', str(FALLBACK_BASE),
            '--output-csv', str(NEXTGEN_CSV),
        ],
        check=True,
        cwd=str(BACKEND_ROOT.parent),
    )

if not NEXTGEN_CSV.exists():
    raise FileNotFoundError(f'Nextgen CSV not found: {NEXTGEN_CSV}')

RUN_STEP47 = True  

cmd = [
    str(PYTHON), str(RUN_SCRIPT),
    '--processed-csv', str(NEXTGEN_CSV),
    '--run-prefix', RUN_PREFIX,
    '--seed-list', '42,1337,2026',
    '--split-seed', '42',
    '--n-splits', '5',
    '--split-mode', 'full',
    '--train-source', 'fakeavceleb',
    '--feature-profile', 'nextgen',
    '--loss', 'focal',
    '--focal-bce-mix', '0.35',
    '--class-balanced-loss',
    '--class-balance-beta', '0.999',
    '--paired-rf-sampling',
    '--stage0-avc-pretrain',
    '--stage0-epochs', '8',
    '--stage0-patience', '3',
    '--stage0-lr', '1e-4',
    '--gend-visual-adapt',
    '--gend-adapt-strength', '0.45',
    '--gend-adapt-prob', '1.0',
    '--enable-av-layernorm-adapter',
    '--ln-only-finetune',
    '--ln-only-unfreeze-heads',
    '--joint-ce-auc-margin',
    '--auc-margin-loss-weight', '0.30',
    '--auc-margin', '0.10',
    '--auc-margin-max-pairs', '1024',
    '--hyperspherical-reg-weight', '0.02',
    '--hyperspherical-margin', '0.20',
    '--causal-breach-loss-weight', '0.05',
    '--causal-breach-target', 'artifact_heuristic',
    '--distortion-loss-weight', '0.05',
    '--distortion-target', 'artifact_heuristic',
    '--phase2-enable',
    '--phase2-rounds', '3',
    '--phase2-hardneg-source', 'val',
    '--hard-negative-weight', '8.0',
    '--phase2-use-hard-positives',
    '--hard-positive-weight', '2.5',
    '--enable-temperature-calibration',
    '--eval-threshold-source', 'val_target',
    '--eval-threshold-priority', 'balanced_acc',
    '--target-acc', '0.95',
    '--target-precision', '0.93',
    '--target-recall', '0.94',
    '--target-f1', '0.94',
    '--target-spec', '0.55',
    '--min-domain-spec', '0.45',
    '--min-domain-rec', '0.88',
    '--phase-selection-priority', 'target_balanced',
    '--ensemble-enable',
    '--ensemble-rank-metric', 'val_auc',
    '--ensemble-weighting', 'rank_metric',
]

print('Step47 command:')
print(' '.join(shlex.quote(x) for x in cmd))

if RUN_STEP47:
    env = dict(os.environ)
    env.setdefault('TORCH_HOME', str(BACKEND_ROOT / '.torch_cache'))
    subprocess.run(cmd, cwd=str(BACKEND_ROOT.parent), env=env, check=True)
else:
    print('RUN_STEP47=False. Set to True when you want to launch Step47.')

# %% [markdown]
# ### Step47: Quick Run Summary + Best Fold Model\n
# Shows latest Step47 per-seed run folders, best fold model by `val_auc`, and ensemble CV metrics (if available).\n

# %%
# Step47 latest summary (best fold model + ensemble metrics)
from pathlib import Path
import json
import pandas as pd

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
RUN_PREFIX = 'step47_fakeav_only_dfdc_push'
LOGS_ROOT = BACKEND_ROOT / 'models' / 'experiment_logs'

seed_runs = sorted(
    [p for p in LOGS_ROOT.glob(f'{RUN_PREFIX}_s*_20*') if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)
print('Latest Step47 seed runs:')
for p in seed_runs[:6]:
    print(' -', p)

best_model = None
best_score = float('-inf')
best_from = None

for run_dir in seed_runs:
    fold_csv = run_dir / 'fold_metrics.csv'
    if not fold_csv.exists():
        continue
    try:
        df = pd.read_csv(fold_csv)
    except Exception:
        continue
    if 'error' in df.columns:
        df = df[df['error'].isna()].copy()
    if df.empty or 'model_dir' not in df.columns:
        continue
    rank_col = 'val_auc' if 'val_auc' in df.columns else ('val_bal_acc' if 'val_bal_acc' in df.columns else None)
    if rank_col is None:
        continue
    row = df.sort_values(by=rank_col, ascending=False).iloc[0]
    mdir = Path(str(row['model_dir']))
    score = float(row[rank_col])
    if mdir.exists() and (mdir / 'cfn_emb.pth').exists() and score > best_score:
        best_score = score
        best_model = mdir
        best_from = (run_dir, rank_col)

print('')
if best_model is None:
    print('No Step47 best model found yet. Run the previous cell with RUN_STEP47=True.')
else:
    print('Best Step47 model (for DFDC eval):')
    print(best_model)
    print(f'From run: {best_from[0].name} | metric: {best_from[1]}={best_score:.4f}')

multiseed_runs = sorted(
    [p for p in LOGS_ROOT.glob(f'{RUN_PREFIX}_multiseed_20*') if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)
print('')
if not multiseed_runs:
    print('No Step47 multiseed summary directory found yet.')
else:
    ms = multiseed_runs[0]
    print('Latest multiseed dir:', ms)
    ens = ms / 'ensemble_summary.json'
    if ens.exists():
        obj = json.loads(ens.read_text())
        cv = obj.get('cv_metrics', {})
        def _m(k):
            v = cv.get(k, {})
            return float(v.get('mean', float('nan')))
        print(
            f"Ensemble CV mean: ACC={_m('test_acc'):.4f} AUC={_m('test_auc'):.4f} "
            f"F1={_m('test_f1'):.4f} PREC={_m('test_prec'):.4f} REC={_m('test_rec'):.4f} "
            f"BAL_ACC={_m('test_bal_acc'):.4f}"
        )
    else:
        print('ensemble_summary.json not found in latest multiseed dir.')

# %% [markdown]
# ### Step48: FakeAV-Anchor + DFDC AUC Push (Source-Only)
# Runs a conservative multiseed recipe to preserve FakeAV performance while pushing DFDC cross-data AUC.
# Set `RUN_STEP48 = True` to execute training + temperature-aware post-hoc sweep.

# %%
# Step48 run (FakeAV-anchor + DFDC AUC push, source-only)
from pathlib import Path
import os
import shlex
import subprocess

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
RUN_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_step48_fakeav_anchor_dfdc75.sh'
RUN_PREFIX = 'step48_fakeav_anchor_dfdc75'

RUN_STEP48 = False  # Set True to execute

cmd = ['bash', str(RUN_SCRIPT), str(RUN_PREFIX)]
print('Step48 command:')
print(' '.join(shlex.quote(x) for x in cmd))

if RUN_STEP48:
    env = dict(os.environ)
    env.setdefault('TORCH_HOME', str(BACKEND_ROOT / '.torch_cache'))
    subprocess.run(cmd, cwd=str(BACKEND_ROOT.parent), env=env, check=True)
else:
    print('RUN_STEP48=False. Set to True when you want to launch Step48.')

# %% [markdown]
# ### Step48: Tradeoff Audit (FakeAV Guard + DFDC AUC)
# Compares the **current anchor** (Step46 robust selection) against the **latest Step48 best fold model** on DFDC-only val/test,
# while printing FakeAV guard metrics so you can check whether we preserved in-domain quality.

# %%
# Step48 tradeoff audit: FakeAV guard vs DFDC AUC
from pathlib import Path
import importlib.util
import json
import numpy as np
import pandas as pd

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
LOGS_ROOT = BACKEND_ROOT / 'models' / 'experiment_logs'
RUN_PREFIX = 'step48_fakeav_anchor_dfdc75'

RUN_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_fakeav_mrdf_5fold_cv.py'
spec = importlib.util.spec_from_file_location('mrdf_run_module', RUN_SCRIPT)
mod = importlib.util.module_from_spec(spec)
assert spec is not None and spec.loader is not None
spec.loader.exec_module(mod)


def _pick_existing(paths):
    for p in paths:
        if p.exists():
            return p
    raise FileNotFoundError('None of the candidate paths exist.')


def _safe_auc(y, p):
    y = np.asarray(y).astype(int)
    p = np.asarray(p).astype(float)
    if y.size == 0 or np.unique(y).size < 2:
        return float('nan')
    try:
        from sklearn.metrics import roc_auc_score
        return float(roc_auc_score(y, p))
    except Exception:
        return float('nan')


def _dfdc_mask(raw_df):
    if 'dataset' in raw_df.columns:
        ds = raw_df['dataset'].astype(str).str.lower()
        return ds.str.contains('dfdc', regex=False).to_numpy()
    if 'path' in raw_df.columns:
        pp = raw_df['path'].astype(str).str.lower()
        return pp.str.contains('dfdc', regex=False).to_numpy()
    return np.zeros(len(raw_df), dtype=bool)


def _eval_model_on_dfdc(model_dir: Path, feature_profile: str, val_csv: Path, test_csv: Path):
    raw_v, y_v, _, p_v, report_thr = mod._predict_probs(model_dir=model_dir, csv_path=val_csv, feature_profile=feature_profile)
    raw_t, y_t, _, p_t, _ = mod._predict_probs(model_dir=model_dir, csv_path=test_csv, feature_profile=feature_profile)

    mv = _dfdc_mask(raw_v)
    mt = _dfdc_mask(raw_t)

    if int(mv.sum()) == 0 or int(mt.sum()) == 0:
        raise RuntimeError('No DFDC rows found in selected val/test CSV for evaluation.')

    yv, pv = y_v[mv], p_v[mv]
    yt, pt = y_t[mt], p_t[mt]

    dom_v = np.array(['dfdc'] * len(yv))
    dom_t = np.array(['dfdc'] * len(yt))

    val_report = mod.compute_domain_metrics(yv, pv, dom_v, threshold=float(report_thr))['overall']
    test_report = mod.compute_domain_metrics(yt, pt, dom_t, threshold=float(report_thr))['overall']

    best_thr = float(report_thr)
    best_bal = float(val_report.get('bal_acc', float('-inf')))
    for thr in np.linspace(0.01, 0.99, 199):
        vv = mod.compute_domain_metrics(yv, pv, dom_v, threshold=float(thr))['overall']
        bal = float(vv.get('bal_acc', float('-inf')))
        if bal > best_bal:
            best_bal = bal
            best_thr = float(thr)

    test_tuned = mod.compute_domain_metrics(yt, pt, dom_t, threshold=float(best_thr))['overall']

    return {
        'report_threshold': float(report_thr),
        'val_tuned_threshold': float(best_thr),
        'dfdc_val_auc': _safe_auc(yv, pv),
        'dfdc_test_auc': _safe_auc(yt, pt),
        'report_test': test_report,
        'val_tuned_test': test_tuned,
        'n_dfdc_val': int(len(yv)),
        'n_dfdc_test': int(len(yt)),
    }


# -------- Locate Step48 best model --------
ms_dirs = sorted(
    [p for p in LOGS_ROOT.glob(f'{RUN_PREFIX}_multiseed_20*') if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)

if not ms_dirs:
    raise FileNotFoundError('No Step48 multiseed directory found yet. Run Step48 first.')

latest_ms = ms_dirs[0]
ms_summary_path = latest_ms / 'multiseed_summary.json'
ens_summary_path = latest_ms / 'ensemble_summary.json'
posthoc_path = latest_ms / 'posthoc_threshold_sweep_temperatureaware.json'

print('Latest Step48 multiseed dir:', latest_ms)

ms_obj = json.loads(ms_summary_path.read_text())
seed_runs = ms_obj.get('seed_runs', [])

best_model = None
best_rank = float('-inf')
best_rank_col = None
for sr in seed_runs:
    fold_csv = Path(str(sr.get('fold_csv', '')))
    if not fold_csv.exists():
        continue
    df = pd.read_csv(fold_csv)
    if 'error' in df.columns:
        df = df[df['error'].isna()].copy()
    if df.empty or 'model_dir' not in df.columns:
        continue
    rank_col = 'val_auc' if 'val_auc' in df.columns else ('val_bal_acc' if 'val_bal_acc' in df.columns else None)
    if rank_col is None:
        continue
    row = df.sort_values(by=rank_col, ascending=False).iloc[0]
    model_dir = Path(str(row['model_dir']))
    rank = float(row[rank_col])
    if model_dir.exists() and (model_dir / 'cfn_emb.pth').exists() and rank > best_rank:
        best_rank = rank
        best_model = model_dir
        best_rank_col = rank_col

if best_model is None:
    raise RuntimeError('Could not resolve Step48 best model from seed fold metrics.')

print('Step48 best model:', best_model)
print(f'Step48 best rank: {best_rank_col}={best_rank:.4f}')


# -------- Resolve anchor model (Step46 robust selection best) --------
step46_sel_json = LOGS_ROOT / 'step46_fakeav_robust_constrained_robust_selection.json'
anchor_model = None
if step46_sel_json.exists():
    try:
        sel = json.loads(step46_sel_json.read_text())
        bm = sel.get('best_model') or {}
        mm = bm.get('model_dir')
        if mm:
            mm = Path(str(mm))
            if mm.exists() and (mm / 'cfn_emb.pth').exists():
                anchor_model = mm
    except Exception:
        anchor_model = None

if anchor_model is None:
    anchor_model = BACKEND_ROOT / 'models' / 'fakeav_mrdf5cv_step44_normaltest_single_s42_20260316_154454_fold_01_p1_focal_lr0p0003'

print('Anchor model:', anchor_model)


# -------- Eval CSVs (prefer physfix3 variants) --------
val_csv = _pick_existing([
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val_dfdc_augfix3_physfix.csv',
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val_dfdc_augfix3.csv',
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val.csv',
])

test_csv = _pick_existing([
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test_dfdc_augfix3_physfix.csv',
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test_dfdc_augfix3.csv',
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test.csv',
])

print('DFDC eval val csv :', val_csv)
print('DFDC eval test csv:', test_csv)


# -------- Run DFDC cross-data eval --------
rows = []
for name, model_dir, profile in [
    ('anchor_step46', anchor_model, 'extended'),
    ('candidate_step48', best_model, 'nextgen'),
]:
    out = _eval_model_on_dfdc(model_dir=model_dir, feature_profile=profile, val_csv=val_csv, test_csv=test_csv)
    rows.append({
        'name': name,
        'model_dir': str(model_dir),
        'feature_profile': profile,
        'n_dfdc_val': out['n_dfdc_val'],
        'n_dfdc_test': out['n_dfdc_test'],
        'dfdc_val_auc': out['dfdc_val_auc'],
        'dfdc_test_auc': out['dfdc_test_auc'],
        'report_thr': out['report_threshold'],
        'val_tuned_thr': out['val_tuned_threshold'],
        'test_acc@report': float(out['report_test'].get('acc', float('nan'))),
        'test_f1@report': float(out['report_test'].get('f1', float('nan'))),
        'test_bal_acc@report': float(out['report_test'].get('bal_acc', float('nan'))),
        'test_acc@val_tuned': float(out['val_tuned_test'].get('acc', float('nan'))),
        'test_f1@val_tuned': float(out['val_tuned_test'].get('f1', float('nan'))),
        'test_bal_acc@val_tuned': float(out['val_tuned_test'].get('bal_acc', float('nan'))),
    })

tradeoff_df = pd.DataFrame(rows)
print()
print('DFDC cross-data comparison:')
print(tradeoff_df.to_string(index=False))


# -------- FakeAV guard metrics --------
step46_fake_guard = {}
step46_ms_dirs = sorted(
    [p for p in LOGS_ROOT.glob('step46_fakeav_robust_constrained_multiseed_*') if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)
for d in step46_ms_dirs:
    pp = d / 'posthoc_threshold_sweep_temperatureaware.json'
    if not pp.exists():
        continue
    try:
        obj = json.loads(pp.read_text())
        pooled = obj.get('protocol', {}).get('pooled_test_metrics', {})
        if pooled:
            step46_fake_guard = {
                'acc': float(pooled.get('acc', float('nan'))),
                'auc': float(pooled.get('auc', float('nan'))),
                'f1': float(pooled.get('f1', float('nan'))),
                'prec': float(pooled.get('prec', float('nan'))),
                'rec': float(pooled.get('rec', float('nan'))),
                'bal_acc': float(pooled.get('bal_acc', float('nan'))),
            }
            break
    except Exception:
        pass

step48_fake_guard = {}
if ens_summary_path.exists():
    ens = json.loads(ens_summary_path.read_text())
    cv = ens.get('cv_metrics', {})
    def _m(k):
        try:
            return float(cv.get(k, {}).get('mean', float('nan')))
        except Exception:
            return float('nan')
    step48_fake_guard = {
        'acc': _m('test_acc'),
        'auc': _m('test_auc'),
        'f1': _m('test_f1'),
        'prec': _m('test_prec'),
        'rec': _m('test_rec'),
        'bal_acc': _m('test_bal_acc'),
    }

print()
print('FakeAV guard metrics (anchor vs Step48 candidate):')
print('anchor_step46_posthoc_pooled_test:', step46_fake_guard)
print('candidate_step48_ensemble_cv_mean :', step48_fake_guard)


targets = {'fake_acc': 0.95, 'fake_auc': 0.97, 'fake_f1': 0.94, 'fake_prec': 0.93, 'fake_rec': 0.94, 'dfdc_auc': 0.75}
anchor_fake_ok = (
    step46_fake_guard.get('acc', 0.0) >= targets['fake_acc'] and
    step46_fake_guard.get('auc', 0.0) >= targets['fake_auc'] and
    step46_fake_guard.get('f1', 0.0) >= targets['fake_f1'] and
    step46_fake_guard.get('prec', 0.0) >= targets['fake_prec'] and
    step46_fake_guard.get('rec', 0.0) >= targets['fake_rec']
) if step46_fake_guard else False
step48_fake_ok = (
    step48_fake_guard.get('acc', 0.0) >= targets['fake_acc'] and
    step48_fake_guard.get('auc', 0.0) >= targets['fake_auc'] and
    step48_fake_guard.get('f1', 0.0) >= targets['fake_f1'] and
    step48_fake_guard.get('prec', 0.0) >= targets['fake_prec'] and
    step48_fake_guard.get('rec', 0.0) >= targets['fake_rec']
) if step48_fake_guard else False

step48_dfdc_auc = float(tradeoff_df[tradeoff_df['name'] == 'candidate_step48']['dfdc_test_auc'].iloc[0])
anchor_dfdc_auc = float(tradeoff_df[tradeoff_df['name'] == 'anchor_step46']['dfdc_test_auc'].iloc[0])

print()
print('Target check:')
print(f'anchor FakeAV guard pass : {anchor_fake_ok}')
print(f'step48 FakeAV guard pass : {step48_fake_ok}')
print(f'anchor DFDC test AUC     : {anchor_dfdc_auc:.4f}')
print(f'step48 DFDC test AUC     : {step48_dfdc_auc:.4f}')
print(f'DFDC AUC target (>=0.75) met by Step48: {step48_dfdc_auc >= targets["dfdc_auc"]}')

if posthoc_path.exists():
    post = json.loads(posthoc_path.read_text())
    pooled = post.get('protocol', {}).get('pooled_test_metrics', {})
    if pooled:
        print()
        print('Step48 posthoc pooled test (temperature-aware):')
        print({
            'acc': float(pooled.get('acc', float('nan'))),
            'auc': float(pooled.get('auc', float('nan'))),
            'f1': float(pooled.get('f1', float('nan'))),
            'prec': float(pooled.get('prec', float('nan'))),
            'rec': float(pooled.get('rec', float('nan'))),
            'bal_acc': float(pooled.get('bal_acc', float('nan'))),
            'spec': float(pooled.get('spec', float('nan'))),
        })

# %% [markdown]
# ### Step49: AUC-First FakeAV-Only Push
# Runs a new source-only multiseed recipe tuned for **ranking robustness**:
# - AUC-first phase selection
# - val-AUC-ranked ensemble
# - mild CE+AUC-margin objective
# - no aggressive phase2 hard-example curriculum
# Set `RUN_STEP49 = True` to execute.

# %%
# Step49 run (AUC-first, source-only)
from pathlib import Path
import os
import shlex
import subprocess

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
LOGS_ROOT = BACKEND_ROOT / 'models' / 'experiment_logs'
RUN_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_step49_fakeav_auc70_sourceonly.sh'
RUN_PREFIX = 'step49_fakeav_auc70_sourceonly'

RUN_STEP49 = False  # set True to launch training
FAIL_ON_ERROR = False  # set True to raise if launcher returns non-zero


def latest_multiseed_dir(prefix: str) -> Path | None:
    candidates = sorted(
        LOGS_ROOT.glob(f"{prefix}_multiseed_*"),
        key=lambda p: p.stat().st_mtime,
        reverse=True,
    )
    return candidates[0] if candidates else None


cmd = ['bash', str(RUN_SCRIPT), str(RUN_PREFIX)]
print('Step49 command:')
print(' '.join(shlex.quote(x) for x in cmd))

if RUN_STEP49:
    env = dict(os.environ)
    env.setdefault('TORCH_HOME', str(BACKEND_ROOT / '.torch_cache'))
    res = subprocess.run(
        cmd,
        cwd=str(BACKEND_ROOT.parent),
        env=env,
        text=True,
        capture_output=True,
    )
    if res.stdout.strip():
        print('--- launcher stdout (tail) ---')
        print('\n'.join(res.stdout.strip().splitlines()[-120:]))
    if res.returncode != 0:
        print(f'Step49 launcher failed with return code {res.returncode}.')
        if res.stderr.strip():
            print('--- launcher stderr (tail) ---')
            print('\n'.join(res.stderr.strip().splitlines()[-120:]))
        latest = latest_multiseed_dir(RUN_PREFIX)
        if latest and (latest / 'multiseed_summary.json').exists():
            print(f'Latest successful multiseed artifacts: {latest}')
        if FAIL_ON_ERROR:
            raise subprocess.CalledProcessError(res.returncode, cmd, output=res.stdout, stderr=res.stderr)
else:
    print('RUN_STEP49=False. Set to True when you want to launch Step49.')

latest = latest_multiseed_dir(RUN_PREFIX)
if latest is None:
    print('No Step49 multiseed artifacts found yet.')
else:
    print(f'Latest Step49 multiseed dir: {latest}')
    for name in [
        'multiseed_summary.json',
        'ensemble_summary.json',
        'posthoc_threshold_sweep_temperatureaware.json',
    ]:
        p = latest / name
        print(f'  {name}: {"OK" if p.exists() else "MISSING"}')

# %% [markdown]
# ### Step49: Post-hoc Resume (No Retraining)
# Use this when training artifacts already exist but the launcher failed at the end.

# %%
# Step49 post-hoc resume (no retraining)
from pathlib import Path
import json
import shlex
import subprocess

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
LOGS_ROOT = BACKEND_ROOT / 'models' / 'experiment_logs'
POSTHOC_SCRIPT = BACKEND_ROOT / 'scripts' / 'posthoc_multiseed_threshold_sweep.py'
PYTHON_BIN = BACKEND_ROOT / '.venv' / 'bin' / 'python'
RUN_PREFIX = 'step49_fakeav_auc70_sourceonly'

# Optional override to target a specific multiseed directory.
TARGET_MULTISEED_DIR = ''
RERUN_POSTHOC = True  # set False to skip if posthoc JSON already exists


def latest_multiseed_dir(prefix: str) -> Path | None:
    candidates = sorted(
        LOGS_ROOT.glob(f"{prefix}_multiseed_*"),
        key=lambda p: p.stat().st_mtime,
        reverse=True,
    )
    return candidates[0] if candidates else None


if TARGET_MULTISEED_DIR.strip():
    ms_dir = Path(TARGET_MULTISEED_DIR).resolve()
else:
    ms_dir = latest_multiseed_dir(RUN_PREFIX)

if ms_dir is None:
    raise FileNotFoundError(f'No multiseed directory found for prefix={RUN_PREFIX}')

ms_summary = ms_dir / 'multiseed_summary.json'
if not ms_summary.exists():
    raise FileNotFoundError(f'Missing multiseed summary: {ms_summary}')

posthoc_json = ms_dir / 'posthoc_threshold_sweep_temperatureaware.json'
posthoc_csv = ms_dir / 'posthoc_threshold_sweep_temperatureaware_fold_test.csv'

print('Using multiseed dir:', ms_dir)
print('Using summary:', ms_summary)

if posthoc_json.exists() and not RERUN_POSTHOC:
    print('Posthoc file already exists and RERUN_POSTHOC=False; skipping execution.')
else:
    cmd = [
        str(PYTHON_BIN),
        str(POSTHOC_SCRIPT),
        '--multiseed-summary', str(ms_summary),
        '--feature-profile', 'nextgen',
        '--ensemble-rank-metric', 'val_auc',
        '--ensemble-weighting', 'rank_metric',
        '--threshold-priority', 'balanced_acc',
        '--target-acc', '0.90',
        '--target-prec', '0.87',
        '--target-rec', '0.88',
        '--target-f1', '0.88',
        '--target-spec', '0.35',
        '--user-target-acc', '0.95',
        '--user-target-prec', '0.93',
        '--user-target-rec', '0.94',
        '--user-target-f1', '0.94',
    ]
    print('Posthoc command:')
    print(' '.join(shlex.quote(x) for x in cmd))
    res = subprocess.run(cmd, cwd=str(BACKEND_ROOT.parent), text=True, capture_output=True)
    if res.stdout.strip():
        print('--- posthoc stdout ---')
        print('\n'.join(res.stdout.strip().splitlines()[-120:]))
    if res.returncode != 0:
        if res.stderr.strip():
            print('--- posthoc stderr ---')
            print('\n'.join(res.stderr.strip().splitlines()[-120:]))
        raise subprocess.CalledProcessError(res.returncode, cmd, output=res.stdout, stderr=res.stderr)

print('Artifacts:')
print(' ', posthoc_json, '->', 'OK' if posthoc_json.exists() else 'MISSING')
print(' ', posthoc_csv, '->', 'OK' if posthoc_csv.exists() else 'MISSING')

if posthoc_json.exists():
    obj = json.loads(posthoc_json.read_text())
    protocol = (obj.get('protocol') or {}).get('pooled_test_metrics') or {}
    user = (obj.get('user_stretch') or {}).get('pooled_test_metrics') or {}

    def _fmt(m):
        keys = ['acc', 'auc', 'f1', 'prec', 'rec', 'bal_acc']
        return ' '.join(f"{k.upper()}={m.get(k, float('nan')):.4f}" for k in keys)

    print('\nPosthoc pooled test metrics:')
    print(' protocol   :', _fmt(protocol))
    print(' user_stretch:', _fmt(user))

# %% [markdown]
# ### Step49: DFDC Cross-Dataset Leaderboard (Best Available)
# Builds a compact leaderboard across anchor/candidate families (`step45b`, `step46`, `step47`, `step48`, `step49`) and reports:
# - DFDC test AUC (primary)
# - ACC/PREC/REC/F1/SPEC/BAL_ACC at report threshold
# - best model summary

# %%
# Step49 DFDC leaderboard (cross-dataset)
from pathlib import Path
import importlib.util
import json
import numpy as np
import pandas as pd

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
RUN_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_fakeav_mrdf_5fold_cv.py'
LOGS_ROOT = BACKEND_ROOT / 'models' / 'experiment_logs'

spec = importlib.util.spec_from_file_location('mrdf_run_module', RUN_SCRIPT)
mod = importlib.util.module_from_spec(spec)
assert spec is not None and spec.loader is not None
spec.loader.exec_module(mod)


def _pick_existing(paths):
    for p in paths:
        if p.exists():
            return p
    raise FileNotFoundError('No candidate CSV found.')


def _safe_auc(y, p):
    y = np.asarray(y).astype(int)
    p = np.asarray(p).astype(float)
    if y.size == 0 or np.unique(y).size < 2:
        return float('nan')
    from sklearn.metrics import roc_auc_score
    return float(roc_auc_score(y, p))


def _dfdc_mask(raw_df):
    if 'dataset' in raw_df.columns:
        ds = raw_df['dataset'].astype(str).str.lower()
        return ds.str.contains('dfdc', regex=False).to_numpy()
    if 'path' in raw_df.columns:
        pp = raw_df['path'].astype(str).str.lower()
        return pp.str.contains('dfdc', regex=False).to_numpy()
    return np.zeros(len(raw_df), dtype=bool)


def _best_model_from_prefix(prefix, rank_pref=('val_auc', 'val_bal_acc')):
    run_dirs = sorted(
        [p for p in LOGS_ROOT.glob(f'{prefix}_s*_20*') if p.is_dir()],
        key=lambda p: p.stat().st_mtime,
        reverse=True,
    )
    best_model = None
    best_rank = float('-inf')
    best_col = None
    for run in run_dirs:
        fold_csv = run / 'fold_metrics.csv'
        if not fold_csv.exists():
            continue
        try:
            df = pd.read_csv(fold_csv)
        except Exception:
            continue
        if 'error' in df.columns:
            df = df[df['error'].isna()].copy()
        if df.empty or 'model_dir' not in df.columns:
            continue
        rank_col = None
        for c in rank_pref:
            if c in df.columns:
                rank_col = c
                break
        if rank_col is None:
            continue
        row = df.sort_values(by=rank_col, ascending=False).iloc[0]
        mdir = Path(str(row['model_dir']))
        score = float(row[rank_col])
        if mdir.exists() and (mdir / 'cfn_emb.pth').exists() and score > best_rank:
            best_model = mdir
            best_rank = score
            best_col = rank_col
    return best_model, best_col, best_rank


def _eval_model(model_name, model_dir, feature_profile, val_csv, test_csv):
    if model_dir is None or not (model_dir / 'cfn_emb.pth').exists():
        return None

    raw_v, y_v, _, p_v, report_thr = mod._predict_probs(model_dir=model_dir, csv_path=val_csv, feature_profile=feature_profile)
    raw_t, y_t, _, p_t, _ = mod._predict_probs(model_dir=model_dir, csv_path=test_csv, feature_profile=feature_profile)

    mv = _dfdc_mask(raw_v)
    mt = _dfdc_mask(raw_t)
    if int(mv.sum()) == 0 or int(mt.sum()) == 0:
        return None

    yv, pv = y_v[mv], p_v[mv]
    yt, pt = y_t[mt], p_t[mt]
    dom_t = np.array(['dfdc'] * len(yt))

    rep = mod.compute_domain_metrics(yt, pt, dom_t, threshold=float(report_thr))['overall']

    return {
        'name': model_name,
        'model_dir': str(model_dir),
        'feature_profile': feature_profile,
        'n_dfdc_test': int(len(yt)),
        'dfdc_test_auc': _safe_auc(yt, pt),
        'report_acc': float(rep.get('acc', float('nan'))),
        'report_prec': float(rep.get('prec', float('nan'))),
        'report_rec': float(rep.get('rec', float('nan'))),
        'report_f1': float(rep.get('f1', float('nan'))),
        'report_spec': float(rep.get('spec', float('nan'))),
        'report_bal_acc': float(rep.get('bal_acc', float('nan'))),
        'report_tp': float(rep.get('tp', float('nan'))),
        'report_tn': float(rep.get('tn', float('nan'))),
        'report_fp': float(rep.get('fp', float('nan'))),
        'report_fn': float(rep.get('fn', float('nan'))),
        'report_threshold': float(report_thr),
    }


val_csv = _pick_existing([
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val_dfdc_augfix3_physfix.csv',
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val_dfdc_augfix3.csv',
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val.csv',
])

test_csv = _pick_existing([
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test_dfdc_augfix3_physfix.csv',
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test_dfdc_augfix3.csv',
    BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test.csv',
])

print('DFDC eval val csv :', val_csv)
print('DFDC eval test csv:', test_csv)

candidates = []

# Fixed references
candidates.append(('deployed_baseline', BACKEND_ROOT / 'models' / 'featup_dfdcplus2_v5_specguard', 'extended'))
candidates.append(('step44_normaltest', BACKEND_ROOT / 'models' / 'fakeav_mrdf5cv_step44_normaltest_single_s42_20260316_154454_fold_01_p1_focal_lr0p0003', 'extended'))
candidates.append(('step45b_bce_videofocus2_cb_joint', BACKEND_ROOT / 'models' / 'step45b_fakeav_only_dfdc_auc_bce_videofocus2_cb_joint_s42_20260316_173022_fold_01_p1_bce_lr0p0003', 'extended'))

# Step46 robust selected
sel_json = LOGS_ROOT / 'step46_fakeav_robust_constrained_robust_selection.json'
if sel_json.exists():
    try:
        obj = json.loads(sel_json.read_text())
        bm = (obj.get('best_model') or {}).get('model_dir')
        if bm:
            candidates.append(('step46_selected_best', Path(str(bm)), 'extended'))
    except Exception:
        pass

# Best folds from Step47/48/49 by val_auc
for prefix, name in [
    ('step47_fakeav_only_dfdc_push', 'step47_best_fold'),
    ('step48_fakeav_anchor_dfdc75', 'step48_best_fold'),
    ('step49_fakeav_auc70_sourceonly', 'step49_best_fold'),
]:
    mdir, rcol, rscore = _best_model_from_prefix(prefix)
    if mdir is not None:
        candidates.append((name, mdir, 'nextgen'))
        print(f'{name}: {mdir} ({rcol}={rscore:.4f})')

rows = []
for name, mdir, profile in candidates:
    try:
        r = _eval_model(name, Path(mdir), profile, val_csv, test_csv)
        if r is not None:
            rows.append(r)
    except Exception as e:
        rows.append({'name': name, 'model_dir': str(mdir), 'feature_profile': profile, 'error': str(e)})

if not rows:
    raise RuntimeError('No candidate models evaluated successfully.')

df = pd.DataFrame(rows)
if 'dfdc_test_auc' in df.columns:
    df = df.sort_values(by='dfdc_test_auc', ascending=False, na_position='last').reset_index(drop=True)

show_cols = [
    'name', 'dfdc_test_auc',
    'report_acc', 'report_prec', 'report_rec', 'report_f1', 'report_spec', 'report_bal_acc',
    'report_tp', 'report_tn', 'report_fp', 'report_fn',
    'model_dir', 'error'
]
show_cols = [c for c in show_cols if c in df.columns]

print()
print('DFDC cross-dataset leaderboard (report threshold):')
print(df[show_cols].to_string(index=False))

best = df.iloc[0].to_dict()
print()
print('Best current DFDC cross-dataset model:')
print(json.dumps(best, indent=2))

# %% [markdown]
# ### Step50: DFDC Anti-Collapse Strict (Val-Driven)\n
# Run guarded DFDC selection with stricter anti-collapse constraints while preserving Step46 FakeAV floors.\n

# %%
# Step50 strict DFDC anti-collapse selection (val-driven)
from pathlib import Path
import json
import shlex
import subprocess

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
PYTHON_BIN = BACKEND_ROOT / '.venv' / 'bin' / 'python'
SELECT_SCRIPT = BACKEND_ROOT / 'scripts' / 'fakeav_guarded_dfdc_selection.py'

MULTISEED_SUMMARY = BACKEND_ROOT / 'models' / 'experiment_logs' / 'step46_fakeav_robust_constrained_multiseed_20260317_112014' / 'multiseed_summary.json'
CLEAN_CSV = BACKEND_ROOT / 'models' / 'experiment_logs' / 'step46_fakeav_robust_constrained_selector_inputs' / 'causal_multimodal_dataset_fakeav_fulltrain_test_aug_extended.csv'
STRESS_CSVS = ','.join([
    str(BACKEND_ROOT / 'models' / 'experiment_logs' / 'step46_fakeav_robust_constrained_selector_inputs' / 'causal_multimodal_dataset_fakeav_cap8_test_aug_extended.csv'),
    str(BACKEND_ROOT / 'models' / 'experiment_logs' / 'step46_fakeav_robust_constrained_selector_inputs' / 'causal_multimodal_dataset_fakeav_cap32_test_aug_extended.csv'),
    str(BACKEND_ROOT / 'models' / 'experiment_logs' / 'step46_fakeav_robust_constrained_selector_inputs' / 'causal_multimodal_dataset_fakeav_v2_test_aug_extended.csv'),
])
DFDC_VAL_CSV = BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_val_dfdc_augfix3_physfix.csv'
DFDC_TEST_CSV = BACKEND_ROOT / 'data' / 'processed' / 'causal_multimodal_dataset_mixed_test_dfdc_augfix3_physfix.csv'
TEACHER_MODEL = BACKEND_ROOT / 'models' / 'fakeav_mrdf5cv_step44_normaltest_single_s42_20260316_154454_fold_01_p1_focal_lr0p0003'

OUT_JSON = BACKEND_ROOT / 'models' / 'experiment_logs' / 'step46_fakeav_robust_constrained_guarded_dfdc_selection_strict56.json'
OUT_CSV = BACKEND_ROOT / 'models' / 'experiment_logs' / 'step46_fakeav_robust_constrained_guarded_dfdc_selection_strict56.csv'

RUN_STEP50_STRICT = True

cmd = [
    str(PYTHON_BIN), str(SELECT_SCRIPT),
    '--multiseed-summary', str(MULTISEED_SUMMARY),
    '--feature-profile', 'extended',
    '--clean-csv', str(CLEAN_CSV),
    '--stress-csvs', STRESS_CSVS,
    '--fakeav-only-filter',
    '--teacher-model-dir', str(TEACHER_MODEL),
    '--eps-acc', '0.003',
    '--eps-f1', '0.003',
    '--eps-auc', '0.002',
    '--min-stress-auc-mean', '0.99',
    '--min-stress-f1-mean', '0.98',
    '--min-stress-bal-min', '0.97',
    '--dfdc-val-csv', str(DFDC_VAL_CSV),
    '--dfdc-test-csv', str(DFDC_TEST_CSV),
    '--dfdc-threshold-policy', 'val_target',
    '--target-acc', '0.75',
    '--target-prec', '0.80',
    '--target-rec', '0.80',
    '--target-f1', '0.80',
    '--target-spec', '0.15',
    '--min-dfdc-val-spec', '0.15',
    '--min-dfdc-val-bal-acc', '0.56',
    '--max-dfdc-val-pred-pos-rate', '0.90',
    '--selection-objective', 'dfdc_val_auc',
    '--out-json', str(OUT_JSON),
    '--out-csv', str(OUT_CSV),
]

print('Step50 strict command:')
print(' '.join(shlex.quote(x) for x in cmd))

if RUN_STEP50_STRICT:
    res = subprocess.run(cmd, cwd=str(BACKEND_ROOT.parent), text=True, capture_output=True)
    if res.stdout.strip():
        print('--- selector stdout ---')
        print('\n'.join(res.stdout.strip().splitlines()[-120:]))
    if res.returncode != 0:
        if res.stderr.strip():
            print('--- selector stderr ---')
            print('\n'.join(res.stderr.strip().splitlines()[-120:]))
        raise subprocess.CalledProcessError(res.returncode, cmd, output=res.stdout, stderr=res.stderr)
else:
    print('RUN_STEP50_STRICT=False. Set to True to execute selection.')

if not OUT_JSON.exists():
    raise FileNotFoundError(f'Missing output json: {OUT_JSON}')

obj = json.loads(OUT_JSON.read_text())
best = obj.get('best_model') or {}
print('\nSelected model:', best.get('model_dir'))

for k in [
    'clean_acc', 'clean_f1', 'clean_auc',
    'stress_auc_mean', 'stress_f1_mean', 'stress_bal_acc_min',
    'dfdc_val_auc', 'dfdc_test_auc',
    'dfdc_val_tuned_acc', 'dfdc_val_tuned_prec', 'dfdc_val_tuned_rec', 'dfdc_val_tuned_f1', 'dfdc_val_tuned_spec', 'dfdc_val_tuned_bal_acc', 'dfdc_val_tuned_pred_pos_rate',
    'dfdc_test_tuned_acc', 'dfdc_test_tuned_prec', 'dfdc_test_tuned_rec', 'dfdc_test_tuned_f1', 'dfdc_test_tuned_spec', 'dfdc_test_tuned_bal_acc', 'dfdc_test_tuned_pred_pos_rate',
    'dfdc_threshold',
]:
    if k in best:
        print(f'{k}: {best[k]}')

print('\nConstraint block:')
print(json.dumps(obj.get('constraints') or {}, indent=2))
print('\nArtifacts:')
print(' ', OUT_JSON)
print(' ', OUT_CSV)

# %% [markdown]
# ### Step51: FakeAV Guarded DFDC Push (Training + Selection)\n

# %%
# Step51 run (FakeAV guarded DFDC push)
from pathlib import Path
import os
import shlex
import subprocess

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
RUN_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_step51_fakeav_guarded_dfdcpush.sh'
RUN_PREFIX = 'step51_fakeav_guarded_dfdcpush'

RUN_STEP51 = False  # set True to launch training + guarded selection
FAIL_ON_ERROR = False

cmd = ['bash', str(RUN_SCRIPT), str(RUN_PREFIX)]
print('Step51 command:')
print(' '.join(shlex.quote(x) for x in cmd))

if RUN_STEP51:
    env = dict(os.environ)
    env.setdefault('TORCH_HOME', str(BACKEND_ROOT / '.torch_cache'))
    res = subprocess.run(cmd, cwd=str(BACKEND_ROOT.parent), env=env, text=True, capture_output=True)
    if res.stdout.strip():
        print('--- step51 stdout (tail) ---')
        print('\n'.join(res.stdout.strip().splitlines()[-160:]))
    if res.returncode != 0:
        if res.stderr.strip():
            print('--- step51 stderr (tail) ---')
            print('\n'.join(res.stderr.strip().splitlines()[-160:]))
        if FAIL_ON_ERROR:
            raise subprocess.CalledProcessError(res.returncode, cmd, output=res.stdout, stderr=res.stderr)
else:
    print('RUN_STEP51=False. Set to True to execute Step51.')

# %% [markdown]
# ### Step51: Metrics Snapshot\n

# %%
# Step51 metrics snapshot (ensemble + guarded DFDC selection)
from pathlib import Path
import json

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
LOGS_ROOT = BACKEND_ROOT / 'models' / 'experiment_logs'
RUN_PREFIX = 'step51_fakeav_guarded_dfdcpush'

multiseed_dirs = sorted(LOGS_ROOT.glob(f'{RUN_PREFIX}_multiseed_*'), key=lambda p: p.stat().st_mtime, reverse=True)
if not multiseed_dirs:
    raise FileNotFoundError(f'No multiseed dirs found for {RUN_PREFIX}')
latest = multiseed_dirs[0]
ens_json = latest / 'ensemble_summary.json'
guard_json = LOGS_ROOT / f'{RUN_PREFIX}_guarded_dfdc_selection.json'

print('Latest multiseed dir:', latest)
print('Ensemble summary:', ens_json)
print('Guarded selection:', guard_json)

if ens_json.exists():
    ens = json.loads(ens_json.read_text())
    cv = ens.get('cv_metrics') or {}
    print('\nStep51 ensemble CV means:')
    for k in ['test_acc', 'test_auc', 'test_f1', 'test_prec', 'test_rec', 'test_bal_acc', 'test_f1_real']:
        v = cv.get(k, {})
        if v:
            print(f"  {k}: mean={v.get('mean', float('nan')):.6f} std={v.get('std', float('nan')):.6f}")

if guard_json.exists():
    obj = json.loads(guard_json.read_text())
    print('\nStep51 guarded selection mode:', (obj.get('metadata') or {}).get('selection_mode'))
    best = obj.get('best_model') or {}
    for k in [
        'model_dir',
        'clean_acc', 'clean_f1', 'clean_auc',
        'stress_auc_mean', 'stress_f1_mean', 'stress_bal_acc_min',
        'dfdc_val_auc', 'dfdc_test_auc',
        'dfdc_val_tuned_spec', 'dfdc_val_tuned_bal_acc', 'dfdc_val_tuned_pred_pos_rate',
        'dfdc_test_tuned_spec', 'dfdc_test_tuned_bal_acc', 'dfdc_test_tuned_pred_pos_rate',
    ]:
        if k in best:
            print(f'  {k}: {best[k]}')

# %% [markdown]
# ### Step52: FakeAV Guarded Micro-Ablation\n

# %%
# Step52 run (FakeAV guarded micro-ablation)
from pathlib import Path
import os
import shlex
import subprocess

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
RUN_SCRIPT = BACKEND_ROOT / 'scripts' / 'run_step52_fakeav_guarded_microablation.sh'
RUN_PREFIX = 'step52_fakeav_guarded_microablation'

RUN_STEP52 = False  # set True to launch
FAIL_ON_ERROR = False

cmd = ['bash', str(RUN_SCRIPT), str(RUN_PREFIX)]
print('Step52 command:')
print(' '.join(shlex.quote(x) for x in cmd))

if RUN_STEP52:
    env = dict(os.environ)
    env.setdefault('TORCH_HOME', str(BACKEND_ROOT / '.torch_cache'))
    res = subprocess.run(cmd, cwd=str(BACKEND_ROOT.parent), env=env, text=True, capture_output=True)
    if res.stdout.strip():
        print('--- step52 stdout (tail) ---')
        print('\n'.join(res.stdout.strip().splitlines()[-200:]))
    if res.returncode != 0:
        if res.stderr.strip():
            print('--- step52 stderr (tail) ---')
            print('\n'.join(res.stderr.strip().splitlines()[-200:]))
        if FAIL_ON_ERROR:
            raise subprocess.CalledProcessError(res.returncode, cmd, output=res.stdout, stderr=res.stderr)
else:
    print('RUN_STEP52=False. Set to True to execute Step52.')

# %% [markdown]
# ### Step52: Metrics Snapshot\n

# %%
# Step52 metrics snapshot
from pathlib import Path
import json

BACKEND_ROOT = Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend')
LOGS_ROOT = BACKEND_ROOT / 'models' / 'experiment_logs'
RUN_PREFIX = 'step52_fakeav_guarded_microablation'

multiseed_dirs = sorted(LOGS_ROOT.glob(f'{RUN_PREFIX}_multiseed_*'), key=lambda p: p.stat().st_mtime, reverse=True)
if not multiseed_dirs:
    raise FileNotFoundError(f'No multiseed dirs found for {RUN_PREFIX}')
latest = multiseed_dirs[0]
ens_json = latest / 'ensemble_summary.json'
posthoc_json = latest / 'posthoc_threshold_sweep_temperatureaware.json'
guard_json = LOGS_ROOT / f'{RUN_PREFIX}_guarded_dfdc_selection.json'

print('Latest multiseed dir:', latest)
print('Ensemble summary:', ens_json)
print('Posthoc summary :', posthoc_json)
print('Guarded select  :', guard_json)

if ens_json.exists():
    ens = json.loads(ens_json.read_text())
    cv = ens.get('cv_metrics') or {}
    print('\nStep52 ensemble CV means:')
    for k in ['test_acc', 'test_auc', 'test_f1', 'test_prec', 'test_rec', 'test_bal_acc', 'test_f1_real']:
        v = cv.get(k, {})
        if v:
            print(f"  {k}: mean={v.get('mean', float('nan')):.6f} std={v.get('std', float('nan')):.6f}")

if posthoc_json.exists():
    post = json.loads(posthoc_json.read_text())
    p = (post.get('protocol') or {}).get('pooled_test_metrics') or {}
    u = (post.get('user_stretch') or {}).get('pooled_test_metrics') or {}
    print('\nStep52 posthoc pooled test:')
    print('  protocol   :', ' '.join(f"{k.upper()}={p.get(k, float('nan')):.4f}" for k in ['acc','auc','f1','prec','rec','bal_acc']))
    print('  user_stretch:', ' '.join(f"{k.upper()}={u.get(k, float('nan')):.4f}" for k in ['acc','auc','f1','prec','rec','bal_acc']))

if guard_json.exists():
    obj = json.loads(guard_json.read_text())
    print('\nStep52 guarded selection mode:', (obj.get('metadata') or {}).get('selection_mode'))
    best = obj.get('best_model') or {}
    for k in [
        'model_dir',
        'clean_acc', 'clean_f1', 'clean_auc',
        'stress_auc_mean', 'stress_f1_mean', 'stress_bal_acc_min',
        'dfdc_val_auc', 'dfdc_test_auc',
        'dfdc_val_tuned_spec', 'dfdc_val_tuned_bal_acc', 'dfdc_val_tuned_pred_pos_rate',
        'dfdc_test_tuned_spec', 'dfdc_test_tuned_bal_acc', 'dfdc_test_tuned_pred_pos_rate',
    ]:
        if k in best:
            print(f'  {k}: {best[k]}')

# %% [markdown]
# ### LAV-DF: Config
# Set the LAV-DF root, metadata path, subset, and model used for cross-dataset evaluation.
# Default subset is `test`.

# %%
from pathlib import Path
import os
import sys
import subprocess

# Resolve backend root if setup cells were skipped.
if 'BACKEND_ROOT' not in globals() or BACKEND_ROOT is None or not Path(BACKEND_ROOT).exists():
    _candidates = [
        Path.cwd(),
        Path.cwd().parent,
        Path.cwd().resolve() / 'backend',
        Path('/content/CausalX-Project/backend'),
    ]
    BACKEND_ROOT = next((c for c in _candidates if (c / 'src').exists()), None)

if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

BACKEND_ROOT = Path(BACKEND_ROOT).resolve()
if str(BACKEND_ROOT) not in sys.path:
    sys.path.insert(0, str(BACKEND_ROOT))

_py_bin = BACKEND_ROOT / '.venv/bin/python'
if not _py_bin.exists():
    raise FileNotFoundError(
        f'Required backend venv python not found: {_py_bin}. '
        'Create backend venv and install dependencies first.'
    )
PYTHON_EXE = str(_py_bin)

_probe = subprocess.run(
    [PYTHON_EXE, '-c', 'import sys,pandas,joblib;print(sys.executable);print(sys.prefix)'],
    text=True,
    capture_output=True,
)
if _probe.returncode != 0:
    raise RuntimeError('Backend venv python failed package probe (pandas/joblib).\n' + _probe.stderr[-2000:])
_probe_lines = [ln.strip() for ln in _probe.stdout.splitlines() if ln.strip()]
if not any('.venv' in ln for ln in _probe_lines):
    raise RuntimeError(
        'Python probe indicates interpreter is not using backend venv. '
        f'Probe output: {_probe.stdout!r}'
    )

_lavdf_env = os.getenv('LAVDF_ROOT', '').strip()
_lavdf_candidates = []
if _lavdf_env:
    _lavdf_candidates.append(Path(_lavdf_env).expanduser())
_lavdf_candidates += [
    BACKEND_ROOT / 'data/raw/LAV-DF/extracted/LAV-DF',
    BACKEND_ROOT / 'data/raw/LAV-DF/extracted',
    BACKEND_ROOT / 'data/raw/LAV-DF',
    BACKEND_ROOT / 'data/raw/lav-df/extracted/LAV-DF',
    BACKEND_ROOT / 'data/raw/lav-df/extracted',
    BACKEND_ROOT / 'data/raw/lav-df',
    BACKEND_ROOT / 'data/raw/lavdf/extracted/LAV-DF',
    BACKEND_ROOT / 'data/raw/lavdf/extracted',
    BACKEND_ROOT / 'data/raw/lavdf',
    BACKEND_ROOT / 'data/validation_evaluation_videos/evaluation/data/raw/LAV-DF/extracted/LAV-DF',
    BACKEND_ROOT / 'data/validation_evaluation_videos/evaluation/data/raw/LAV-DF/extracted',
    BACKEND_ROOT / 'data/validation_evaluation_videos/evaluation/data/raw/LAV-DF',
]
LAVDF_ROOT = next((p for p in _lavdf_candidates if p.exists()), _lavdf_candidates[0])

_meta_env = os.getenv('LAVDF_METADATA', '').strip()
_metadata_candidates = []
if _meta_env:
    _metadata_candidates.append(Path(_meta_env).expanduser())
_metadata_candidates += [
    LAVDF_ROOT / 'metadata.min.json',
    LAVDF_ROOT / 'metadata.json',
]
LAVDF_METADATA = next((p for p in _metadata_candidates if p.exists()), None)
if LAVDF_METADATA is None and LAVDF_ROOT.exists():
    for _pattern in ('metadata.min.json', 'metadata.json'):
        _matches = sorted(LAVDF_ROOT.rglob(_pattern))
        if _matches:
            LAVDF_METADATA = _matches[0]
            break

LAVDF_SUBSET = os.getenv('LAVDF_SUBSET', 'test').strip().lower() or 'test'
if LAVDF_SUBSET not in {'all', 'train', 'dev', 'test'}:
    raise ValueError(f'Invalid LAVDF_SUBSET={LAVDF_SUBSET!r}. Use one of all/train/dev/test.')
LAVDF_MAX_VIDEOS = int(os.getenv('LAVDF_MAX_VIDEOS', '0'))
LAVDF_FORCE_REEXTRACT = os.getenv('LAVDF_FORCE_REEXTRACT', '1') == '1'
LAVDF_DISABLE_FALLBACK_EXTRACTOR = os.getenv('LAVDF_DISABLE_FALLBACK_EXTRACTOR', '0') == '1'
LAVDF_FLUSH_EVERY = int(os.getenv('LAVDF_FLUSH_EVERY', '64'))
LAVDF_SHUFFLE_SEED = int(os.getenv('LAVDF_SHUFFLE_SEED', '42'))

DEFAULT_LAVDF_MODEL_DIR = BACKEND_ROOT / 'models/step46_fakeav_robust_constrained_s42_20260317_111112_fold_01_p2_r03_focal_lr0p0003'
MODEL_DIR_LAVDF = Path(os.getenv('LAVDF_MODEL_DIR', str(DEFAULT_LAVDF_MODEL_DIR))).expanduser()
FEATURE_PROFILE_LAVDF = os.getenv('LAVDF_FEATURE_PROFILE', 'extended')
LAVDF_THRESHOLD_OVERRIDE = os.getenv('LAVDF_THRESHOLD', '').strip()
LAVDF_FEATURE_CSV = (BACKEND_ROOT / 'data' / 'processed' / f'causal_multimodal_dataset_lavdf_{LAVDF_SUBSET}_eval.csv').resolve()

LAVDF_TORCH_HOME = (BACKEND_ROOT / '.torch_cache').resolve()
LAVDF_MPLCONFIGDIR = (BACKEND_ROOT / '.mplconfig').resolve()
LAVDF_VISUAL_TCN_PATH = (BACKEND_ROOT / 'models/visual_tcn.pth').resolve()
LAVDF_W2V2_FINETUNED_PATH = (BACKEND_ROOT / 'models/wav2vec2_base_fakeav_ft.pt').resolve()

print('LAVDF_CELL_VERSION         = 2026-03-21-v1')
print('BACKEND_ROOT               =', BACKEND_ROOT)
print('PYTHON_EXE                 =', PYTHON_EXE)
print('Probe sys.executable       =', _probe_lines[0] if _probe_lines else 'n/a')
print('LAVDF_ROOT                 =', LAVDF_ROOT)
print('LAVDF_METADATA             =', LAVDF_METADATA)
print('LAVDF_SUBSET               =', LAVDF_SUBSET)
print('LAVDF_FEATURE_CSV          =', LAVDF_FEATURE_CSV)
print('MODEL_DIR_LAVDF            =', MODEL_DIR_LAVDF)
print('FEATURE_PROFILE_LAVDF      =', FEATURE_PROFILE_LAVDF)
print('LAVDF_MAX_VIDEOS           =', LAVDF_MAX_VIDEOS)
print('LAVDF_FORCE_REEXTRACT      =', LAVDF_FORCE_REEXTRACT)
print('LAVDF_DISABLE_FALLBACK     =', LAVDF_DISABLE_FALLBACK_EXTRACTOR)
print('LAVDF_FLUSH_EVERY          =', LAVDF_FLUSH_EVERY)
print('LAVDF_TORCH_HOME           =', LAVDF_TORCH_HOME)
print('LAVDF_MPLCONFIGDIR         =', LAVDF_MPLCONFIGDIR)
print('LAVDF_VISUAL_TCN_PATH      =', LAVDF_VISUAL_TCN_PATH, '(exists=' + str(LAVDF_VISUAL_TCN_PATH.exists()) + ')')
print('LAVDF_W2V2_FINETUNED       =', LAVDF_W2V2_FINETUNED_PATH, '(exists=' + str(LAVDF_W2V2_FINETUNED_PATH.exists()) + ')')
print('LAV-DF root candidates:')
for _p in _lavdf_candidates:
    print('  -', _p, '(exists=' + str(_p.exists()) + ')')

if not LAVDF_ROOT.exists():
    raise FileNotFoundError(
        'LAV-DF root not found. Set LAVDF_ROOT env var or place dataset under one of: '
        + ', '.join(str(p) for p in _lavdf_candidates)
    )
if LAVDF_METADATA is None or not LAVDF_METADATA.exists():
    raise FileNotFoundError('LAV-DF metadata file not found. Expected metadata.min.json or metadata.json under LAVDF_ROOT.')

# %% [markdown]
# ### LAV-DF: Feature Extraction
# Build a CFN-compatible feature CSV from the selected LAV-DF subset using the metadata-driven loader.

# %%
from pathlib import Path
import os
import subprocess
import pandas as pd

build_script = BACKEND_ROOT / 'scripts/build_lavdf_features.py'
if not build_script.exists():
    raise FileNotFoundError(f'Missing script: {build_script}')

py_bin = Path(PYTHON_EXE)
if not py_bin.exists():
    raise FileNotFoundError(
        f'Required venv python not found: {py_bin}. '
        'Run the LAV-DF config cell first.'
    )
python_exe = str(py_bin)
print('LAVDF_CELL_VERSION=2026-03-21-v1')
print('Python for extraction:', python_exe)

probe = subprocess.run(
    [python_exe, '-c', 'import sys,pandas;print(sys.executable);print(sys.prefix)'],
    text=True,
    capture_output=True,
)
if probe.returncode != 0:
    print('stderr:' + probe.stderr[-3000:])
    raise RuntimeError('Extraction python probe failed.')
if '.venv' not in probe.stdout:
    raise RuntimeError('Wrong python selected for extraction. Restart kernel and rerun setup cells.')

env = dict(os.environ)
LAVDF_TORCH_HOME.mkdir(parents=True, exist_ok=True)
LAVDF_MPLCONFIGDIR.mkdir(parents=True, exist_ok=True)
env['TORCH_HOME'] = str(LAVDF_TORCH_HOME)
env['MPLCONFIGDIR'] = str(LAVDF_MPLCONFIGDIR)
env['CFN_W2V2_MODEL'] = env.get('CFN_W2V2_MODEL', 'WAV2VEC2_BASE')
if LAVDF_VISUAL_TCN_PATH.exists():
    env['CFN_VISUAL_TCN_PATH'] = str(LAVDF_VISUAL_TCN_PATH)
if LAVDF_W2V2_FINETUNED_PATH.exists():
    env['CFN_W2V2_FINETUNED_PATH'] = str(LAVDF_W2V2_FINETUNED_PATH)

if LAVDF_FORCE_REEXTRACT and LAVDF_FEATURE_CSV.exists():
    LAVDF_FEATURE_CSV.unlink()
    print('Removed previous CSV for full re-extraction:', LAVDF_FEATURE_CSV)

cmd = [
    python_exe, str(build_script),
    '--input-root', str(LAVDF_ROOT),
    '--output-csv', str(LAVDF_FEATURE_CSV),
    '--metadata', str(LAVDF_METADATA),
    '--subset', str(LAVDF_SUBSET),
    '--shuffle-seed', str(LAVDF_SHUFFLE_SEED),
    '--flush-every', str(LAVDF_FLUSH_EVERY),
    '--dataset-name', 'LAVDF',
]
if int(LAVDF_MAX_VIDEOS) > 0:
    cmd += ['--max-videos', str(int(LAVDF_MAX_VIDEOS))]
if LAVDF_DISABLE_FALLBACK_EXTRACTOR:
    cmd.append('--disable-fallback-extractor')

print('Running:', ' '.join(cmd))
res = subprocess.run(cmd, cwd=str(BACKEND_ROOT), text=True, capture_output=True, env=env)
if res.stdout.strip():
    print(res.stdout)
if res.returncode != 0:
    print('Extraction failed with code:', res.returncode)
    if res.stderr.strip():
        print('stderr:' + res.stderr[-8000:])
    raise RuntimeError('build_lavdf_features.py failed; see stderr above.')
if res.stderr.strip():
    print('stderr:' + res.stderr[-2000:])

if not LAVDF_FEATURE_CSV.exists():
    raise FileNotFoundError(f'Feature CSV not created: {LAVDF_FEATURE_CSV}')
if LAVDF_FEATURE_CSV.stat().st_size == 0:
    raise RuntimeError(f'Feature CSV exists but is empty: {LAVDF_FEATURE_CSV}')

df_lavdf = pd.read_csv(LAVDF_FEATURE_CSV)
print('Rows:', len(df_lavdf), 'Columns:', len(df_lavdf.columns), 'subset=', LAVDF_SUBSET)
if df_lavdf.empty:
    raise RuntimeError('Feature CSV has zero rows after read; extraction did not produce usable samples.')

display(df_lavdf['label'].value_counts(dropna=False).rename_axis('label').to_frame('count'))
if 'split' in df_lavdf.columns:
    display(df_lavdf['split'].value_counts(dropna=False).rename_axis('split').to_frame('count'))
if {'video_fake', 'audio_fake'}.issubset(df_lavdf.columns):
    combo = df_lavdf.groupby(['video_fake', 'audio_fake']).size().reset_index(name='count')
    display(combo)

# %% [markdown]
# ### LAV-DF: Feature Quality Audit
# Checks whether the extracted AV, embedding, and metadata columns are populated and non-degenerate.

# %%
import pandas as pd

if not LAVDF_FEATURE_CSV.exists():
    raise FileNotFoundError(f'Missing LAV-DF feature CSV: {LAVDF_FEATURE_CSV}. Run extraction cell first.')

df_q = pd.read_csv(LAVDF_FEATURE_CSV)
print('LAVDF_CELL_VERSION=2026-03-21-v1')
print('Feature quality audit rows:', len(df_q))

embed_cols = ['tcn_visual_emb', 'wav2vec_audio_emb', 'wav2vec2_base_ft_emb', 'effnet_b4_face_emb', 'lip_roi_emb']
av_dyn_cols = [
    'av_correlation', 'av_peak_corr', 'av_peak_prominence',
    'av_corr_05_std', 'av_corr_10_std', 'av_corr_20_std',
    'audio_rms_std', 'lip_velocity_std',
]
meta_cols = ['used_fallback_extractor', 'video_fake', 'audio_fake', 'n_fakes']

summary_rows = []
for col in embed_cols + av_dyn_cols + meta_cols:
    if col not in df_q.columns:
        summary_rows.append({'column': col, 'present': False})
        continue
    s = pd.to_numeric(df_q[col], errors='coerce').fillna(0.0)
    summary_rows.append(
        {
            'column': col,
            'present': True,
            'mean': float(s.mean()),
            'std': float(s.std()),
            'nunique': int(s.nunique(dropna=False)),
            'nonzero_rate': float((s.abs() > 1e-12).mean()),
        }
    )

summary_df = pd.DataFrame(summary_rows)
display(summary_df)

num_cols = df_q.select_dtypes(include=['number']).columns.tolist()
const_cols = [
    c for c in num_cols
    if c not in ['label', 'video_fake', 'audio_fake', 'modify_video', 'modify_audio']
    and df_q[c].nunique(dropna=False) <= 1
]
print('Constant numeric feature columns:', len(const_cols))
if const_cols:
    print('Sample constants:', const_cols[:20])

issues = []
for col in embed_cols + av_dyn_cols:
    row = summary_df[summary_df['column'] == col]
    if row.empty or not bool(row.iloc[0].get('present', False)):
        issues.append(f'missing: {col}')
        continue
    nz = float(row.iloc[0].get('nonzero_rate', 0.0) or 0.0)
    if nz < 0.05:
        issues.append(f'near-zero: {col} (nonzero_rate={nz:.3f})')

if issues:
    print('Quality issues detected:')
    for item in issues:
        print(' -', item)
else:
    print('Quality audit passed: key AV/audio/embedding features are populated.')

# %% [markdown]
# ### LAV-DF: Evaluation
# Runs clip-level classification evaluation on the extracted LAV-DF subset using the generic CFN CSV evaluator.

# %%
import json
import subprocess
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

if not LAVDF_FEATURE_CSV.exists():
    raise FileNotFoundError(f'Missing LAV-DF feature CSV: {LAVDF_FEATURE_CSV}. Run extraction cell first.')

eval_script = BACKEND_ROOT / 'scripts/eval_cfn_csv.py'
if not eval_script.exists():
    raise FileNotFoundError(f'Missing script: {eval_script}')
if not MODEL_DIR_LAVDF.exists():
    raise FileNotFoundError(f'Model directory not found: {MODEL_DIR_LAVDF}')

py_bin = Path(PYTHON_EXE)
if not py_bin.exists():
    raise FileNotFoundError(
        f'Required venv python not found: {py_bin}. '
        'Run the LAV-DF config cell first.'
    )
python_exe = str(py_bin)
print('LAVDF_CELL_VERSION=2026-03-21-v1')
print('Python for evaluation:', python_exe)

probe = subprocess.run(
    [python_exe, '-c', 'import sys,joblib,pandas;print(sys.executable);print(sys.prefix)'],
    text=True,
    capture_output=True,
)
if probe.returncode != 0:
    print('stderr:' + probe.stderr[-3000:])
    raise RuntimeError('Evaluation python probe failed.')
if '.venv' not in probe.stdout:
    raise RuntimeError('Wrong python selected for evaluation. Restart kernel and rerun setup cells.')

cmd = [
    python_exe, str(eval_script),
    '--model-dir', str(MODEL_DIR_LAVDF),
    '--data-csv', str(LAVDF_FEATURE_CSV),
    '--feature-profile', str(FEATURE_PROFILE_LAVDF),
]
if LAVDF_THRESHOLD_OVERRIDE:
    cmd += ['--threshold', LAVDF_THRESHOLD_OVERRIDE]

print('Running:', ' '.join(cmd))
res = subprocess.run(cmd, cwd=str(BACKEND_ROOT), text=True, capture_output=True)
if res.stdout.strip():
    print(res.stdout)
if res.returncode != 0:
    print('Evaluation failed with code:', res.returncode)
    if res.stderr.strip():
        print('stderr:' + res.stderr[-8000:])
    raise RuntimeError('eval_cfn_csv.py failed; see stderr above.')
if res.stderr.strip():
    print('stderr:' + res.stderr[-2000:])

overall = None
for ln in res.stdout.splitlines():
    if ln.startswith('overall:'):
        overall = json.loads(ln.split('overall:', 1)[1].strip())
        break

if overall is not None:
    print('LAV-DF Metrics Summary:')
    print(
        f"ACC={float(overall.get('acc', 0.0)):.4f} "
        f"PREC={float(overall.get('prec', 0.0)):.4f} "
        f"REC={float(overall.get('rec', 0.0)):.4f} "
        f"F1={float(overall.get('f1', 0.0)):.4f} "
        f"AUC={float(overall.get('auc', 0.0)):.4f} "
        f"PR_AUC={float(overall.get('pr_auc', 0.0)):.4f} "
        f"SPEC={float(overall.get('spec', 0.0)):.4f} "
        f"BAL_ACC={float(overall.get('bal_acc', 0.0)):.4f} "
        f"| TP={int(overall.get('tp', 0))} TN={int(overall.get('tn', 0))} "
        f"FP={int(overall.get('fp', 0))} FN={int(overall.get('fn', 0))}"
    )
    show = {k: overall.get(k) for k in ['acc', 'prec', 'rec', 'f1', 'auc', 'pr_auc', 'spec', 'bal_acc', 'tp', 'tn', 'fp', 'fn']}
    display(pd.DataFrame([show]))

    tp = int(overall.get('tp', 0))
    tn = int(overall.get('tn', 0))
    fp = int(overall.get('fp', 0))
    fn = int(overall.get('fn', 0))
    cm = np.array([[tn, fp], [fn, tp]], dtype=int)

    fig, ax = plt.subplots(figsize=(4.5, 4))
    im = ax.imshow(cm, cmap='Blues')
    for (r, c), v in np.ndenumerate(cm):
        ax.text(c, r, str(v), ha='center', va='center', fontsize=12)
    ax.set_xticks([0, 1], labels=['Pred Real', 'Pred Fake'])
    ax.set_yticks([0, 1], labels=['True Real', 'True Fake'])
    ax.set_title(f'LAV-DF Confusion Matrix ({LAVDF_SUBSET})')
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    plt.tight_layout()
    plt.show()
else:
    raise RuntimeError('Could not parse overall metrics from eval_cfn_csv.py output.')

# %% [markdown]
# Corrected Cross-dataset Evaluation

# %%
# ============================================================
# LAV-DF Cross-Dataset Evaluation — Cell 1: Config
# ============================================================
from pathlib import Path
import os, sys

BACKEND_ROOT = next(
    (c for c in [
        Path('/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend'),
        Path('/content/CausalX-Project/backend'),
        Path.cwd(),
        Path.cwd().parent,
    ] if (c / 'src').exists()),
    None
)
if BACKEND_ROOT is None:
    raise RuntimeError('Cannot find backend root with src/ directory.')

sys.path.insert(0, str(BACKEND_ROOT))

PYTHON_EXE = str(BACKEND_ROOT / '.venv' / 'bin' / 'python')
if not Path(PYTHON_EXE).exists():
    import shutil
    PYTHON_EXE = shutil.which('python3') or sys.executable

# ---- LAV-DF Paths ----
LAVDF_ROOT     = BACKEND_ROOT / 'data/validation_evaluation_videos/evaluation/data/raw/LAV-DF/extracted/LAV-DF'
LAVDF_METADATA = LAVDF_ROOT / 'metadata.min.json'
LAVDF_FEATURE_CSV_VAL  = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_lavdf_dev_eval_fixed.csv'
LAVDF_FEATURE_CSV_TEST = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_lavdf_test_eval_fixed.csv'

# ---- Model ----
MODEL_DIR_LAVDF = BACKEND_ROOT / 'models/step46_fakeav_robust_constrained_s42_20260317_030925_fold_01_p2_r03_focal_lr0p0003'

# ---- Feature Profile ----
FEATURE_PROFILE_LAVDF = 'extended'

# ---- Torch/MPL cache ----
LAVDF_TORCH_HOME   = BACKEND_ROOT / '.torch_cache'
LAVDF_MPLCONFIGDIR = BACKEND_ROOT / '.mpl_cache'
LAVDF_TORCH_HOME.mkdir(parents=True, exist_ok=True)
LAVDF_MPLCONFIGDIR.mkdir(parents=True, exist_ok=True)

# ---- Extraction settings ----
LAVDF_SHUFFLE_SEED    = 42
LAVDF_FLUSH_EVERY     = 64
LAVDF_MAX_VIDEOS      = 0    
LAVDF_FORCE_REEXTRACT = True  # True = re-extract fresh

# ---- Scripts ----
BUILD_SCRIPT = BACKEND_ROOT / 'scripts/build_lavdf_features.py'
EVAL_SCRIPT  = BACKEND_ROOT / 'scripts/eval_cfn_csv.py'
for s in [BUILD_SCRIPT, EVAL_SCRIPT]:
    if not s.exists():
        raise FileNotFoundError(f'Missing script: {s}')

# ---- Env ----
ENV = dict(os.environ)
ENV['TORCH_HOME']            = str(LAVDF_TORCH_HOME)
ENV['MPLCONFIGDIR']          = str(LAVDF_MPLCONFIGDIR)
ENV['CFN_W2V2_MODEL']        = 'WAV2VEC2_BASE'
ENV['CFN_USE_EMBEDDINGS']    = 'true'
ENV['MEDIAPIPE_DISABLE_GPU'] = '1'
ENV['CUDA_VISIBLE_DEVICES']  = '-1'

print('BACKEND_ROOT    :', BACKEND_ROOT)
print('PYTHON_EXE      :', PYTHON_EXE)
print('LAVDF_ROOT exists:', LAVDF_ROOT.exists())
print('METADATA exists  :', LAVDF_METADATA.exists())
print('MODEL_DIR exists :', MODEL_DIR_LAVDF.exists())

models_to_check = {
    'visual_tcn'        : BACKEND_ROOT / 'models/visual_tcn.pth',
    'wav2vec_finetuned' : BACKEND_ROOT / 'models/wav2vec2_finetuned.pth',
}
for name, path in models_to_check.items():
    print(f'{"✅" if path.exists() else "❌"} {name}: {path}')

# ---- Fix wav2vec ENV ----
ENV['CFN_W2V2_MODEL']     = 'WAV2VEC2_BASE'
ENV['CFN_USE_EMBEDDINGS'] = 'true'

# Explicitly set torch home for model download
ENV['TORCH_HOME'] = str(LAVDF_TORCH_HOME)

# TCN zero is expected — same as FakeAVCeleb training
# Only wav2vec needs fixing

print('=== Fixed ENV ===')
for k in ['CFN_W2V2_MODEL', 'CFN_USE_EMBEDDINGS', 'TORCH_HOME']:
    print(f'  ✅ {k} = {ENV[k]}')
    
import subprocess

result = subprocess.run(
    ['grep', '-n', 'wav2vec',
     str(BACKEND_ROOT / 'scripts/build_lavdf_features.py')],
    capture_output=True, text=True
)
print(result.stdout[:3000])
# Out:
# BACKEND_ROOT    : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend
# PYTHON_EXE      : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.venv/bin/python
# LAVDF_ROOT exists: True
# METADATA exists  : True
# MODEL_DIR exists : True
# ✅ visual_tcn: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/visual_tcn.pth
# ❌ wav2vec_finetuned: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/wav2vec2_finetuned.pth
# === Fixed ENV ===
#   ✅ CFN_W2V2_MODEL = WAV2VEC2_BASE
#   ✅ CFN_USE_EMBEDDINGS = true
#   ✅ TORCH_HOME = /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.torch_cache

# %%
# ============================================================
# LAV-DF Cross-Dataset Evaluation — Cell 2: Feature Extraction
# ============================================================
import subprocess
import pandas as pd

# Verify subprocess ENV before extraction
_env_check = subprocess.run(
    [PYTHON_EXE, '-c',
     'import os; print("CFN_W2V2_MODEL =", os.getenv("CFN_W2V2_MODEL", "NOT SET")); '
     'print("CFN_USE_EMBEDDINGS =", os.getenv("CFN_USE_EMBEDDINGS", "NOT SET")); '
     'print("TORCH_HOME =", os.getenv("TORCH_HOME", "NOT SET"))'],
    capture_output=True, text=True, env=ENV
)
print('=== Subprocess ENV Check ===')
print(_env_check.stdout.strip())
if 'NOT SET' in _env_check.stdout:
    raise RuntimeError('ENV vars not properly passed to subprocess. Fix Cell 1 first.')
print('✅ ENV vars confirmed in subprocess\n')


def extract_lavdf_features(subset: str, output_csv: Path, force: bool = True):
    if force and output_csv.exists():
        output_csv.unlink()
        print(f'Removed old CSV for re-extraction: {output_csv}')

    valid_subsets = {'all', 'train', 'dev', 'test'}
    if subset not in valid_subsets:
        raise ValueError(f'Invalid subset "{subset}". Choose from: {valid_subsets}')

    # Ensure ENV has correct wav2vec settings before each extraction
    ENV['CFN_W2V2_MODEL']     = 'WAV2VEC2_BASE'
    ENV['CFN_USE_EMBEDDINGS'] = 'true'
    ENV['TORCH_HOME']         = str(LAVDF_TORCH_HOME)

    cmd = [
        PYTHON_EXE, str(BUILD_SCRIPT),
        '--input-root',   str(LAVDF_ROOT),
        '--output-csv',   str(output_csv),
        '--metadata',     str(LAVDF_METADATA),
        '--subset',       subset,
        '--shuffle-seed', str(LAVDF_SHUFFLE_SEED),
        '--flush-every',  str(LAVDF_FLUSH_EVERY),
        '--dataset-name', 'LAVDF',
    ]
    if int(LAVDF_MAX_VIDEOS) > 0:
        cmd += ['--max-videos', str(int(LAVDF_MAX_VIDEOS))]

    print(f'\nExtracting [{subset}] → {output_csv.name}')
    print('CMD:', ' '.join(cmd))

    res = subprocess.run(
        cmd, cwd=str(BACKEND_ROOT),
        text=True, capture_output=True, env=ENV
    )
    if res.stdout.strip():
        print(res.stdout[-3000:])
    if res.returncode != 0:
        print('STDERR:', res.stderr[-5000:])
        raise RuntimeError(f'Extraction failed for subset={subset}. See STDERR above.')
    if res.stderr.strip():
        print('stderr (tail):', res.stderr[-1000:])

    if not output_csv.exists() or output_csv.stat().st_size == 0:
        raise RuntimeError(f'Output CSV missing or empty: {output_csv}')

    df = pd.read_csv(output_csv)
    print(f'\n[{subset}] Rows={len(df)} Columns={len(df.columns)}')
    print('Label counts:')
    print(df['label'].value_counts(dropna=False).to_string())

    # Feature quality check
    key_cols = [
        'wav2vec_audio_emb', 'tcn_visual_emb',
        'av_correlation', 'lip_velocity_std', 'audio_rms_std',
    ]
    print('\nKey feature nonzero rates:')
    for col in key_cols:
        if col in df.columns:
            s = pd.to_numeric(df[col], errors='coerce').fillna(0.0)
            nz = float((s.abs() > 1e-12).mean())
            status = '✅' if nz > 0.05 else '❌'
            print(f'  {status} {col}: nonzero_rate={nz:.4f}')
        else:
            print(f'  ❌ {col}: MISSING')

    return df


# Extract dev split first — for threshold calibration
df_val = extract_lavdf_features(
    'dev', LAVDF_FEATURE_CSV_VAL, force=LAVDF_FORCE_REEXTRACT
)

# Extract test split
df_test = extract_lavdf_features(
    'test', LAVDF_FEATURE_CSV_TEST, force=LAVDF_FORCE_REEXTRACT
)
# Out:
# === Subprocess ENV Check ===
# CFN_W2V2_MODEL = WAV2VEC2_BASE
# CFN_USE_EMBEDDINGS = true
# TORCH_HOME = /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/.torch_cache
# ✅ ENV vars confirmed in subprocess
#
# Removed old CSV for re-extraction: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_dataset_lavdf_dev_eval_fixed.csv
#
# Extracting [dev] → causal_multimodal_dataset_lavdf_dev_eval_fixed.csv
# ...

# %% [markdown]
# Threshold Calibration (Val Set)

# %%
# ============================================================
# LAV-DF Cross-Dataset Evaluation — Cell 3: Threshold Calibration
# ============================================================
import subprocess, json
import numpy as np
import pandas as pd

if not LAVDF_FEATURE_CSV_VAL.exists():
    raise FileNotFoundError(
        f'Dev CSV missing: {LAVDF_FEATURE_CSV_VAL}. Run Cell 2 first.'
    )

print('Running threshold sweep on DEV set ...')
print(f'Dev CSV: {LAVDF_FEATURE_CSV_VAL}')
print(f'Model  : {MODEL_DIR_LAVDF}\n')

thresholds_to_try = [round(t, 3) for t in np.arange(0.05, 0.95, 0.025)]

best_thr    = 0.5
best_bal    = 0.0
thr_results = []

for i, thr in enumerate(thresholds_to_try):
    cmd_thr = [
        PYTHON_EXE, str(EVAL_SCRIPT),
        '--model-dir',       str(MODEL_DIR_LAVDF),
        '--data-csv',        str(LAVDF_FEATURE_CSV_VAL),
        '--feature-profile', FEATURE_PROFILE_LAVDF,
        '--threshold',       str(thr),
    ]
    r = subprocess.run(
        cmd_thr, cwd=str(BACKEND_ROOT),
        text=True, capture_output=True, env=ENV
    )
    for ln in r.stdout.splitlines():
        if ln.startswith('overall:'):
            m = json.loads(ln.split('overall:', 1)[1].strip())
            bal  = float(m.get('bal_acc', 0.0))
            f1   = float(m.get('f1',      0.0))
            spec = float(m.get('spec',    0.0))
            rec  = float(m.get('rec',     0.0))
            auc  = float(m.get('auc',     0.0))
            thr_results.append({
                'threshold': thr,
                'bal_acc':   bal,
                'f1':        f1,
                'spec':      spec,
                'rec':       rec,
                'auc':       auc,
            })
            if bal > best_bal:
                best_bal = bal
                best_thr = thr
            if (i + 1) % 10 == 0:
                print(f'  Progress: {i+1}/{len(thresholds_to_try)} '
                      f'| current best thr={best_thr} bal_acc={best_bal:.4f}')
            break

thr_df = pd.DataFrame(thr_results).sort_values('bal_acc', ascending=False)

print('\nTop 10 thresholds by Balanced Accuracy:')
print(thr_df.head(10).to_string(index=False))
print(f'\n✅ Best LAV-DF threshold = {best_thr}  (bal_acc={best_bal:.4f})')
# Out:
# Running threshold sweep on DEV set ...
# Dev CSV: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_dataset_lavdf_dev_eval_fixed.csv
# Model  : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/step46_fakeav_robust_constrained_s42_20260317_030925_fold_01_p2_r03_focal_lr0p0003
#   Progress: 10/36 | current best thr=0.275 bal_acc=0.5263
#   Progress: 20/36 | current best thr=0.5 bal_acc=0.5361
#   Progress: 30/36 | current best thr=0.5 bal_acc=0.5361
#
# Top 10 thresholds by Balanced Accuracy:
#  threshold  bal_acc       f1     spec      rec      auc
#      0.500 0.536140 0.530061 0.669206 0.403074 0.545077
#      0.450 0.535681 0.569787 0.618909 0.452452 0.545077
#      0.600 0.535644 0.448740 0.756982 0.314305 0.545077
#      0.525 0.535286 0.509552 0.691089 0.379483 0.545077
#      0.625 0.535156 0.428665 0.775722 0.294589 0.545077
#      0.475 0.534972 0.549579 0.642849 0.427095 0.545077
# ...

# %% [markdown]
# Evaluation

# %%
# ============================================================
# LAV-DF Cross-Dataset Evaluation — Cell 4: Final Evaluation
# ============================================================
import subprocess, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

if 'best_thr' not in globals():
    raise RuntimeError('best_thr not defined. Run Cell 3 first.')
if not LAVDF_FEATURE_CSV_TEST.exists():
    raise FileNotFoundError(
        f'Test CSV missing: {LAVDF_FEATURE_CSV_TEST}. Run Cell 2 first.'
    )

print(f'Using calibrated threshold : {best_thr}')
print(f'Test CSV                   : {LAVDF_FEATURE_CSV_TEST}')
print(f'Model                      : {MODEL_DIR_LAVDF}\n')

cmd_test = [
    PYTHON_EXE, str(EVAL_SCRIPT),
    '--model-dir',       str(MODEL_DIR_LAVDF),
    '--data-csv',        str(LAVDF_FEATURE_CSV_TEST),
    '--feature-profile', FEATURE_PROFILE_LAVDF,
    '--threshold',       str(best_thr),
]
res_test = subprocess.run(
    cmd_test, cwd=str(BACKEND_ROOT),
    text=True, capture_output=True, env=ENV
)
if res_test.stdout.strip():
    print(res_test.stdout)
if res_test.returncode != 0:
    print('STDERR:', res_test.stderr[-5000:])
    raise RuntimeError('Test evaluation failed. See STDERR above.')

# ---- Parse overall metrics ----
overall = None
for ln in res_test.stdout.splitlines():
    if ln.startswith('overall:'):
        overall = json.loads(ln.split('overall:', 1)[1].strip())
        break

if overall is None:
    raise RuntimeError('Could not parse overall metrics from eval output.')

# ---- Clean summary ----
print('\n' + '='*60)
print('  LAV-DF Cross-Dataset Evaluation — Final Results')
print('='*60)
print(f"  Model    : step46_fakeav_robust_constrained (FakeAVCeleb trained)")
print(f"  Dataset  : LAV-DF test split")
print(f"  Threshold: {best_thr} (calibrated on LAV-DF dev set)")
print('='*60)
print(f"  ACC      = {float(overall['acc']):.4f}")
print(f"  AUC      = {float(overall['auc']):.4f}")
print(f"  PR-AUC   = {float(overall['pr_auc']):.4f}")
print(f"  F1       = {float(overall['f1']):.4f}")
print(f"  Precision= {float(overall['prec']):.4f}")
print(f"  Recall   = {float(overall['rec']):.4f}")
print(f"  Spec     = {float(overall['spec']):.4f}")
print(f"  Bal.ACC  = {float(overall['bal_acc']):.4f}")
print(f"  TP={int(overall['tp'])}  TN={int(overall['tn'])}  "
      f"FP={int(overall['fp'])}  FN={int(overall['fn'])}")
print('='*60)

display(pd.DataFrame([{
    'ACC':    round(float(overall['acc']),   4),
    'AUC':    round(float(overall['auc']),   4),
    'PR-AUC': round(float(overall['pr_auc']),4),
    'F1':     round(float(overall['f1']),    4),
    'Prec':   round(float(overall['prec']),  4),
    'Rec':    round(float(overall['rec']),   4),
    'Spec':   round(float(overall['spec']),  4),
    'BalACC': round(float(overall['bal_acc']),4),
}]))

# ---- Per-scenario breakdown ----
print('\nPer-Scenario Breakdown:')
df_test_data = pd.read_csv(LAVDF_FEATURE_CSV_TEST)
if {'video_fake', 'audio_fake'}.issubset(df_test_data.columns):
    def scenario_name(r):
        vf = int(r['video_fake'])
        af = int(r['audio_fake'])
        return {
            (0, 0): 'RealVideo-RealAudio',
            (1, 0): 'FakeVideo-RealAudio',
            (0, 1): 'RealVideo-FakeAudio',
            (1, 1): 'FakeVideo-FakeAudio',
        }.get((vf, af), f'vf={vf}_af={af}')

    df_test_data['scenario'] = df_test_data.apply(scenario_name, axis=1)
    sc_counts = df_test_data.groupby('scenario').agg(
        count=('label', 'count'),
        fake_rate=('label', 'mean'),
    ).reset_index()
    print(sc_counts.to_string(index=False))

# ---- Plots ----
tp = int(overall['tp']); tn = int(overall['tn'])
fp = int(overall['fp']); fn = int(overall['fn'])
cm = np.array([[tn, fp], [fn, tp]], dtype=int)

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# Confusion matrix
im = axes[0].imshow(cm, cmap='Blues')
for (r, c), v in np.ndenumerate(cm):
    axes[0].text(c, r, str(v), ha='center', va='center', fontsize=12)
axes[0].set_xticks([0, 1], labels=['Pred Real', 'Pred Fake'])
axes[0].set_yticks([0, 1], labels=['True Real', 'True Fake'])
axes[0].set_title(f'LAV-DF Confusion Matrix\n(thr={best_thr})')
fig.colorbar(im, ax=axes[0], fraction=0.046, pad=0.04)

# Threshold sweep
if 'thr_results' in globals() and thr_results:
    thr_plot = pd.DataFrame(thr_results)
    axes[1].plot(thr_plot['threshold'], thr_plot['bal_acc'],
                 label='Balanced ACC', marker='o', markersize=3)
    axes[1].plot(thr_plot['threshold'], thr_plot['f1'],
                 label='F1', marker='s', markersize=3)
    axes[1].plot(thr_plot['threshold'], thr_plot['spec'],
                 label='Specificity', marker='^', markersize=3)
    axes[1].axvline(best_thr, color='red', linestyle='--',
                    label=f'Best thr={best_thr}')
    axes[1].set_xlabel('Threshold')
    axes[1].set_ylabel('Score')
    axes[1].set_title('Threshold Sweep (LAV-DF Dev Set)')
    axes[1].legend(fontsize=8)
    axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# ---- Comparison table ----
print('\nComparison: In-Domain vs Cross-Dataset')
display(pd.DataFrame([
    {
        'Dataset':  'FakeAVCeleb — Step44 (in-domain)',
        'ACC':  0.9988, 'AUC': 0.9997,
        'F1':   0.9994, 'Bal.ACC': 0.9799,
    },
    {
        'Dataset':  'LAV-DF (cross-dataset, zero-shot)',
        'ACC':  round(float(overall['acc']),   4),
        'AUC':  round(float(overall['auc']),   4),
        'F1':   round(float(overall['f1']),    4),
        'Bal.ACC': round(float(overall['bal_acc']), 4),
    },
]))
# Out:
# Using calibrated threshold : 0.5
# Test CSV                   : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_dataset_lavdf_test_eval_fixed.csv
# Model                      : /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/step46_fakeav_robust_constrained_s42_20260317_030925_fold_01_p2_r03_focal_lr0p0003
#
# AV features: zero-filled 3 missing columns: ['effnet_b4_face_emb', 'lip_roi_emb', 'wav2vec2_base_ft_emb']
# Physical features: zero-filled 5 missing columns: ['video_motion_noise_ratio', 'video_shape_noise_ratio', 'video_temporal_instability', 'video_detection_dropout', 'video_compression_proxy']
# model_dir=/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/step46_fakeav_robust_constrained_s42_20260317_030925_fold_01_p2_r03_focal_lr0p0003
# data_csv=/Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_dataset_lavdf_test_eval_fixed.csv
# ...

# %% [markdown]
# ## LAV-DF Post-Processing Balance

# %%
# ============================================================
# LAV-DF Post-Processing Balance — Cell A
# ============================================================
import pandas as pd
from pathlib import Path

# ---- Paths ----
LAVDF_FEATURE_CSV_DEV  = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_lavdf_dev_eval_fixed.csv'
LAVDF_FEATURE_CSV_TEST = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_lavdf_test_eval_fixed.csv'

LAVDF_BALANCED_DEV  = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_lavdf_dev_balanced.csv'
LAVDF_BALANCED_TEST = BACKEND_ROOT / 'data/processed/causal_multimodal_dataset_lavdf_test_balanced.csv'

def balance_dataset(csv_path: Path, out_path: Path, seed: int = 42):
    if not csv_path.exists():
        raise FileNotFoundError(f'CSV not found: {csv_path}')

    df = pd.read_csv(csv_path)
    print(f'Original [{csv_path.name}]:')
    print(df['label'].value_counts(dropna=False).to_string())

    real = df[df['label'] == 0]
    fake = df[df['label'] == 1]

    # Minority class size
    n = min(len(real), len(fake))

    df_balanced = pd.concat([
        real.sample(n=n, random_state=seed),
        fake.sample(n=n, random_state=seed),
    ]).sample(frac=1, random_state=seed).reset_index(drop=True)

    df_balanced.to_csv(out_path, index=False)

    print(f'Balanced [{out_path.name}]:')
    print(df_balanced['label'].value_counts(dropna=False).to_string())
    print(f'Total rows: {len(df_balanced)} (real={n}, fake={n})')

    return df_balanced

# Balance dev
df_dev_bal  = balance_dataset(LAVDF_FEATURE_CSV_DEV,  LAVDF_BALANCED_DEV)

# Balance test
df_test_bal = balance_dataset(LAVDF_FEATURE_CSV_TEST, LAVDF_BALANCED_TEST)

print('✅ Balanced CSVs saved:')
print(' ', LAVDF_BALANCED_DEV)
print(' ', LAVDF_BALANCED_TEST)
# Out:
# Original [causal_multimodal_dataset_lavdf_dev_eval_fixed.csv]:
# label
# 1    23229
# 0     8271
# Balanced [causal_multimodal_dataset_lavdf_dev_balanced.csv]:
# label
# 0    8271
# 1    8271
# Total rows: 16542 (real=8271, fake=8271)
# Original [causal_multimodal_dataset_lavdf_test_eval_fixed.csv]:
# label
# 1    19194
# 0     6906
# Balanced [causal_multimodal_dataset_lavdf_test_balanced.csv]:
# label
# 0    6906
# 1    6906
# Total rows: 13812 (real=6906, fake=6906)
# ✅ Balanced CSVs saved:
#   /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_dataset_lavdf_dev_balanced.csv
#   /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/data/processed/causal_multimodal_dataset_lavdf_test_balanced.csv

# %%
import json
from pathlib import Path

# Load manifest
manifest_path = next(BACKEND_ROOT.rglob('fakeavceleb_best_step46_multiseed_manifest.json'))
manifest = json.loads(manifest_path.read_text())

# Get best single fold model (fold_01, seed_42)
best_artifact = manifest['artifacts'][0]
best_model_dir = BACKEND_ROOT / 'models' / Path(best_artifact['model_path']).parent

print('Best model dir:', best_model_dir)
print('Exists:', best_model_dir.exists())

# Update MODEL_DIR_LAVDF
MODEL_DIR_LAVDF = best_model_dir
print('MODEL_DIR_LAVDF updated to best model')
# Out:
# Best model dir: /Users/venturit/Documents/GitHub/FYP/CausalX-Project/backend/models/step46_fakeav_robust_constrained_s42_20260317_030925_fold_01_p2_r03_focal_lr0p0003
# Exists: True
# MODEL_DIR_LAVDF updated to best model

# %% [markdown]
# ## LAV-DF Balanced Threshold Calibration + Final Evaluation

# %%
# ============================================================
# LAV-DF Balanced Evaluation — Cell B
# ============================================================
import subprocess, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

if not LAVDF_BALANCED_DEV.exists():
    raise FileNotFoundError(f'Balanced dev CSV missing. Run Cell A first.')
if not LAVDF_BALANCED_TEST.exists():
    raise FileNotFoundError(f'Balanced test CSV missing. Run Cell A first.')

# ---- Step 1: Threshold sweep on balanced DEV ----
print('Threshold sweep on balanced DEV set ...')

thresholds_to_try = [round(t, 3) for t in np.arange(0.05, 0.95, 0.025)]
best_thr_bal    = 0.5
best_bal_bal    = 0.0
thr_results_bal = []

for i, thr in enumerate(thresholds_to_try):
    cmd = [
        PYTHON_EXE, str(EVAL_SCRIPT),
        '--model-dir',       str(MODEL_DIR_LAVDF),
        '--data-csv',        str(LAVDF_BALANCED_DEV),
        '--feature-profile', FEATURE_PROFILE_LAVDF,
        '--threshold',       str(thr),
    ]
    r = subprocess.run(cmd, cwd=str(BACKEND_ROOT),
                       text=True, capture_output=True, env=ENV)
    for ln in r.stdout.splitlines():
        if ln.startswith('overall:'):
            m = json.loads(ln.split('overall:', 1)[1].strip())
            bal  = float(m.get('bal_acc', 0.0))
            f1   = float(m.get('f1',      0.0))
            spec = float(m.get('spec',    0.0))
            rec  = float(m.get('rec',     0.0))
            auc  = float(m.get('auc',     0.0))
            thr_results_bal.append({
                'threshold': thr,
                'bal_acc':   bal,
                'f1':        f1,
                'spec':      spec,
                'rec':       rec,
                'auc':       auc,
            })
            if bal > best_bal_bal:
                best_bal_bal = bal
                best_thr_bal = thr
            if (i + 1) % 10 == 0:
                print(f'  Progress: {i+1}/{len(thresholds_to_try)} '
                      f'| best thr={best_thr_bal} bal_acc={best_bal_bal:.4f}')
            break

thr_df_bal = pd.DataFrame(thr_results_bal).sort_values('bal_acc', ascending=False)
print('Top 5 thresholds (balanced dev):')
print(thr_df_bal.head(5).to_string(index=False))
print(f'✅ Best threshold (balanced) = {best_thr_bal} (bal_acc={best_bal_bal:.4f})')

# ---- Step 2: Final eval on balanced TEST ----
print(f'Final evaluation on balanced TEST set ...')
print(f'Threshold: {best_thr_bal}')

cmd_test = [
    PYTHON_EXE, str(EVAL_SCRIPT),
    '--model-dir',       str(MODEL_DIR_LAVDF),
    '--data-csv',        str(LAVDF_BALANCED_TEST),
    '--feature-profile', FEATURE_PROFILE_LAVDF,
    '--threshold',       str(best_thr_bal),
]
res_test = subprocess.run(cmd_test, cwd=str(BACKEND_ROOT),
                          text=True, capture_output=True, env=ENV)
if res_test.returncode != 0:
    print('STDERR:', res_test.stderr[-3000:])
    raise RuntimeError('Balanced test evaluation failed.')

overall = None
for ln in res_test.stdout.splitlines():
    if ln.startswith('overall:'):
        overall = json.loads(ln.split('overall:', 1)[1].strip())
        break

if overall is None:
    raise RuntimeError('Could not parse overall metrics.')

# ---- Results ----
print('' + '='*60)
print('  LAV-DF Balanced Cross-Dataset Evaluation')
print('='*60)
print(f'  Threshold: {best_thr_bal} (calibrated on balanced dev)')
print('='*60)
print(f'  ACC      = {float(overall["acc"]):.4f}')
print(f'  AUC      = {float(overall["auc"]):.4f}')
print(f'  PR-AUC   = {float(overall["pr_auc"]):.4f}')
print(f'  F1       = {float(overall["f1"]):.4f}')
print(f'  Precision= {float(overall["prec"]):.4f}')
print(f'  Recall   = {float(overall["rec"]):.4f}')
print(f'  Spec     = {float(overall["spec"]):.4f}')
print(f'  Bal.ACC  = {float(overall["bal_acc"]):.4f}')
print(f'  TP={int(overall["tp"])} TN={int(overall["tn"])} '
      f'FP={int(overall["fp"])} FN={int(overall["fn"])}')
print('='*60)

display(pd.DataFrame([{
    'ACC':    round(float(overall['acc']),    4),
    'AUC':    round(float(overall['auc']),    4),
    'PR-AUC': round(float(overall['pr_auc']), 4),
    'F1':     round(float(overall['f1']),     4),
    'Prec':   round(float(overall['prec']),   4),
    'Rec':    round(float(overall['rec']),    4),
    'Spec':   round(float(overall['spec']),   4),
    'BalACC': round(float(overall['bal_acc']),4),
}]))

# ---- Comparison table ----
print('Full Comparison:')
display(pd.DataFrame([
    {
        'Dataset':  'FakeAVCeleb — Step44 (in-domain)',
        'ACC': 0.9988, 'AUC': 0.9997,
        'F1':  0.9994, 'Bal.ACC': 0.9799,
    },
    {
        'Dataset':  'LAV-DF imbalanced (zero-shot)',
        'ACC': 0.4464, 'AUC': 0.5251,
        'F1':  0.4942, 'Bal.ACC': 0.5163,
    },
    {
        'Dataset':  'LAV-DF balanced (zero-shot)',
        'ACC':     round(float(overall['acc']),    4),
        'AUC':     round(float(overall['auc']),    4),
        'F1':      round(float(overall['f1']),     4),
        'Bal.ACC': round(float(overall['bal_acc']),4),
    },
]))

# ---- Plots ----
tp = int(overall['tp']); tn = int(overall['tn'])
fp = int(overall['fp']); fn = int(overall['fn'])
cm = np.array([[tn, fp], [fn, tp]], dtype=int)

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

im = axes[0].imshow(cm, cmap='Blues')
for (r, c), v in np.ndenumerate(cm):
    axes[0].text(c, r, str(v), ha='center', va='center', fontsize=12)
axes[0].set_xticks([0, 1], labels=['Pred Real', 'Pred Fake'])
axes[0].set_yticks([0, 1], labels=['True Real', 'True Fake'])
axes[0].set_title(f'LAV-DF Balanced Confusion Matrix(thr={best_thr_bal})')
fig.colorbar(im, ax=axes[0], fraction=0.046, pad=0.04)

thr_plot = pd.DataFrame(thr_results_bal)
axes[1].plot(thr_plot['threshold'], thr_plot['bal_acc'],
             label='Balanced ACC', marker='o', markersize=3)
axes[1].plot(thr_plot['threshold'], thr_plot['f1'],
             label='F1', marker='s', markersize=3)
axes[1].plot(thr_plot['threshold'], thr_plot['spec'],
             label='Specificity', marker='^', markersize=3)
axes[1].axvline(best_thr_bal, color='red', linestyle='--',
                label=f'Best thr={best_thr_bal}')
axes[1].set_xlabel('Threshold')
axes[1].set_ylabel('Score')
axes[1].set_title('Threshold Sweep (Balanced LAV-DF Dev)')
axes[1].legend(fontsize=8)
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Threshold sweep on balanced DEV set ...
#   Progress: 10/36 | best thr=0.275 bal_acc=0.5317
#   Progress: 20/36 | best thr=0.45 bal_acc=0.5371
#   Progress: 30/36 | best thr=0.45 bal_acc=0.5371
# Top 5 thresholds (balanced dev):
#  threshold  bal_acc       f1     spec      rec      auc
#      0.450 0.537057 0.495786 0.618909 0.455205 0.549171
#      0.500 0.536936 0.466351 0.669206 0.404667 0.549171
#      0.475 0.536030 0.480541 0.642849 0.429210 0.549171
#      0.525 0.535183 0.449330 0.691089 0.379277 0.549171
#      0.425 0.535062 0.508656 0.588804 0.481320 0.549171
# ✅ Best threshold (balanced) = 0.45 (bal_acc=0.5371)
# Final evaluation on balanced TEST set ...
# Threshold: 0.45
# ...
#   LAV-DF Balanced Cross-Dataset Evaluation
# ...
#   Threshold: 0.45 (calibrated on balanced dev)
# ...
#   ACC      = 0.5257
#   AUC      = 0.5313
#   PR-AUC   = 0.5351
#   F1       = 0.4557
#   Precision= 0.5346
#   Recall   = 0.3970
#   Spec     = 0.6544
#   Bal.ACC  = 0.5257
# ...
